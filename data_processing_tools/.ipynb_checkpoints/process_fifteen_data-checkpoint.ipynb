# %%
import pandas as pd

# %%
df2018 = pd.read_csv("../fifteen_dataset/2018.csv")

# %%
df2017 = pd.read_csv("../fifteen_dataset/2017.csv")

# %%
df2016 = pd.read_csv("../fifteen_dataset/2016.csv")

# %%
df2015 = pd.read_csv("../fifteen_dataset/2015.csv")

# %%
df2014 = pd.read_csv("../fifteen_dataset/2014.csv")

# %%
df2013 = pd.read_csv("../fifteen_dataset/2013.csv")

# %%
df2012 = pd.read_csv("../fifteen_dataset/2012.csv")

# %%
df2011 = pd.read_csv("../fifteen_dataset/2011.csv")

# %%
df = pd.concat([df2018,df2017,df2016,df2015,df2014,df2013,df2012,df2011])

# %%
df = df.reset_index(drop=True)

# %%
df
# Out:
#                                                     clue  \
# 0      12 DUNT Local gild moribunD UNTil [taking some...
# 1             18 OPE HOPEful [times]revealed in song (3)
# 2      1 THEORY  Nothing divides the lines – that’s t...
# 3                             4 SMACKS  Blows kisses (6)
# 4      9 TRIUMPHANT  Run at it wildly, picking up spe...
# 5      10 PEER  Member of the Lords backtracking on r...
# 6                   16 PARMESAN  Cheese cut & grated (8)
# 7      19 GUEST One’s offered hospitality in rogue st...
# 8      21 DIASPORA  Those living abroad get help retu...
# 9                           23 NETHER  Lower numbers (6)
# 10     25 AGIO  Finally, “Hi ho Silver” before the ch...
# 11     26 EVIL MINDED  Did men live sinfully, being i...
# 12     2 EQUATOR  Without question, a route should be...
# 13     3 REPORTERS  Press on, having left the last tr...
# 14     5 MOTTO  Bottoms up, endlessly – that’s the wa...
# 15     11 CAPITAL LETTER London landlord that’s facin...
# 16     8 DA CAPO Party embracing a limit on spending ...
# 17     13 PLAYING UP No being cryptic and causing pro...
# 18     15 ERGONOMIC  For this reason lack of amplific...
# 19     18 NIACIN  Doctor, can I get the first pair to...
# 20     20 EAT INTO Dropped dead while antidote was wo...
# 21             22 OCEAN  The main problem with canoe (5)
# 22     1 COUNCIL  A Parisian caught breaking wind in ...
# 23     5 BOTCHED  Nick loses head in the sack – that’...
# 24     9 ABDICATOR Edward the VIII? A British tyrant ...
# 25     10 SYRIA Country stronghold you raid in anger ...
# 26     11 PARMA  Parents to tour Rome at first, then ...
# 27     12 ICE MAIDEN  Nice dame I put out is a really...
# 28     13 GLUCOSE  Posh firm near Kent after good tip...
# 29     15 LAPPING Drinking like a setter? Don’t start...
# ...                                                  ...
# 64869  15. Promote correct manner of ambulation, as 1...
# 64870  16. Iodine thus something to discuss regarding...
# 64871   17. Potential layer in this painting finish? (8)
# 64872  19. Weak character from outer space, a Klingon...
# 64873  23. Something cheeky about capital of Rhodesia...
# 64874  1. Lying down in middle of boulevard after dri...
# 64875  4. In which one may see Odette boast about the...
# 64876               10. Girl cuddling boy in a state (9)
# 64877                  11. Clear away thatch aloft (3,2)
# 64878        12. Cat, say, brought back after search (7)
# 64879  13. Hornblower’s short speech after end of cla...
# 64880  14. Suspicious transaction with him, a republi...
# 64881     21. Drank one given by doctor, one by bunk (7)
# 64882  22. Court finally presented with motive for ac...
# 64883       24. Fuss about a single step in a series (5)
# 64884  25. Complete change of opinion concerning fell...
# 64885  26. Provide forceful evidence against the Ital...
# 64886     27. Is worried about small son getting pet (6)
# 64887             1. Willy Loman? Name lass involved (8)
# 64888                2. Roman god in place, cast out (5)
# 64889              3. Quack remedy in no way unusual (7)
# 64890  5. Around northern tip of region, one state wi...
# 64891           6. Chief magistrate upset about demo (7)
# 64892  7. Inordinate praise about favourite hors d’oe...
# 64893                         8. Use Forster device? (6)
# 64894   15. Computer image of distressed lamb in hut (9)
# 64895   16. Trendy types, carollers surrounding wife (8)
# 64896  18. Jazz fan about to reveal what goes on in n...
# 64897  19. Choose artist showing a complex character (7)
# 64898       20. Turn down quantity of Chinese food (3,3)
#
#                                                      exp  len
# 0       E 14 NELIS Fruit that’s PENSILE* [rotted] [wi...  273
# 1       W 21 OHM’S LAW [Criminal] {WHO WAS L (left)}*...  398
# 2       O (Nothing) between (divides) THE and RY (lin...   50
# 3       Double Definition. First one in to give a use...   75
# 4        MPH (speed) inside (RUN AT IT)* AInd: wildly...   58
# 5       RE (on) EP (reord) all reversed (backtracking...  268
# 6       (AMPERSAN[d] )* AInd: grated.  Last one in. S...  105
# 7                                   Hidden: roGUE STate    21
# 8       AID< (help, returning) first letters S P O R ...   79
# 9       N and ETHER are each a number: N just from N[...  254
# 10      AG (silver) before [h]I [h]O I had to look th...  101
# 11      (DID MEN LIVE)* AInd: sinfully 27/28 PUT ONE ...  305
# 12                (A ROUTE Q[uestion])* AInd: organised    39
# 13                     RE (on) PORT (left) [straggl]ERS    34
# 14                                      [b]OTTOM[s] < 6/   17
# 15      Charade: CAPITAL (London) LETTER (landlord) 7...  174
# 16      A CAP (a limit) inside DO (party). Musical term    49
# 17      Answer as wordplay NO is ON (playing) reverse...  105
# 18      ERGO (For this reason) NO MIC (lack of amplif...  181
# 19      (CAN I )* AInd: Doctor, IN[ject]. As seen on ...   81
# 20                   (ANITDOTE – D[ead])* AInd: working    36
# 21                          (CANOE)* AInd: problem with    29
# 22                                    (UN + C) in COIL.    19
# 23                                      [n]OTCH in BED.    17
# 24      A + B + DIC[t]ATOR. I rather liked “half the ...  118
# 25      Acrostic of S[tronghold] Y[ou] R[aid] I[n] A[...   53
# 26                            (PA + MA) touring R[ome].    27
# 27                            Anagram of (NICE DAME I).    27
# 28                            G + L[ord] + U + CO + SE.    27
# 29                                          [f]LAPPING.    13
# ...                                                  ...  ...
# 64869   PROPAGATE A homophone of proper gait (‘correc...   72
# 64870   ISOTOPIC A charade of I (‘iodine’, chemical s...   99
# 64871       EGGSHELL Definition and cryptic definition.    45
# 64872   LIMPET A charade of LIMP (‘weak’) + ET (‘char...  196
# 64873   BURMA A charade of an envelope (‘about’) of R...  121
# 64874               SUPINE (IN+(boul)E(vard)) after SUP    37
# 64875                         SWAN LAKE (LA in SWANK)+E    27
# 64876                       LOUISIANA LOUISA around IAN    29
# 64877                       MOP UP MOP(hair, thatch)+UP    29
# 64878                         SCOURGE (EG<) after SCOUR    27
# 64879         HORATIO (clas)H+ORATIO Horatio Hornblower    43
# 64880   ANTIMONARCHIST (TRANSACTION+HIM*) 17. Said of...  111
# 64881                                IMBIBED I+MB+I+BED    20
# 64882                            TREASON (cour)T+REASON    24
# 64883                               STAIR STIR around A    21
# 64884                            ABOUT-FACE ABOUT+F+ACE    24
# 64885                          MILITATE (IL+IT) in MATE    26
# 64886                  CARESS CARES around S(on) … Down    34
# 64887                             SALESMAN (NAME+LASS*)    23
# 64888                                   PLUTO PL+(OUT*)    17
# 64889                                 NOSTRUM NO+ST+RUM    19
# 64890   WEATHER STATION R in (ONE STATE WITH A*) a bi...   59
# 64891                               NOMARCH (ON<)+MARCH    21
# 64892                    APPETISER (PRAISE*) around PET    32
# 64893   EMPLOY EM(forster)+PLOY clever misleading clu...  159
# 64894                          THUMBNAIL (LAMB IN HUT*)    26
# 64895                         SWINGERS SINGERS around W    27
# 64896             CABARET CAT around BARE &lit, perhaps    39
# 64897                                  ELECTRA ELECT+RA    18
# 64898                                   DIM SUM DIM+SUM    17
#
# [64899 rows x 3 columns]

# %%
import re
def extract_answer_from_clue(clue):
    regex = '\d*\.*\s{1,2}([A-Z\s\-]{2,}\s)'
    try:
        answer = re.search(regex,clue).group(0)
        return clue.replace(answer,'')
    except Exception:
        return clue

# %%
def remove_prefix_number_from_clue(clue):
    regex = '(\d{1,2}\.*)\s'
    try:
        answer = re.search(regex,clue).group(0)
        return clue.replace(answer,'')
    except Exception:
        return clue

# %%
df['clue'] = df['clue'].apply(extract_answer_from_clue)

# %%
df['clue'] = df['clue'].apply(remove_prefix_number_from_clue)

# %%
df = df.drop('len',axis=1)

# %%
df
# Out:
#                                                     clue  \
# 0      Local gild moribunD UNTil [taking some members...
# 1                    HOPEful [times]revealed in song (3)
# 2        Nothing divides the lines – that’s the idea (6)
# 3                                       Blows kisses (6)
# 4      Run at it wildly, picking up speed and winning...
# 5         Member of the Lords backtracking on record (4)
# 6                                Cheese cut & grated (8)
# 7           One’s offered hospitality in rogue state (5)
# 8      Those living abroad get help returning, with f...
# 9                                      Lower numbers (6)
# 10        Finally, “Hi ho Silver” before the charge! (4)
# 11     Did men live sinfully, being intent on wrongdo...
# 12     Without question, a route should be organised ...
# 13     Press on, having left the last trio of straggl...
# 14     Bottoms up, endlessly – that’s the watchword! (5)
# 15         London landlord that’s facing sentence? (7,6)
# 16     Party embracing a limit on spending from the b...
# 17          No being cryptic and causing problems! (7,2)
# 18     For this reason lack of amplification is condu...
# 19     Doctor, can I get the first pair to inject ess...
# 20     Dropped dead while antidote was working? Bothe...
# 21                       The main problem with canoe (5)
# 22        Parisian caught breaking wind in congress? (7)
# 23     Nick loses head in the sack – that’s messed up...
# 24     Edward the VIII? A British tyrant half the tim...
# 25     Country stronghold you raid in anger at the fr...
# 26         Parents to tour Rome at first, then here? (5)
# 27      Nice dame I put out is a really cool woman (3,6)
# 28     Posh firm near Kent after good tip from Lord S...
# 29     Drinking like a setter? Don’t start panicking!...
# ...                                                  ...
# 64869    Promote correct manner of ambulation, as 13 (9)
# 64870  Iodine thus something to discuss regarding sim...
# 64871       Potential layer in this painting finish? (8)
# 64872  Weak character from outer space, a Klingon, as...
# 64873  Something cheeky about capital of Rhodesia, a ...
# 64874  Lying down in middle of boulevard after drink (6)
# 64875  In which one may see Odette boast about the Fr...
# 64876                   Girl cuddling boy in a state (9)
# 64877                      Clear away thatch aloft (3,2)
# 64878            Cat, say, brought back after search (7)
# 64879   Hornblower’s short speech after end of clash (7)
# 64880  Suspicious transaction with him, a republican?...
# 64881         Drank one given by doctor, one by bunk (7)
# 64882  Court finally presented with motive for act of...
# 64883           Fuss about a single step in a series (5)
# 64884  Complete change of opinion concerning fellow e...
# 64885  Provide forceful evidence against the Italian,...
# 64886         Is worried about small son getting pet (6)
# 64887                Willy Loman? Name lass involved (8)
# 64888                   Roman god in place, cast out (5)
# 64889                 Quack remedy in no way unusual (7)
# 64890  Around northern tip of region, one state with ...
# 64891              Chief magistrate upset about demo (7)
# 64892  Inordinate praise about favourite hors d’oeuvr...
# 64893                            Use Forster device? (6)
# 64894       Computer image of distressed lamb in hut (9)
# 64895       Trendy types, carollers surrounding wife (8)
# 64896  Jazz fan about to reveal what goes on in night...
# 64897      Choose artist showing a complex character (7)
# 64898           Turn down quantity of Chinese food (3,3)
#
#                                                      exp
# 0       E 14 NELIS Fruit that’s PENSILE* [rotted] [wi...
# 1       W 21 OHM’S LAW [Criminal] {WHO WAS L (left)}*...
# 2       O (Nothing) between (divides) THE and RY (lin...
# 3       Double Definition. First one in to give a use...
# 4        MPH (speed) inside (RUN AT IT)* AInd: wildly...
# 5       RE (on) EP (reord) all reversed (backtracking...
# 6       (AMPERSAN[d] )* AInd: grated.  Last one in. S...
# 7                                   Hidden: roGUE STate
# 8       AID< (help, returning) first letters S P O R ...
# 9       N and ETHER are each a number: N just from N[...
# 10      AG (silver) before [h]I [h]O I had to look th...
# 11      (DID MEN LIVE)* AInd: sinfully 27/28 PUT ONE ...
# 12                (A ROUTE Q[uestion])* AInd: organised
# 13                     RE (on) PORT (left) [straggl]ERS
# 14                                      [b]OTTOM[s] < 6/
# 15      Charade: CAPITAL (London) LETTER (landlord) 7...
# 16      A CAP (a limit) inside DO (party). Musical term
# 17      Answer as wordplay NO is ON (playing) reverse...
# 18      ERGO (For this reason) NO MIC (lack of amplif...
# 19      (CAN I )* AInd: Doctor, IN[ject]. As seen on ...
# 20                   (ANITDOTE – D[ead])* AInd: working
# 21                          (CANOE)* AInd: problem with
# 22                                    (UN + C) in COIL.
# 23                                      [n]OTCH in BED.
# 24      A + B + DIC[t]ATOR. I rather liked “half the ...
# 25      Acrostic of S[tronghold] Y[ou] R[aid] I[n] A[...
# 26                            (PA + MA) touring R[ome].
# 27                            Anagram of (NICE DAME I).
# 28                            G + L[ord] + U + CO + SE.
# 29                                          [f]LAPPING.
# ...                                                  ...
# 64869   PROPAGATE A homophone of proper gait (‘correc...
# 64870   ISOTOPIC A charade of I (‘iodine’, chemical s...
# 64871       EGGSHELL Definition and cryptic definition.
# 64872   LIMPET A charade of LIMP (‘weak’) + ET (‘char...
# 64873   BURMA A charade of an envelope (‘about’) of R...
# 64874               SUPINE (IN+(boul)E(vard)) after SUP
# 64875                         SWAN LAKE (LA in SWANK)+E
# 64876                       LOUISIANA LOUISA around IAN
# 64877                       MOP UP MOP(hair, thatch)+UP
# 64878                         SCOURGE (EG<) after SCOUR
# 64879         HORATIO (clas)H+ORATIO Horatio Hornblower
# 64880   ANTIMONARCHIST (TRANSACTION+HIM*) 17. Said of...
# 64881                                IMBIBED I+MB+I+BED
# 64882                            TREASON (cour)T+REASON
# 64883                               STAIR STIR around A
# 64884                            ABOUT-FACE ABOUT+F+ACE
# 64885                          MILITATE (IL+IT) in MATE
# 64886                  CARESS CARES around S(on) … Down
# 64887                             SALESMAN (NAME+LASS*)
# 64888                                   PLUTO PL+(OUT*)
# 64889                                 NOSTRUM NO+ST+RUM
# 64890   WEATHER STATION R in (ONE STATE WITH A*) a bi...
# 64891                               NOMARCH (ON<)+MARCH
# 64892                    APPETISER (PRAISE*) around PET
# 64893   EMPLOY EM(forster)+PLOY clever misleading clu...
# 64894                          THUMBNAIL (LAMB IN HUT*)
# 64895                         SWINGERS SINGERS around W
# 64896             CABARET CAT around BARE &lit, perhaps
# 64897                                  ELECTRA ELECT+RA
# 64898                                   DIM SUM DIM+SUM
#
# [64899 rows x 2 columns]

# %%
df['is_anagram'] = df['exp'].apply(lambda x:len(re.findall('(anagram|anag|\)\*|\*\(|\*\))',x,re.IGNORECASE))>0)

# %%
df[df['is_anagram']]
# Out:
#                                                     clue  \
# 4      Run at it wildly, picking up speed and winning...
# 6                                Cheese cut & grated (8)
# 11     Did men live sinfully, being intent on wrongdo...
# 12     Without question, a route should be organised ...
# 15         London landlord that’s facing sentence? (7,6)
# 19     Doctor, can I get the first pair to inject ess...
# 20     Dropped dead while antidote was working? Bothe...
# 21                       The main problem with canoe (5)
# 27      Nice dame I put out is a really cool woman (3,6)
# 32            Rubbish old git cites is all about me? (9)
# 35                        made time up without delay (9)
# 38        Bubbly chap game to get blotto around noon (9)
# 44     Plain rude to mess around with a northern don (9)
# 45     Police head new plan to ask for change in Amer...
# 46     Doctor assessing condition of long-winded pati...
# 58     say contract’s to be rewritten, ensuring invio...
# 60     Rock tunes – Dominican initially involved was ...
# 63     Excludes human agency from boosters misguidedl...
# 65     Nasty nippers, group of six playing around wit...
# 74     Source of bird seed, kilo lost from bursting g...
# 80        Hat material? Third of sale goes in a rush (5)
# 88            Arrogance in memo I’d amended with pen (9)
# 95                                 Outstandinglesson (5)
# 99                   Spring up, diving into gift bag (8)
# 105    Ice melts with both micro-organisms used in th...
# 107     When messed up, I snort line — through here? (7)
# 112                Revolt in Peru is revolutionary (4,2)
# 117       Poor Paul requires some medical containers (8)
# 122    1AUSA’s abandoned wise folk – they’ve been stu...
# 125                     10AEuropean’s valiant “Out!” (7)
# ...                                                  ...
# 64776                  Sir Nigel ordered German wine (8)
# 64783  See 5 Down See 5 Down [INTERNATIONAL MONETARY]...
# 64785  Sees new Latin translation as vitally importan...
# 64787  Capital or very good deal ruined by incomplete...
# 64790                   Delay for debt-ridden sailor (6)
# 64794        Very complacent or misguidedidealists (4-9)
# 64795  We have to enter shrine rebuilt for one giving...
# 64804  Run with last bit of email, cc from Vince Cabl...
# 64813                 Small gift strangely appealing (9)
# 64815  At St Paul’s ultimate activist is unravelling ...
# 64818   Cryptic giant having joined Times – has he? (10)
# 64822  English one who noted stirring Earl Grey at th...
# 64824  Taking lead from Sita, Stoic converted – embra...
# 64828  Fez trainee refashioned – it’s useful in winte...
# 64838         Doctor gin in filthy room? That’s mean (6)
# 64840  After resistance, change census area – that al...
# 64842  There’s assistance here to welcome rerouted fl...
# 64843  Shattered bike racer swallowing tablet – it re...
# 64847  Unusually nice article, he might shed light? (11)
# 64848            Play has racier tone unfortunately (10)
# 64850  Urged to reform internally, gone off alcohol, ...
# 64855                  Hard, Proust, funny old comic (7)
# 64858    Making sweet love in windy act, ruing gas (5-7)
# 64865     It doesn’t matter which here, it turns out (6)
# 64880  Suspicious transaction with him, a republican?...
# 64887                Willy Loman? Name lass involved (8)
# 64888                   Roman god in place, cast out (5)
# 64890  Around northern tip of region, one state with ...
# 64892  Inordinate praise about favourite hors d’oeuvr...
# 64894       Computer image of distressed lamb in hut (9)
#
#                                                      exp  is_anagram
# 4        MPH (speed) inside (RUN AT IT)* AInd: wildly...        True
# 6       (AMPERSAN[d] )* AInd: grated.  Last one in. S...        True
# 11      (DID MEN LIVE)* AInd: sinfully 27/28 PUT ONE ...        True
# 12                (A ROUTE Q[uestion])* AInd: organised         True
# 15      Charade: CAPITAL (London) LETTER (landlord) 7...        True
# 19      (CAN I )* AInd: Doctor, IN[ject]. As seen on ...        True
# 20                   (ANITDOTE – D[ead])* AInd: working         True
# 21                          (CANOE)* AInd: problem with         True
# 27                            Anagram of (NICE DAME I).         True
# 32                          Anagram of (O + GIT CITES).         True
# 35                            Anagram of (I MADE TIME).         True
# 38                               (CHAP GAME)* around N.         True
# 44                     Anagram of (RUDE + A + N + DON).         True
# 45                        Anagram of (HEAD + N + PLAN).         True
# 46                                Anagram of ASSESSING.         True
# 58                                  *(I SAY CONTRACTS).         True
# 60      D(ominican) in *TUNES. 28 DE RIGUEUR I’d urge...        True
# 63                                    I in *(BOOSTERS).         True
# 65      S in SESTET, with the two parts exchanged. I ...        True
# 74                             *(GRANARY SACKS) less K.         True
# 80      L (third letter in saLe) in TULE (a kind of b...        True
# 88      A charade of IMMODE, an anagram (‘amended’) o...        True
# 95      Double definition (“a class act”). 6 BACK TO ...        True
# 99      An envelope (‘diving into’) of APS, a reversa...        True
# 105                                         (ICE BOTH)*         True
# 107    (I SNORT L)* 27*. POULENC Having lost capital,...        True
# 112                                          (PERU IS)*         True
# 117                                        (PAUL SOME)*         True
# 122     they’ve been stuffed! / SAU (anag, i.e. aband...        True
# 125               European / anag, i.e. out, of VALIANT         True
# ...                                                  ...         ...
# 64776   Anagram of (ordered) SIR NIGEL RIESLING (dry ...        True
# 64783   Anagram of (to be reformulated) LOAN IS and C...        True
# 64785   Anagram of (new) SEES + anagram of (translati...        True
# 64787   A (very good) + anagram of (ruined) DEAL + ID...        True
# 64790   TAR (sailor) contained in (ridden [oppressed ...        True
# 64794   Anagram of (misguided) EFSF IDEALISTS (EFSF i...        True
# 64795   OUR (we have) contained in (to enter) an anag...        True
# 64804   INVULNERABLE : Anagram of(redraft) [RUN + L(l...        True
# 64813   LAGNIAPPE : Anagram of(strangely) APPEALING D...        True
# 64815   VITAL STATISTICS : Anagram of(unravelling) [A...        True
# 64818   ENIGMATIST : Anagram of(cryptic) [GIANT plus(...        True
# 64822   ELGAR : Anagram of(stirring) [EARL + G(first ...        True
# 64824   TAOISTIC : Anagram of(converted) ITA{“Sita” m...        True
# 64828   ANTIFREEZE : Anagram of(refashioned) FEZ TRAI...        True
# 64838   STINGY : Anagram of(doctor) GIN contained in(...        True
# 64840   REASSURANCE : Anagram of(change) CENSUS AREA ...        True
# 64842   AIRFIELD : AID(assistance) containing(to welc...        True
# 64843   ICEBREAKER : Anagram of(shattered) BIKE RACER...        True
# 64847   ELECTRICIAN : Anagram of(unusually) NICE ARTI...        True
# 64848   RECREATION : Anagram of(unfortunately) RACIER...        True
# 64850   DRUDGERY : Anagram of(to reform) URGED contai...        True
# 64855   HOTSPUR A charade of H (‘hard’) + OTSPUR, an ...        True
# 64858   SUGAR-COATING An anagram (‘windy’) of O (‘lov...        True
# 64865     EITHER An anagram (‘turns out’) of ‘here it’.         True
# 64880   ANTIMONARCHIST (TRANSACTION+HIM*) 17. Said of...        True
# 64887                             SALESMAN (NAME+LASS*)         True
# 64888                                   PLUTO PL+(OUT*)         True
# 64890   WEATHER STATION R in (ONE STATE WITH A*) a bi...        True
# 64892                    APPETISER (PRAISE*) around PET         True
# 64894                          THUMBNAIL (LAMB IN HUT*)         True
#
# [12621 rows x 3 columns]

# %%
df['is_homophone'] = df['exp'].apply(lambda x:len(re.findall('(homophone|sound)',x,re.IGNORECASE))>0)

# %%
df[df['is_homophone']]
# Out:
#                                                     clue  \
# 102         Neighbourhood style, according to report (5)
# 152            Outspoken bright young whippersnapper (5)
# 159    Big event for sports college, and sound equipm...
# 167              Rider cycled here without hard seat (8)
# 199    Praise group just outside the medal positions,...
# 205    Drink with thanks announced? A delicious drink...
# 282    Spooner’s authentic furniture material that ma...
# 287          Think out loud where to put the horses? (4)
# 297    Report of fire in passage with rubbish going t...
# 305               Young bird and small seal in sound (6)
# 319    Blue substance ?- is this what officers get pa...
# 330    Cleavages Simon Peter and Andrew perhaps found...
# 331       Politician leading English party? False! (7-2)
# 336    Send letter to us that’s left out? On the cont...
# 345    Disputed region ready for broadcast on space s...
# 356    Cat lover, so it’s said, first to describe spi...
# 404    More flamboyant Formula One driver, it is said...
# 545                          Sound of toilet in shed (6)
# 556                  Milled grain for a bloomer, say (9)
# 653    It’s said capacious hanky’s needed, if you’re ...
# 752            Period when was jousting, reportedly? (9)
# 807    Is it driver James or MP Jeremy reported perse...
# 831    Land in Siberia, part of journey being discuss...
# 833               Announcement: target has been hit? (8)
# 860     What arises from the Ashes? Renewed hope, hav...
# 964       Fragment of Messiah heard, part of a cycle (9)
# 1152               Asian joint said to be very small (4)
# 1206   Announced check on drug problem for the enviro...
# 1260                        Broadcast mocking writer (4)
# 1285   We’re told an essential ingredient for Caribbe...
# ...                                                  ...
# 63907               Hearts in grip of force collapse (4)
# 63945  Practical expert, mostly genuine and no-nonsen...
# 64098  Who’s uplifted Sound of Music with Mother Supe...
# 64142     Wheat product reportedly grown in Sussex (3,5)
# 64154                     Wake to sound of arguments (5)
# 64168         Whistled to girls having viewing aids (10)
# 64198                   Mind chap’s lesson read out? (6)
# 64483      High storey heard as not necessarily 15 (4,4)
# 64491      How a Londoner is said to work with this? (6)
# 64496  Science said to convey antipathy to Old Bill (10)
# 64502         Rules on air that smoker will resent (3,3)
# 64518            Suddenly see timeless Arctic Circle (5)
# 64562  Get in line, say, for game across the Thames (...
# 64569  Fellow with divisions in road, reportedly – he...
# 64604  Chess champion announcing lack of fish on menu...
# 64661  Reportedly, that chap will supply unlisted wea...
# 64666         Good ear gets sound of emptying bottle (4)
# 64698                They sing about 24 pages on air (5)
# 64699                          POWs bury joints, say (9)
# 64758  Spicy snack from, say, B-52’s hold, said to be...
# 64764                   Brake loudly: road ends here (4)
# 64771  A tautness sound, as might be heard by driller...
# 64778     Not mad about chance one gets to be gloomy (9)
# 64784  Discussed in mischievous way the sea creatures...
# 64861  Flying reptile, frightening thing with lots of...
# 64864  Christian hoarding treasure primarily after go...
# 64866  Fish and snake on the road, one sliding down t...
# 64867          Southern African’s sexy figure, baby! (9)
# 64869    Promote correct manner of ambulation, as 13 (9)
# 64872  Weak character from outer space, a Klingon, as...
#
#                                                      exp  is_anagram  \
# 102     A homophone (‘according to report’) of MANNER...       False
# 152                             SONNY Sounds like SUNNY        False
# 159     OLYMPICS POLY – college & MICS – sound equipm...       False
# 167     DERRIERE RIDER*cycled & a not H(ard) (h)ERE 2...       False
# 199     SET (group) + homophone [we’re told] of FOURT...       False
# 205     Homophone [announced] of: NECK (drink) + TA (...       False
# 282     spoonerism of SOUND (authentic) PINE (furnitu...       False
# 287                            sounds like MUSE (think)        False
# 297                            sounds like SHOOT (fire)        False
# 305                     sounds like SIGNET (small seal)        False
# 319     COPPER NITRATE I heard this joke decades ago ...       False
# 330     FISSURES Sounds like [found pronounced] ‘fish...       False
# 331     TRUMPED-UP TRUMP [politician] + E [English] +...       False
# 336     WRITE IN Sounds like ‘right in’ – which is no...       False
# 345     KASHMIR KASH – sounds like [broadcast] ‘cash’...       False
# 356      TOM (‘cat’) preceded by homophone of FAN (‘l...       False
# 404                     homophone of Niki ‘Lauda’[wiki]        False
# 545                    Homophone of ‘throne’, a toilet.        False
# 556    CORN (milled grain) + homophone of “flower”, &...       False
# 653                RHEUMY Sounds like roomy [capacious]        False
# 752        Homophone (reportedly) of “fought knight”???        False
# 807     sounds like ‘which Hunt?’ – between racing dr...       False
# 831                                 Sounds like “step”.        False
# 833                     A simple and obvious homophone.        False
# 860     PHOENIX An anagram of HOPE (anagrind is ‘rene...        True
# 964    Homophone of “Handel bar”, which might be a fr...       False
# 1152      TINY (sounds like [said] THAI [THAIland is ...       False
# 1206    RAIN sounds like (announced) rein (check) fol...       False
# 1260    SAKI (Hector Hugh Munro) sounds like SARKY (s...       False
# 1285    AKEE IVEE Sounds like (we’re told) A KEY (an ...       False
# ...                                                  ...         ...
# 63907   H (hearts [suit in playing cards]) contained ...       False
# 63945   Def: Practical expert. ECH (mostly genuine) a...       False
# 64098   MA (mother) + (AIR [melody or tune; sound of ...        True
# 64142   RYE BREAD : Homophone of(reportedly) {“rye”(a...       False
# 64154   ROUSE : Homophone of(sound of) “rows”(argumen...       False
# 64168   SUNGLASSES : SUNG(made a whistling sound, as ...       False
# 64198   SHRINK Lessen is a homophone (‘read out’) of ...       False
# 64483   TALL (high) + TALE (story [sounds like {heard...       False
# 64491   ARDOUR (sounds like [is said] ‘ARDER, how an ...       False
# 64496   MET (Metropolitan Police; Old Bill) + ALLURGY...       False
# 64502   Homophone “Syntax” (rules on air) and &Lit. I...       False
# 64518   IN[t]UIT Circle in the definition is a circle...       False
# 64562   KEW BRIDGE KEW [sounds like [say] queue – get...       False
# 64569   GUY FAWKES GUY [fellow] + FAWKES [sounds like...       False
# 64604   KARPOV : Homophone of(announcing) “carp”(fish...       False
# 64661   unlisted U HEEL (sounds like [reportedly] HE’...       False
# 64666     G (good) + LUG (ear) G LUG GLUG (a word rep...       False
# 64698   CHOIR (sounds like [on air] QUIRE [24 sheets ...       False
# 64699   INTER (bury) + NEES (sounds like [say] KNEES ...       False
# 64758   BOMBAY MIX Sounds like (“said”) “bomb bay”, i...       False
# 64764                          KERB Homophone of “curb”        False
# 64771   ATTENTION Sounds like “a tension”, and soldie...       False
# 64778   SANE (sound in mind, rational; not mad) conta...       False
# 64784   NAUTILI (sounds like [discussed] NAUGHTILY [i...       False
# 64861   PTEROSAUR 13 is PRONOUNCED, and this is the f...       False
# 64864   AUDITOR A charade (‘after’) of AU (‘gold’) + ...       False
# 64866   SKATEBOARD A charade of SKATE (‘fish’) + BOA ...       False
# 64867   HOTTENTOT A charade of HOT (‘sexy’) + TEN (‘f...       False
# 64869   PROPAGATE A homophone of proper gait (‘correc...       False
# 64872   LIMPET A charade of LIMP (‘weak’) + ET (‘char...       False
#
#        is_homophone
# 102            True
# 152            True
# 159            True
# 167            True
# 199            True
# 205            True
# 282            True
# 287            True
# 297            True
# 305            True
# 319            True
# 330            True
# 331            True
# 336            True
# 345            True
# 356            True
# 404            True
# 545            True
# 556            True
# 653            True
# 752            True
# 807            True
# 831            True
# 833            True
# 860            True
# 964            True
# 1152           True
# 1206           True
# 1260           True
# 1285           True
# ...             ...
# 63907          True
# 63945          True
# 64098          True
# 64142          True
# 64154          True
# 64168          True
# 64198          True
# 64483          True
# 64491          True
# 64496          True
# 64502          True
# 64518          True
# 64562          True
# 64569          True
# 64604          True
# 64661          True
# 64666          True
# 64698          True
# 64699          True
# 64758          True
# 64764          True
# 64771          True
# 64778          True
# 64784          True
# 64861          True
# 64864          True
# 64866          True
# 64867          True
# 64869          True
# 64872          True
#
# [1844 rows x 4 columns]

# %%
df['is_double'] = df['exp'].apply(lambda x:len(re.findall('(double|\sdd\s|Two definitions|\sdefs)',x,re.IGNORECASE))>0)

# %%
df[df['is_double']]
# Out:
#                                                     clue  \
# 3                                       Blows kisses (6)
# 5         Member of the Lords backtracking on record (4)
# 31     Crazy couple of people getting jiggy with it? (7)
# 41     Weightlifter’s companion and I might ring last...
# 95                                 Outstandinglesson (5)
# 121                            One way still to go … (4)
# 141                 18DHouse of Commons kind of pot? (7)
# 166                              Identificationmarks (8)
# 180                        More enthusiastic mourner (6)
# 198                Emphasisesymptom of work pressure (6)
# 225                                      Cover band? (5)
# 241                                  Stick with team (5)
# 273                                  Get out ofmoney (7)
# 300                             Weesound from a bell (6)
# 320    Architect built outstanding oratory primarily ...
# 322                          Considerable mess gone? (4)
# 366           Subsidiary operation on railway branch (8)
# 375      They may be looked up to in the cheap seats (4)
# 377                     Go up to reach the hierarchy (5)
# 389                  Royalunit involved with charge? (5)
# 390                                 Reallynot joking (9)
# 426                         Chiefsection of the foot (4)
# 455       Bother at home with multi-function toilet? (9)
# 477    Sweet turns allowed for a pair of sixes maybe (6)
# 492    Protective garb, taking everything into accoun...
# 509                     Issue instructions to lawyer (5)
# 514                  Herald magnificent achievement? (7)
# 533                                     Meetinghouse (8)
# 549                                   Rider’s skill (13)
# 553          Say too much about one’s being boastful (7)
# ...                                                  ...
# 64356                   Carpenter in fast food joint (6)
# 64366                               Gently wipe fish (3)
# 64372                                   Stern parent (4)
# 64395                              Precedent in case (7)
# 64408                                  Chief’s brief (5)
# 64498     Where soldiers appear to display idleness? (8)
# 64504     … which might be one if it does this run (4,4)
# 64511                 Start of Operation Midnight? (4,4)
# 64525                      Noticed again and said so (8)
# 64574  Rule about little room at first needing scrubb...
# 64577     A few lines — got some between the teeth (3,4)
# 64583                                Money for tramp (5)
# 64585                  Uniquely how folk tales begin (4)
# 64591                     The best toys for children (4)
# 64595                        Swollen, as smokers did (6)
# 64598                   Oddball‘s Christmas missive? (4)
# 64599      Put right what stripper did after the act (9)
# 64619                                  Prison unrest (4)
# 64621  Blair cut short after gushing “A national hero...
# 64754       30DChamber in temple’s underground vault (5)
# 64761  Judge accepts D-Day series of battles for a si...
# 64779     Means of attachment for a natural climber? (7)
# 64802  In most need of support – the rest of Spain do...
# 64811                                   Harry Potter (6)
# 64827               Only remaining shoemaker’s model (4)
# 64832              Landlord’s means of communication (6)
# 64834                                    Gentle sort (4)
# 64844                 Tiger starts with it of course (3)
# 64853                               Actors discarded (4)
# 64868                       It’s said to be obvious (10)
#
#                                                      exp  is_anagram  \
# 3       Double Definition. First one in to give a use...       False
# 5       RE (on) EP (reord) all reversed (backtracking...       False
# 31                                     Two definitions.        False
# 41      This initially seemed like two definitions, b...       False
# 95      Double definition (“a class act”). 6 BACK TO ...        True
# 121                                   Double definition        False
# 141     double defn. / the House of Commons is a (deb...       False
# 166                           SPOTTING Double defintion        False
# 180                       KEENER Double definition Down        False
# 198                                   Double definition        False
# 225     LAYER : Double defn. 1: … over a surface, suc...       False
# 241     STAFF : Double defn: 2nd: … in a particular o...       False
# 273                                              2 defs        False
# 300                                          double def        False
# 320     THEOCRATIC Anagram [built] of ARCHITECT round...        True
# 322                              TIDY Double definition        False
# 366                                  Double definition.        False
# 375      Double def. Seats high up – ‘in the gods’ – ...       False
# 377                          Double def, both strained.        False
# 389     double definition: =the name of many Kings; =...       False
# 390                              double definition Down        False
# 426                                              2 defs        False
# 455     INCOMMODE : IN(at home) + COMMODE(a piece of ...       False
# 477    Reverse of PUD (pudding, sweet) + LET – a dupl...       False
# 492                                   Double definition        False
# 509      BRIEF (issue instructions) BRIEF BRIEF (barr...       False
# 514      TRIUMPH (the closest match I can find betwee...       False
# 533             Double def., 1st royal, 2nd theatrical.        False
# 549                                  Double definition.        False
# 553      EG (‘say’) + OTT (‘too much’) around 1’S. “O...       False
# ...                                                  ...         ...
# 64356                         CHIPPY Double definition.        False
# 64366                                DAB : Double defn.        False
# 64372   REAR : Double defn: 1st: The back part,rear o...       False
# 64395                                        EXAMPLE dd        False
# 64408                                          PRIME dd        False
# 64498   IN ACTION (where soldiers appear) INACTION (i...       False
# 64504   DD I think this is a Double Def. One is “run”...        True
# 64511   Double Def. (sort of?) 00:00 is the zero hour...       False
# 64525          double definition: noticed again/said so        False
# 64574   CANCELLATION CANON [rule] around [about] CELL...       False
# 64577                        BIT PART double definition        False
# 64583               POUND : Double defn. 2nd: as a verb        False
# 64585   ONCE : Double defn: 2nd: Eg. “ONCE upon a tim...       False
# 64591   TOPS : Double defn: 1st: The best, usually in...       False
# 64595                             PUFFED : Double defn.        False
# 64598                               CARD : Double defn.        False
# 64599                          REDRESSED : Double defn.        False
# 64619                                       Double def.        False
# 64621   TON[y] (Blair cut short) after WELLING (gushi...       False
# 64754   / double defn (of sorts) – CELLA = temple cha...       False
# 64761                     RED DWARF REF around DD + WAR        False
# 64779   TENDRIL (anything resembling a plant’s tendri...       False
# 64802   SAGGIEST : {SIEST(“siesta”,the midday rest th...       False
# 64811   NIGGLE : Double defn: 1st: To find fault with...       False
# 64827                               LAST : Double defn.        False
# 64832                             LETTER : Double defn.        False
# 64834                               KIND : Double defn.        False
# 64844   TEE : Double defn: 1st: The letter “t” with w...       False
# 64853                               CAST : Double defn.        False
# 64868   PRONOUNCED A double definition, and the major...       False
#
#        is_homophone  is_double
# 3             False       True
# 5             False       True
# 31            False       True
# 41            False       True
# 95            False       True
# 121           False       True
# 141           False       True
# 166           False       True
# 180           False       True
# 198           False       True
# 225           False       True
# 241           False       True
# 273           False       True
# 300           False       True
# 320           False       True
# 322           False       True
# 366           False       True
# 375           False       True
# 377           False       True
# 389           False       True
# 390           False       True
# 426           False       True
# 455           False       True
# 477           False       True
# 492           False       True
# 509           False       True
# 514           False       True
# 533           False       True
# 549           False       True
# 553           False       True
# ...             ...        ...
# 64356         False       True
# 64366         False       True
# 64372         False       True
# 64395         False       True
# 64408         False       True
# 64498         False       True
# 64504         False       True
# 64511         False       True
# 64525         False       True
# 64574         False       True
# 64577         False       True
# 64583         False       True
# 64585         False       True
# 64591         False       True
# 64595         False       True
# 64598         False       True
# 64599         False       True
# 64619         False       True
# 64621         False       True
# 64754         False       True
# 64761         False       True
# 64779         False       True
# 64802         False       True
# 64811         False       True
# 64827         False       True
# 64832         False       True
# 64834         False       True
# 64844         False       True
# 64853         False       True
# 64868         False       True
#
# [3848 rows x 5 columns]

# %%
df['is_cryptic'] = df['exp'].apply(lambda x:len(re.findall('(cryptic|\scd\s)',x,re.IGNORECASE))>0)

# %%
df[df['is_cryptic']]
# Out:
#                                                     clue  \
# 9                                      Lower numbers (6)
# 55                       Left port with cargo aboard (5)
# 144                      Basically, here in row 15 (2,6)
# 147    Services for caravan wheel in its current cond...
# 212         Place for fuel frequented by students? (4,4)
# 301    Place of worship without tower or spire, not i...
# 323    Scholar of art and law in chairman up for test...
# 365                                    Scottish well (6)
# 367            Where past customs are on the way out (7)
# 521     Channels transmitting material that’s too muc...
# 529                                 “Carry On” films (7)
# 544         Game which only the one behind can win (7,6)
# 676                     They did a stretch in prison (5)
# 679     Where to glide over the surface endlessly wit...
# 695                Unyielding as Left or Right here? (8)
# 699       Fourth, fifth or sixth rage, potentially (4,4)
# 703             Interval that’s between two notes? (4-4)
# 709                           Given light by setter? (6)
# 718                          Pass on way up and down (5)
# 846    Defensive attitude that may once have got Tige...
# 927                          Record of achievement (4,4)
# 948                       No peace till one’s buried (7)
# 950                 Board wanted to get you on board (9)
# 951       Her husband-to-be was a slippery customer (10)
# 955                 Housecoat a stone’s throw away? (10)
# 961                             Make one think again (6)
# 966                              Top-level clearance (8)
# 974            A lodge that’s possibly pre- Roman? (3-3)
# 975    A short La Scala production made her name, app...
# 976    A short La Scala production made her name, app...
# ...                                                  ...
# 63850            Cuts of meat in the refrigerator? (4-9)
# 63854  Measure of cloth put inside appropriate mechan...
# 63856                   Ivy, perhaps, always growing (9)
# 63859                                 Greek starter? (5)
# 63866           Crib clue from Crucible, for example (7)
# 63931                     Poles caught sabre dancing (6)
# 63935                                     Drop iron? (8)
# 63941           Maria might be somewhat moved by us (10)
# 63943  One assisting with O2’s admission procedure? (...
# 63957  Waiters will be irritated by this going forwar...
# 64015  46DRecording featuring revue repeatedly ignori...
# 64046                          A series in dispute (2,5)
# 64136                 Soldier that would take flight (6)
# 64144             Does this suit a gardener’s needs? (5)
# 64156      How to make more from a single recording? (9)
# 64160                            Crusading barrister (7)
# 64200                                   Sand in guts (4)
# 64290  My partner may be set to drive off with a memb...
# 64297      What can help to make children nuisances? (5)
# 64495               Tradesmen get to grips with them (6)
# 64520                                       Play up? (8)
# 64562  Get in line, say, for game across the Thames (...
# 64567    Sunburn for man like the ground to a wheel? (7)
# 64574  Rule about little room at first needing scrubb...
# 64800                   Business management course (6,8)
# 64818   Cryptic giant having joined Times – has he? (10)
# 64831    Like Venus de Milo, with no warlike threat? (7)
# 64854  Bit of an exercise, instruction to lift operat...
# 64871       Potential layer in this painting finish? (8)
# 64880  Suspicious transaction with him, a republican?...
#
#                                                      exp  is_anagram  \
# 9       N and ETHER are each a number: N just from N[...       False
# 55      L ADEN. A delightfully simple clue that would...       False
# 144     AT BOTTOM Row 15 is thebottom line 10 Pitcher...       False
# 147     OASIS Cryptic def & O – wheel shape & AS IS –...       False
# 212     Cryptic definition Is it? If so, then I’m not...        True
# 301                   cryptic def (whole clue actually)        False
# 323     ORAL EXAM RA [Royal Academician – scholar of ...       False
# 365                          Not-so-cryptic definition.        False
# 367      Cryptic def., although that ‘are’ feels very...       False
# 521       OVERFLOWS (the clue is a cryptic definition...       False
# 529                           Whole clue cryptic. Neat.        False
# 544      Cryptic def., winner being the last bum-on-s...       False
# 676     RACKS Cryptic definition – RACKS were once us...       False
# 679     SKI SLOPE Cryptic definition – SKIn (surface)...        True
# 695     cryptic def, political stance [Also refers to...       False
# 699     cryptic clue; [GEAR = RAGE*; fourth fifth or ...       False
# 703     cryptic clue – potentially splitting TI and M...       False
# 709     cryptic clue, the sun is a setter (something ...       False
# 718                            cryptic clue, palindrome        False
# 846                                 Cryptic definition.        False
# 927         Cryptic definition, with a pun on “record”.        False
# 948    Cryptic definition, referring to the phrase “b...       False
# 950                                  Cryptic definition        False
# 951    Cryptic definition, referring (rather vaguely)...       False
# 955                                  Cryptic definition        False
# 961                                  Cryptic definition        False
# 966                                  Cryptic definition        False
# 974     AGE-OLD (A LODGE)* (*possibly) 9 Leading lady...        True
# 975     HEAD GIRL Cryptic definition (“upper classes”...       False
# 976     HEAD GIRL Cryptic definition (“upper classes”...        True
# ...                                                  ...         ...
# 63850   COLD-SHOULDERS Definition and cryptic definit...       False
# 63854   PROPELLER An envelope (‘inside’) of ELL (‘mea...       False
# 63856      EVERGREEN Definition and cryptic definition.        False
# 63859   ALPHA Cryptic definition: the first letter of...       False
# 63866   🙂 ANAGRAM : Cryptic defn: “crib clue” is an e...        True
# 63931   CABERS C+(SABRE*) 3. Ageing, as the walrus un...        True
# 63935   DECREASE cdd 9. Admitted as a barrister shout...       False
# 63941   Cryptic Def. The Maria here is not the girl t...       False
# 63943   Cryptic Def. relying on the misdirection of t...       False
# 63957   Interrelated Double def. one of them cryptic-...       False
# 64015   / CD (recording) around RU – Re(V)Ue – ignori...       False
# 64046   AT ISSUE A + TISSUE, as in ‘a tissue of lies’...       False
# 64136   ARCHER : Cryptic defn: An old-time soldier wi...       False
# 64144   SPADE : Cryptic defn. of a gardener’s tool wh...       False
# 64156   RERELEASE : (Not so?) cryptic defn. Reference...       False
# 64160   TEMPLAR : Cryptic defn: A barrister who has c...       False
# 64200   GRIT Double definition. 2. See 25 – See 25 3....       False
# 64290   SHAMPOO A + MP in SHOO. Cryptic definition, a...       False
# 64297   ENNUI Cryptic definition, or &lit, depending ...       False
# 64495   PLIERS (tool with serrated jaws for gripping)...       False
# 64520   Headroom being free area above your head so s...       False
# 64562   KEW BRIDGE KEW [sounds like [say] queue – get...       False
# 64567   TANGENT TAN [sunburn] + GENT [man] – another ...       False
# 64574   CANCELLATION CANON [rule] around [about] CELL...       False
# 64800   TOILET TRAINING : Cryptic defn: “To do one’s ...       False
# 64818   ENIGMATIST : Anagram of(cryptic) [GIANT plus(...        True
# 64831   UNARMED : Cryptic defn: Descriptive of the fa...       False
# 64854   PRESS-UP Definition and cryptic definition, w...       False
# 64871       EGGSHELL Definition and cryptic definition.        False
# 64880   ANTIMONARCHIST (TRANSACTION+HIM*) 17. Said of...        True
#
#        is_homophone  is_double  is_cryptic
# 9             False      False        True
# 55            False      False        True
# 144           False      False        True
# 147           False      False        True
# 212           False      False        True
# 301           False      False        True
# 323           False      False        True
# 365           False      False        True
# 367           False      False        True
# 521           False      False        True
# 529           False      False        True
# 544           False      False        True
# 676           False      False        True
# 679           False      False        True
# 695           False      False        True
# 699           False      False        True
# 703           False      False        True
# 709           False      False        True
# 718           False      False        True
# 846           False      False        True
# 927           False      False        True
# 948           False      False        True
# 950           False      False        True
# 951           False      False        True
# 955           False      False        True
# 961           False      False        True
# 966           False      False        True
# 974           False      False        True
# 975           False      False        True
# 976           False      False        True
# ...             ...        ...         ...
# 63850         False      False        True
# 63854         False      False        True
# 63856         False      False        True
# 63859         False      False        True
# 63866         False      False        True
# 63931         False      False        True
# 63935         False      False        True
# 63941         False      False        True
# 63943         False       True        True
# 63957         False       True        True
# 64015         False      False        True
# 64046         False      False        True
# 64136         False      False        True
# 64144         False      False        True
# 64156         False      False        True
# 64160         False      False        True
# 64200         False       True        True
# 64290         False      False        True
# 64297         False      False        True
# 64495         False      False        True
# 64520         False      False        True
# 64562          True      False        True
# 64567         False      False        True
# 64574         False       True        True
# 64800         False      False        True
# 64818         False      False        True
# 64831         False      False        True
# 64854         False      False        True
# 64871         False      False        True
# 64880         False      False        True
#
# [2239 rows x 6 columns]

# %%
df['is_contain'] = df['exp'].apply(lambda x:len(re.findall('(contain|\sin\s|\saround\s|\sbetween\s|\sinside\s)',x,re.IGNORECASE))>0)

# %%
df[df['is_contain']]
# Out:
#                                                     clue  \
# 1                    HOPEful [times]revealed in song (3)
# 2        Nothing divides the lines – that’s the idea (6)
# 3                                       Blows kisses (6)
# 4      Run at it wildly, picking up speed and winning...
# 5         Member of the Lords backtracking on record (4)
# 6                                Cheese cut & grated (8)
# 11     Did men live sinfully, being intent on wrongdo...
# 15         London landlord that’s facing sentence? (7,6)
# 16     Party embracing a limit on spending from the b...
# 17          No being cryptic and causing problems! (7,2)
# 22        Parisian caught breaking wind in congress? (7)
# 23     Nick loses head in the sack – that’s messed up...
# 33     love almost everything about that one’s sauce (5)
# 36     Half-cut Barnes punches left-wingers? Ruddy qu...
# 37     Variety of glasses that browser should try on (7)
# 38        Bubbly chap game to get blotto around noon (9)
# 39     One steering ship should avoid leading Republi...
# 40     Tenor getting into row about a right crappy pl...
# 42     Unit of beer model-type upset over head of stu...
# 48     Suits initially criticised medal won by those ...
# 53     Broom fashioned in tea-tree or chocolate tree (9)
# 54                   Diseased sheep unknown in pound (5)
# 55                       Left port with cargo aboard (5)
# 56                 Clumsy mistake involving an asset (9)
# 57     What identifies him includes start of petulanc...
# 59      Large part of tomahawk may be unearthed here (5)
# 60     Rock tunes – Dominican initially involved was ...
# 62     junction of routes with lane is spanned by it (5)
# 63     Excludes human agency from boosters misguidedl...
# 65     Nasty nippers, group of six playing around wit...
# ...                                                  ...
# 64821  Tie short procedure covered by plastic surgeon...
# 64825  Office item even more out-of-date quietly inst...
# 64830              Worker less productive after cold (7)
# 64833  After drink and kiss, joiner recalling song in...
# 64836  Lacking time, take land out of production crea...
# 64838         Doctor gin in filthy room? That’s mean (6)
# 64842  There’s assistance here to welcome rerouted fl...
# 64843  Shattered bike racer swallowing tablet – it re...
# 64845            Reduction in size permitted in meat (6)
# 64849  Annoys with criticism, singular, that’s avoida...
# 64850  Urged to reform internally, gone off alcohol, ...
# 64851   French city hotel in area known to clergyman (6)
# 64855                  Hard, Proust, funny old comic (7)
# 64856                     Further Essex traffic jams (5)
# 64857  One-on-one combat taken outside that is, chara...
# 64863         Scent block in the shape of roadworks? (7)
# 64864  Christian hoarding treasure primarily after go...
# 64868                       It’s said to be obvious (10)
# 64873  Something cheeky about capital of Rhodesia, a ...
# 64875  In which one may see Odette boast about the Fr...
# 64876                   Girl cuddling boy in a state (9)
# 64883           Fuss about a single step in a series (5)
# 64885  Provide forceful evidence against the Italian,...
# 64886         Is worried about small son getting pet (6)
# 64890  Around northern tip of region, one state with ...
# 64892  Inordinate praise about favourite hors d’oeuvr...
# 64893                            Use Forster device? (6)
# 64894       Computer image of distressed lamb in hut (9)
# 64895       Trendy types, carollers surrounding wife (8)
# 64896  Jazz fan about to reveal what goes on in night...
#
#                                                      exp  is_anagram  \
# 1       W 21 OHM’S LAW [Criminal] {WHO WAS L (left)}*...       False
# 2       O (Nothing) between (divides) THE and RY (lin...       False
# 3       Double Definition. First one in to give a use...       False
# 4        MPH (speed) inside (RUN AT IT)* AInd: wildly...        True
# 5       RE (on) EP (reord) all reversed (backtracking...       False
# 6       (AMPERSAN[d] )* AInd: grated.  Last one in. S...        True
# 11      (DID MEN LIVE)* AInd: sinfully 27/28 PUT ONE ...        True
# 15      Charade: CAPITAL (London) LETTER (landlord) 7...        True
# 16      A CAP (a limit) inside DO (party). Musical term        False
# 17      Answer as wordplay NO is ON (playing) reverse...       False
# 22                                    (UN + C) in COIL.        False
# 23                                      [n]OTCH in BED.        False
# 33                              ((I + 0) in AL[l]) + 1.        False
# 36                                    [bar]NES in REDS.        False
# 37                                    IE in SPECS. Down        False
# 38                               (CHAP GAME)* around N.         True
# 39      [r]UDDER. 3 COCK-A-HOOP  Bird and a bear goin...       False
# 40                              T. in ((A + R) in LINE.        False
# 42                  S[tudio] in (ALE + Model T Ford).<.        False
# 48      (C[riticised] + OM) in BEES. Reference to par...       False
# 53      *BROOM in THEA (the tea genus). Theobroma is ...       False
# 54      X in BRAY. I was unfamiliar with this word an...       False
# 55      L ADEN. A delightfully simple clue that would...       False
# 56                                      A BOON in BISH.        False
# 57      P(etulance) in HIS ID. 18 MAKAR E.g. McGonaga...       False
# 59      Hidden in “tomahawk”. I’m not sure that this ...       False
# 60      D(ominican) in *TUNES. 28 DE RIGUEUR I’d urge...        True
# 62      Hidden in routes lane. Tesla is a derived SI ...       False
# 63                                    I in *(BOOSTERS).         True
# 65      S in SESTET, with the two parts exchanged. I ...        True
# ...                                                  ...         ...
# 64821   CLIP-ON : LIPO(short for liposuction,procedur...       False
# 64825   STAPLER : STALER(even more out-of-date/old ha...       False
# 64830   CLEANER : C(cold) LEANER(less productive, tho...       False
# 64833   ALEXANDRIA : X(kiss) placed after(after) ALE(...       False
# 64836   SEASIDE : “set aside”(take land out of produc...       False
# 64838   STINGY : Anagram of(doctor) GIN contained in(...        True
# 64842   AIRFIELD : AID(assistance) containing(to welc...        True
# 64843   ICEBREAKER : Anagram of(shattered) BIKE RACER...        True
# 64845   CUTLET : CUT(reduction in size) LET(permitted...       False
# 64849   NEEDLESS : NEEDLES(annoys with criticism) S(s...       False
# 64850   DRUDGERY : Anagram of(to reform) URGED contai...        True
# 64851   PARISH : PARIS(French capital city) H(represe...       False
# 64855   HOTSPUR A charade of H (‘hard’) + OTSPUR, an ...        True
# 64856   EXTRA A hidden answer (‘jams’) in ‘EssEX TRAf...       False
# 64857   DIESEL FUEL An envelope (‘taken outside’) of ...       False
# 64863   COLOGNE An envelope (‘in’) of LOG (‘block’ of...       False
# 64864   AUDITOR A charade (‘after’) of AU (‘gold’) + ...       False
# 64868   PRONOUNCED A double definition, and the major...       False
# 64873   BURMA A charade of an envelope (‘about’) of R...       False
# 64875                         SWAN LAKE (LA in SWANK)+E        False
# 64876                       LOUISIANA LOUISA around IAN        False
# 64883                               STAIR STIR around A        False
# 64885                          MILITATE (IL+IT) in MATE        False
# 64886                  CARESS CARES around S(on) … Down        False
# 64890   WEATHER STATION R in (ONE STATE WITH A*) a bi...        True
# 64892                    APPETISER (PRAISE*) around PET         True
# 64893   EMPLOY EM(forster)+PLOY clever misleading clu...       False
# 64894                          THUMBNAIL (LAMB IN HUT*)         True
# 64895                         SWINGERS SINGERS around W        False
# 64896             CABARET CAT around BARE &lit, perhaps        False
#
#        is_homophone  is_double  is_cryptic  is_contain
# 1             False      False       False        True
# 2             False      False       False        True
# 3             False       True       False        True
# 4             False      False       False        True
# 5             False       True       False        True
# 6             False      False       False        True
# 11            False      False       False        True
# 15            False      False       False        True
# 16            False      False       False        True
# 17            False      False       False        True
# 22            False      False       False        True
# 23            False      False       False        True
# 33            False      False       False        True
# 36            False      False       False        True
# 37            False      False       False        True
# 38            False      False       False        True
# 39            False      False       False        True
# 40            False      False       False        True
# 42            False      False       False        True
# 48            False      False       False        True
# 53            False      False       False        True
# 54            False      False       False        True
# 55            False      False        True        True
# 56            False      False       False        True
# 57            False      False       False        True
# 59            False      False       False        True
# 60            False      False       False        True
# 62            False      False       False        True
# 63            False      False       False        True
# 65            False      False       False        True
# ...             ...        ...         ...         ...
# 64821         False      False       False        True
# 64825         False      False       False        True
# 64830         False      False       False        True
# 64833         False      False       False        True
# 64836         False      False       False        True
# 64838         False      False       False        True
# 64842         False      False       False        True
# 64843         False      False       False        True
# 64845         False      False       False        True
# 64849         False      False       False        True
# 64850         False      False       False        True
# 64851         False      False       False        True
# 64855         False      False       False        True
# 64856         False      False       False        True
# 64857         False      False       False        True
# 64863         False      False       False        True
# 64864          True      False       False        True
# 64868         False       True       False        True
# 64873         False      False       False        True
# 64875         False      False       False        True
# 64876         False      False       False        True
# 64883         False      False       False        True
# 64885         False      False       False        True
# 64886         False      False       False        True
# 64890         False      False       False        True
# 64892         False      False       False        True
# 64893         False      False       False        True
# 64894         False      False       False        True
# 64895         False      False       False        True
# 64896         False      False       False        True
#
# [24852 rows x 7 columns]

# %%
df['is_reverse'] = df['exp'].apply(lambda x:len(re.findall('(reverse|<|reversal|return)',x,re.IGNORECASE))>0)

# %%
df[df['is_reverse']]
# Out:
#                                                     clue  \
# 0      Local gild moribunD UNTil [taking some members...
# 5         Member of the Lords backtracking on record (4)
# 8      Those living abroad get help returning, with f...
# 14     Bottoms up, endlessly – that’s the watchword! (5)
# 17          No being cryptic and causing problems! (7,2)
# 30     In Spain, the PM turned on old American model (7)
# 39     One steering ship should avoid leading Republi...
# 42     Unit of beer model-type upset over head of stu...
# 43     Bit of computer kit in the Paris-Dakar rally? ...
# 80        Hat material? Third of sale goes in a rush (5)
# 89          Modules among best in use, on reflection (5)
# 94                    Element about work upset agent (6)
# 99                   Spring up, diving into gift bag (8)
# 103         Self altogether absorbing, on reflection (3)
# 106                     Best reverse narcotic hell (3-3)
# 108                           Marker hit from behind (3)
# 111           Disregard baker’s produce flipped over (4)
# 115              Grass with designs on getting high? (5)
# 136       4D“Sacrifice Green’s head!”: morning piece (6)
# 157                                 Put down face up (4)
# 161                    Fur upset environmental group (6)
# 164    Effigy stuffed with vile contents lit up with ...
# 186               A crazy, upwardly mobile architect (4)
# 195    Find in the morning out of bed retired Argenti...
# 217    Tart before wine recalled by son in Low Countr...
# 221    Comedian’s comeback about posh fellows gets la...
# 228        Fabulous rampant beast described by quote (6)
# 242    Drive back by river in carriage having a cockt...
# 244          Search reservists turning up for battle (6)
# 271    Indian believer is turning up in European capi...
# ...                                                  ...
# 64466       Uncommunicative name brought up in split (8)
# 64490    One has to mind it with dogs and cats about (4)
# 64504     … which might be one if it does this run (4,4)
# 64508  Fat revolutionary loves occupying bit on the s...
# 64514  Put out for the count? It would be mad to get ...
# 64517  We look as though we’re going about a restorat...
# 64554  Is fashionable rearming to take effect under c...
# 64564  Slough disposal is after its first during reve...
# 64575  Language of heart-throb after rise of homework...
# 64587  One unfinished match brought back Eastern visi...
# 64592           Unguents applied to playground kicks (7)
# 64605                      Raising bar in fixed game (6)
# 64615           Brown, on retiring: “Haven’t a clue” (5)
# 64665  Growth on oak’s entirely covered by type of oi...
# 64691                   Jack up smack and senses fly (4)
# 64697                            Spot retreating fox (3)
# 64707  Maybe count number at joint spinning endlessly...
# 64716        Haulier reversed as he removed contents (6)
# 64718                          Yanks open these nuts (8)
# 64760  Being obsessed with self, say nothing about mu...
# 64767    Tone of green state party after eggs tossed (7)
# 64768  Like a satellite operated by universal line as...
# 64780  LIke mechanical man traced back from Martucci ...
# 64793  Much desire for wealth upset European Commissi...
# 64816  Turning up piece from Madonna, Mel B only gets...
# 64819  Fostered one put stone finally in giant-killin...
# 64833  After drink and kiss, joiner recalling song in...
# 64857  One-on-one combat taken outside that is, chara...
# 64878            Cat, say, brought back after search (7)
# 64891              Chief magistrate upset about demo (7)
#
#                                                      exp  is_anagram  \
# 0       E 14 NELIS Fruit that’s PENSILE* [rotted] [wi...       False
# 5       RE (on) EP (reord) all reversed (backtracking...       False
# 8       AID< (help, returning) first letters S P O R ...       False
# 14                                      [b]OTTOM[s] < 6/       False
# 17      Answer as wordplay NO is ON (playing) reverse...       False
# 30                           (EL + PM)< after (EX + A).        False
# 39      [r]UDDER. 3 COCK-A-HOOP  Bird and a bear goin...       False
# 42                  S[tudio] in (ALE + Model T Ford).<.        False
# 43      The rally being an example of a DRIVE that is...       False
# 80      L (third letter in saLe) in TULE (a kind of b...        True
# 89      A hidden (‘in’) reversed (‘on reflection’) an...       False
# 94      A charade of C (circa, ‘about’) plus OP (opus...       False
# 99      An envelope (‘diving into’) of APS, a reversa...        True
# 103                     Hidden in reverse of altOGEther        False
# 106              Reverse of POT (narcotic) + PIT (hell)        False
# 108    Reverse of BAT (to hit) Down 1*. HENDR[IX] Old...       False
# 111                                     Reverse of BUNS        False
# 115                          Reverse of DRAWS (designs)        False
# 136     sacrifice / G (first letter, or head, of Gree...       False
# 157         LAID DIAL face reversed “up” in a down clue        False
# 161     OCELOT Reversed ECO & LOT for group. Never kn...       False
# 164     GUILTILY Contents of (v)IL(e) & LIT reversed ...       False
# 186     ADAM A + a reversal [upwardly mobile] of MAD ...       False
# 195     AM (in the morning) + UP (out of bed), togeth...       False
# 217     FLAN (tart) + reversal [recalled] of RED (win...       False
# 221     GUFFAW : Reversal of(…’s comeback) WAG(a come...       False
# 228     EXOTIC : Reversal of(rampant;wild) [ OX(a bea...       False
# 242     MARGARITA : Reversal of(… back) RAM(to drive,...       False
# 244     COMBAT : COMB(to search carefully and systema...       False
# 271     Paris — the European capital — with its ‘is’ ...       False
# ...                                                  ...         ...
# 64466   CITE (name) reversed (brought up; this is a d...       False
# 64490   PETS (dogs and cats) reversed (about) STEP (o...       False
# 64504   DD I think this is a Double Def. One is “run”...        True
# 64508   (NIL O)< loves, reversed inside LANE (ref. Lo...       False
# 64514                                             NUTS<        False
# 64517   A REFIT OR all reversed (RevInd: wheels) Brin...       False
# 64554   to take effect under certain conditions: <[re...       False
# 64564   ECDYSIS IS after D [first letter of disposal]...       False
# 64575   YIDDISH DISH [heart-throb] after reversal [ri...       False
# 64587   MAGI : Reversal of(brought back) [I(Roman num...       False
# 64592   RECOILS : OILS(unguents) placed after(applied...       False
# 64605   TENNIS : Reversal of(raising) [INN(where one ...       False
# 64615                                   DUN (Brown) ON<        False
# 64665     ALL (entirely) contained in (covered by) TU...       False
# 64691   senses S TANG (smack, in the sense of a disti...       False
# 64697        DOT (spot) reversed (retreating) TOD (fox)        False
# 64707   N (number) + ELBOW (joint) excluding W the la...       False
# 64716   Hidden word in (contents) REVERSED AS HE REMO...       False
# 64718   CRACKERS (In the UK we ‘pull crackers’ at Chr...       False
# 64760                EGOMANIAC EG + O + <CAIN around MA        False
# 64767   AVOCADO CA (for the state of California) + DO...       False
# 64768                   LUNAR RAN + U + L, all reversed        False
# 64780   Hidden word in (traced … from) MARTUCCI TO BO...       False
# 64793   All but the last letter of (much) D of GREED ...       False
# 64816   NOBLEMAN : Reversal of(turning up) and hidden...       False
# 64819   NURSELING : [E(last letter,finally of “stone”...       False
# 64833   ALEXANDRIA : X(kiss) placed after(after) ALE(...       False
# 64857   DIESEL FUEL An envelope (‘taken outside’) of ...       False
# 64878                         SCOURGE (EG<) after SCOUR        False
# 64891                               NOMARCH (ON<)+MARCH        False
#
#        is_homophone  is_double  is_cryptic  is_contain  is_reverse
# 0             False      False       False       False        True
# 5             False       True       False        True        True
# 8             False      False       False       False        True
# 14            False      False       False       False        True
# 17            False      False       False        True        True
# 30            False      False       False       False        True
# 39            False      False       False        True        True
# 42            False      False       False        True        True
# 43            False      False       False       False        True
# 80            False      False       False        True        True
# 89            False      False       False        True        True
# 94            False      False       False        True        True
# 99            False      False       False        True        True
# 103           False      False       False        True        True
# 106           False      False       False       False        True
# 108           False      False       False        True        True
# 111           False      False       False       False        True
# 115           False      False       False       False        True
# 136           False      False       False        True        True
# 157           False      False       False        True        True
# 161           False      False       False       False        True
# 164           False      False       False        True        True
# 186           False      False       False       False        True
# 195           False      False       False       False        True
# 217           False      False       False       False        True
# 221           False      False       False        True        True
# 228           False      False       False        True        True
# 242           False      False       False        True        True
# 244           False      False       False        True        True
# 271           False      False       False       False        True
# ...             ...        ...         ...         ...         ...
# 64466         False      False       False        True        True
# 64490         False      False       False       False        True
# 64504         False       True       False        True        True
# 64508         False      False       False        True        True
# 64514         False      False       False       False        True
# 64517         False      False       False       False        True
# 64554         False      False       False        True        True
# 64564         False      False       False        True        True
# 64575         False      False       False       False        True
# 64587         False      False       False       False        True
# 64592         False      False       False        True        True
# 64605         False      False       False        True        True
# 64615         False      False       False       False        True
# 64665         False      False       False        True        True
# 64691         False      False       False        True        True
# 64697         False      False       False       False        True
# 64707         False      False       False       False        True
# 64716         False      False       False        True        True
# 64718         False      False       False        True        True
# 64760         False      False       False        True        True
# 64767         False      False       False       False        True
# 64768         False      False       False       False        True
# 64780         False      False       False        True        True
# 64793         False      False       False        True        True
# 64816         False      False       False        True        True
# 64819         False      False       False        True        True
# 64833         False      False       False        True        True
# 64857         False      False       False        True        True
# 64878         False      False       False       False        True
# 64891         False      False       False       False        True
#
# [5347 rows x 8 columns]

# %%
df['is_alternate'] = df['exp'].apply(lambda x:len(re.findall('(alternate|\salt\s)',x,re.IGNORECASE))>0)

# %%
df[df['is_alternate']]
# Out:
#                                                     clue  \
# 84     Car may well, at regular intervals, move slowl...
# 536                    Pass regularly through school (3)
# 581                   Handles sliced white, a lady’s (6)
# 670        Regular helpings of roast loin sell out (3,2)
# 1423              Mature and frail, peeing regularly (5)
# 1712         Tense cast regularly seen in this place (7)
# 1873   Fear naked golfers regularly get below-par sco...
# 2024                  Winger in a last-minute switch (9)
# 2100            Kiddies regularly team up, in theory (7)
# 3523                        Poem of Frost read aloud (5)
# 3763   Ready for service, nuns gambolled every now an...
# 4841           Pan’s character’s gypsy taking call (6,4)
# 5300   Regular features of culm above leaf-like stem (7)
# 5640         Norse collection needed, say, regularly (4)
# 7302   Regularly appearing, exam days when school’s o...
# 7340   Exams need to be taken regularly and made less...
# 7400                    Key scripture backing change (5)
# 7561    Referring to some numbers Adrian regularly us...
# 7627   Spanish region’s alternately lean, mean, nice ...
# 7732         Regularly sneers at poor old counsellor (6)
# 8163   Vignette, proper text with odd parts missing, ...
# 8296   Occasionally funny and flipping mad? Open the ...
# 8843   Dining out, magnate’s regularly ignored and un...
# 8853   Garlands end regularly abandoned in different ...
# 9858   Vehicle that carries regular team and another (4)
# 9869              Craving for flour — is it regular? (4)
# 9880              Regulars leaving GI’s army by foot (4)
# 10494                   Regularly looks at TV series (4)
# 10518  Inflammation affected penis? It hurt, on and o...
# 10814                         Substituteevery second (9)
# ...                                                  ...
# 42724            Regularly spanks this Hindu goddess (5)
# 43120      Man in France I see regularly in Verviers (6)
# 44261   In arcade, alternately bought and sold goods (5)
# 44570  Road trips Elaine and Mary alternately take to...
# 44870  Braindead oddly screened in British Library – ...
# 45267             Power to seize key American bank (4,4)
# 45415                             Love birds, idiots (5)
# 45774  Starbuck’s boss‘s regular withdrawals of cash,...
# 48951  34AGlaswegian bird is evil now and again with ...
# 49232  tiny bit sweet, hard to swallow: alternately a...
# 49581         Ambassador key to Hungary’s well being (6)
# 49875  Regular features of the grim academic session (4)
# 50514               This pot some occasionally steal (6)
# 50958  Device making regulars out of guards’ great ar...
# 51365               Aura of game on public transport (6)
# 52102       Regulars turning in quiz a drunk climber (5)
# 52584               3DSeaweed seconds from open reef (3)
# 52940                 Regularly praises exam success (4)
# 55915   Rider starts to holler at Gran, ‘Pull over!’ (7)
# 57100  Bit of kitchen equipment just being still at r...
# 57337  Peppered throughout, crucial in that Indian si...
# 57703  With inquiring expression, insert key to revea...
# 57899  Regularly spout spiteful gossip, reactionary a...
# 58036  Disputed editors cutting things like this, occ...
# 59850  Bookmakers work in them risk picking the odds (7)
# 61298      10.Old poet’s passed by a grove regularly (4)
# 61791      27AFrozen hands regularly in Alpine winds (6)
# 63264      Alternately lance and drain noisome boils (4)
# 63267  Volunteer soldier, one who endeavours to prote...
# 63607  25AGrimly, threat united rally every now and t...
#
#                                                      exp  is_anagram  \
# 84      Alternate letters (‘at regular intervals’) of...       False
# 536                      Alternate letters of ‘sChOoL’.        False
# 581    Alternate letters (indicated by “sliced”) of W...       False
# 670     RAT ON Alternate or ‘regular’ letters in RoAs...       False
# 1423                  alternate letters of fRaIl PeEiNg        False
# 1712    THEATRE T (tense) plus cAsT (alternate or ‘re...       False
# 1873    fEAr (naked, without end letters) GoLfErS(reg...       False
# 2024    ALTERNATE TERN (winger) in A + LATE (last min...       False
# 2100    IDEALLY Alternate letters of [k]I[d]D[i]Es + ...       False
# 3523    Homophone (read aloud) of RIME. ‘Rime’, in ca...       False
# 3763         USABLE Alternate letters of nUnS gAmBoLlEd        False
# 4841    TINKER (gypsy) BELL (call) – another new word...       False
# 5300    (CLADODE). Alternate (regular) letters in “Cu...       False
# 5640   Alternate letters of nEeDeD sAy 7. HAVE A FIT ...       False
# 7302                     Alternate letters of eXaM dAyS        False
# 7340      EASED Alternate letters of E(x)A(m)S (n)E(e)D        False
# 7400       Alt (on keyboard) + R(eligious) E(ducation)<        False
# 7561    ORDINAL ADrIaN (alternate or ‘regular’ letter...       False
# 7627           alternate letters of LeAm MeAn NiCe HeAd        False
# 7732    Alternate letters (‘regularly’) of ‘sNeErSaT ...       False
# 8163    Read into that what you will, it’s alternate ...       False
# 8296    / UN (occasional/alternate letters of ‘fUnNy’...       False
# 8843    INDIGNANT It’s DINING*out& alternate letters ...       False
# 8853       GRADED Alternate letters of GaRlAnDsEnD Down        False
# 9858   Alternate letters of TeAm + XI (eleven – crick...       False
# 9869   I think this is supposed to be alternate lette...       False
# 9880            alternate letters of “..gI‘s ArMy By..”        False
# 10494    Alternate letters (‘regularly’) of ‘LoOkS aT‘.        False
# 10518   PENIS IT HuRt (off and on, i.e. alternate let...        True
# 10814                       ALTERNATE Double Definition        False
# ...                                                  ...         ...
# 42724   Alternate letters (‘regularly’) of ‘SpAnKsThI...       False
# 43120   A charade of JE (‘in France I’) plus alternat...       False
# 44261                DEALT hidden in arcaDE ALTernately        False
# 44570   St [street, road] anagram of elaine alternate...        True
# 44870   Alternate letters of bRaInDeAd in B(ritish) L...       False
# 45267   SWAY (power) contains (to seize) ALT (key) A ...       False
# 45415           Alt spelling OAFS O (love) AVES (birds)        False
# 45774   Alternate leters (‘regular withdrawls’) of ‘c...       False
# 48951   / alternate letters (now and again) of EvIl, ...       False
# 49232   Ins of LOLIPOP (alternate letters) in MINT (s...       False
# 49581    HE (His Excellency) + ALT (reference ALT key...       False
# 49875   Alternate letters of … ThE gRiM … 5 STATIONER...       False
# 50514   ThIs PoT sOmE (alternate letters) as in walk ...       False
# 50958         Alternate letters from GuArDs’ GrEaT aRmY        False
# 51365   NIM (anold and widespread game, perhaps orig ...       False
# 52102    Alternately reversed in qUiZ a DrUnK.Spotted...       False
# 52584   / alternate letters (every second) from ‘Op(E...       False
# 52940   PASS Alternate letters (‘regularly’) of P[r]A...       False
# 55915    H[oller] A[t] G[ran] DRAG< Ref. to H Rider H...        True
# 57100   UTENSIL Alternate letters of ‘jUsT bEiNg StIl...       False
# 57337    RAITA Alternate letters in cRu{C}iAl In ThAt C        False
# 57703   W (with) + ins of ALT (a key on the keyboard ...       False
# 57899      Alternate letters of sPoUt + reverse of DIRT        False
# 58036   CROSSED SWORDS =”Disputed”. ED[itor]S inside ...       False
# 59850   Alternate letters (‘picking the odds’) of ‘Wo...       False
# 61298   YGOE  Alternate letters of bY a GrOvE. Spense...       False
# 61791   / alternate letters (regularly_ from FrOzEn H...       False
# 63264   ACNE Alternate letters of lAnCe, + outside le...       False
# 63267   TERRIER TRIER round ER 24. “Pardon me!”, I as...       False
# 63607   / DO (t(h)reat) + U (united) + RLY (alternate...       False
#
#        is_homophone  is_double  is_cryptic  is_contain  is_reverse  \
# 84            False      False       False       False       False
# 536           False      False       False       False       False
# 581           False      False       False       False       False
# 670           False      False       False        True       False
# 1423          False      False       False       False       False
# 1712          False      False       False        True       False
# 1873          False      False       False       False       False
# 2024          False      False       False        True       False
# 2100          False      False       False       False       False
# 3523           True      False       False        True       False
# 3763          False      False       False       False       False
# 4841          False      False       False       False       False
# 5300          False      False       False        True       False
# 5640          False      False       False        True       False
# 7302          False      False       False       False       False
# 7340          False      False       False       False       False
# 7400          False      False       False       False        True
# 7561          False      False       False        True       False
# 7627          False      False       False       False       False
# 7732          False      False       False        True       False
# 8163          False      False       False       False       False
# 8296          False      False       False       False       False
# 8843          False      False       False       False       False
# 8853          False      False       False       False       False
# 9858          False      False       False       False       False
# 9869          False      False       False       False       False
# 9880          False      False       False       False       False
# 10494         False      False       False       False       False
# 10518         False      False       False       False       False
# 10814         False       True       False       False       False
# ...             ...        ...         ...         ...         ...
# 42724         False      False       False       False       False
# 43120         False      False       False        True       False
# 44261         False      False       False        True       False
# 44570         False      False       False       False       False
# 44870         False      False       False        True       False
# 45267         False      False       False        True       False
# 45415         False      False       False       False       False
# 45774         False      False       False       False       False
# 48951         False      False       False       False       False
# 49232         False      False       False        True       False
# 49581         False      False       False       False       False
# 49875          True      False       False        True       False
# 50514         False      False       False        True       False
# 50958         False      False       False       False       False
# 51365         False      False       False        True       False
# 52102         False      False       False        True        True
# 52584         False      False       False       False       False
# 52940         False      False       False       False       False
# 55915         False      False       False       False        True
# 57100         False      False       False       False       False
# 57337         False      False       False        True       False
# 57703         False      False       False        True       False
# 57899         False      False       False       False        True
# 58036         False      False       False        True       False
# 59850         False      False       False        True       False
# 61298         False      False       False       False       False
# 61791         False      False       False       False       False
# 63264         False      False       False       False       False
# 63267         False      False       False       False       False
# 63607         False      False       False       False       False
#
#        is_alternate
# 84             True
# 536            True
# 581            True
# 670            True
# 1423           True
# 1712           True
# 1873           True
# 2024           True
# 2100           True
# 3523           True
# 3763           True
# 4841           True
# 5300           True
# 5640           True
# 7302           True
# 7340           True
# 7400           True
# 7561           True
# 7627           True
# 7732           True
# 8163           True
# 8296           True
# 8843           True
# 8853           True
# 9858           True
# 9869           True
# 9880           True
# 10494          True
# 10518          True
# 10814          True
# ...             ...
# 42724          True
# 43120          True
# 44261          True
# 44570          True
# 44870          True
# 45267          True
# 45415          True
# 45774          True
# 48951          True
# 49232          True
# 49581          True
# 49875          True
# 50514          True
# 50958          True
# 51365          True
# 52102          True
# 52584          True
# 52940          True
# 55915          True
# 57100          True
# 57337          True
# 57703          True
# 57899          True
# 58036          True
# 59850          True
# 61298          True
# 61791          True
# 63264          True
# 63267          True
# 63607          True
#
# [132 rows x 9 columns]

# %%
df['is_init'] = df['exp'].apply(lambda x:len(re.findall('((?!^initially)initial|\s\w\(|first letter)',x,re.IGNORECASE))>0)

# %%
df[df['is_init']]
# Out:
#                                                     clue  \
# 3                                       Blows kisses (6)
# 8      Those living abroad get help returning, with f...
# 9                                      Lower numbers (6)
# 17          No being cryptic and causing problems! (7,2)
# 41     Weightlifter’s companion and I might ring last...
# 57     What identifies him includes start of petulanc...
# 60     Rock tunes – Dominican initially involved was ...
# 61         Work on copy of Hockney’s head – a female (5)
# 64          Special production of Cenci, spectacular (6)
# 68     Coffee from the fringes of Colombia after an e...
# 71          Drunk up about a quarter of pint at most (4)
# 82     Device for calculating area covered initially ...
# 83         China, clear about power, ignoring France (9)
# 90      Unpleasant smell, not first to indicate fish (5)
# 114         Out to replace leader, that’s the point! (5)
# 124    9APlan produced by heartless, beastly mother, ...
# 136       4D“Sacrifice Green’s head!”: morning piece (6)
# 149         Wanting pair bagging a couple of Oscars? (4)
# 151    Tease hip Republican with comedy skin piercing...
# 154    Source of iron rule in strictly secular school...
# 159    Big event for sports college, and sound equipm...
# 160                           Get fitter, time drops (5)
# 162      Agent finally managed second class disguise (9)
# 165    Arm policeman with soldiers blocking minor tho...
# 167              Rider cycled here without hard seat (8)
# 168    Beeb’s unending concerts, originally with Henr...
# 221    Comedian’s comeback about posh fellows gets la...
# 224             One is taken in by crafty card sharp (5)
# 230           Cobblers‘ first half own goal was hard (7)
# 237                    Lightweight stroller’s better (7)
# ...                                                  ...
# 64718                          Yanks open these nuts (8)
# 64724                 11APole’s covering bird in oil (5)
# 64728  16AChief accountant upset customer lacking sin...
# 64730             19AWhen star put in fuel for plane (5)
# 64733  26ASaucy calendar displays series of romances (5)
# 64734  31APlain face is very good on shortened 2-iron...
# 64744  8DEmperor follows in something of traditional ...
# 64750  23DSupport cash discount by returning box for ...
# 64755  Endlessly large rocks together with floral rin...
# 64792   First among drummers, Moon cuts it as nutter (5)
# 64798             Investor first annoyed with Merkel (6)
# 64802  In most need of support – the rest of Spain do...
# 64804  Run with last bit of email, cc from Vince Cabl...
# 64807           Daring Charles, say, to take cocaine (4)
# 64808  West covering protest — island to flog French ...
# 64809                Spoiled Tramp’s quiet broadcast (8)
# 64814  The Guardian joining line in the box with elec...
# 64815  At St Paul’s ultimate activist is unravelling ...
# 64816  Turning up piece from Madonna, Mel B only gets...
# 64822  English one who noted stirring Earl Grey at th...
# 64824  Taking lead from Sita, Stoic converted – embra...
# 64825  Office item even more out-of-date quietly inst...
# 64830              Worker less productive after cold (7)
# 64833  After drink and kiss, joiner recalling song in...
# 64840  After resistance, change census area – that al...
# 64843  Shattered bike racer swallowing tablet – it re...
# 64846  Mischievous act in Portugal, giving off bad sm...
# 64849  Annoys with criticism, singular, that’s avoida...
# 64851   French city hotel in area known to clergyman (6)
# 64886         Is worried about small son getting pet (6)
#
#                                                      exp  is_anagram  \
# 3       Double Definition. First one in to give a use...       False
# 8       AID< (help, returning) first letters S P O R ...       False
# 9       N and ETHER are each a number: N just from N[...       False
# 17      Answer as wordplay NO is ON (playing) reverse...       False
# 41      This initially seemed like two definitions, b...       False
# 57      P(etulance) in HIS ID. 18 MAKAR E.g. McGonaga...       False
# 60      D(ominican) in *TUNES. 28 DE RIGUEUR I’d urge...        True
# 61                                      EDIT H(ockney).        False
# 64                                    S(pecial) *CENCI.        False
# 68          A RABI (a spring grain harvest) C(olombi)A.        False
# 71      P (one of four letters, a quarter, in PINT) i...       False
# 82      An envelope (‘in’) of AC (‘AreaCovered initia...       False
# 83      An envelope (‘about’) of [f]ORCE (‘power’ – f...       False
# 90      A subtraction: [s]TENCH (‘unpleasant smell’) ...       False
# 114    WRONG (out) with the first letter changed. I’m...       False
# 124     plan / D(A)_M (general term for an aimal, or ...       False
# 136     sacrifice / G (first letter, or head, of Gree...       False
# 149                   POOR 2 x O(scar) inside PR – pair        False
# 151         HYPODERMIC [HIP R(epublican) COMEDY]*teased        False
# 154     ORE A secular school would have O – zero R(el...       False
# 159     OLYMPICS POLY – college & MICS – sound equipm...       False
# 160                           TRAIN T(ime) & RAIN drops        False
# 162     TRANSFORM End of (agen)T & RAN – managed & S(...        True
# 165     BROADSWORD D(etective) S(ergeant) & W(ith) & ...       False
# 167     DERRIERE RIDER*cycled & a not H(ard) (h)ERE 2...       False
# 168                 BEECH BEE(b) & C(oncerts) & H(enry)        False
# 221     GUFFAW : Reversal of(…’s comeback) WAG(a come...       False
# 224     ACRID : I(Roman numeral for “one”) contained ...        True
# 230     HOGWASH : The 1st letter of(first) “half” + O...       False
# 237     GAMBLER : G(abbrev. for “gram”, a very small ...       False
# ...                                                  ...         ...
# 64718   CRACKERS (In the UK we ‘pull crackers’ at Chr...       False
# 64724                  / OAR (pole) around T(I)T (bird)        False
# 64728   / AC (CA, chief accountant, upset) + C(L)ENT ...       False
# 64730                  / AS (when) around V(E)GA (star)        False
# 64733   / hidden word in sauCY C(A)LEndar 27A T GRAEC...        True
# 64734   / SO (very good) + CLE(E) – shortened CLEEK, ...        True
# 64744                       / I (in) + N(E)RO (emperor)        False
# 64750   / BRA (support) + C(D) (cash discount) + ELET...       False
# 64755   GARLAND *LARG(e), anagrind “rocks”, + AND =”t...        True
# 64792   (D (initial letter of [first among] DRUMMERS ...       False
# 64798   ANGEL (investor, particularly in the world of...       False
# 64802   SAGGIEST : {SIEST(“siesta”,the midday rest th...       False
# 64804   INVULNERABLE : Anagram of(redraft) [RUN + L(l...        True
# 64807   RACY : RAY(someone,say with the name Charles ...       False
# 64808   MADEMOISELLE : MAE(West, buxom actress after ...       False
# 64809   IMPAIRED : I’M(I am,setter is,Tramp is,Tramp’...       False
# 64814   TWELVE : [WE(the Guardian,the paper that’s pu...       False
# 64815   VITAL STATISTICS : Anagram of(unravelling) [A...        True
# 64816   NOBLEMAN : Reversal of(turning up) and hidden...       False
# 64822   ELGAR : Anagram of(stirring) [EARL + G(first ...        True
# 64824   TAOISTIC : Anagram of(converted) ITA{“Sita” m...        True
# 64825   STAPLER : STALER(even more out-of-date/old ha...       False
# 64830   CLEANER : C(cold) LEANER(less productive, tho...       False
# 64833   ALEXANDRIA : X(kiss) placed after(after) ALE(...       False
# 64840   REASSURANCE : Anagram of(change) CENSUS AREA ...        True
# 64843   ICEBREAKER : Anagram of(shattered) BIKE RACER...        True
# 64846   PRANK : P(International Vehicle Registration ...       False
# 64849   NEEDLESS : NEEDLES(annoys with criticism) S(s...       False
# 64851   PARISH : PARIS(French capital city) H(represe...       False
# 64886                  CARESS CARES around S(on) … Down        False
#
#        is_homophone  is_double  is_cryptic  is_contain  is_reverse  \
# 3             False       True       False        True       False
# 8             False      False       False       False        True
# 9             False      False        True       False       False
# 17            False      False       False        True        True
# 41            False       True       False       False       False
# 57            False      False       False        True       False
# 60            False      False       False        True       False
# 61            False      False       False       False       False
# 64            False      False       False       False       False
# 68            False      False       False       False       False
# 71            False      False       False        True       False
# 82            False      False       False        True       False
# 83            False      False       False        True       False
# 90            False      False       False       False       False
# 114           False      False       False        True       False
# 124           False      False       False        True       False
# 136           False      False       False        True        True
# 149           False      False       False        True       False
# 151           False      False       False       False       False
# 154           False      False       False       False       False
# 159            True      False       False       False       False
# 160           False      False       False       False       False
# 162           False      False       False       False       False
# 165           False      False       False        True       False
# 167            True      False       False       False       False
# 168           False      False       False       False       False
# 221           False      False       False        True        True
# 224           False      False       False        True       False
# 230           False      False       False        True       False
# 237           False      False       False       False       False
# ...             ...        ...         ...         ...         ...
# 64718         False      False       False        True        True
# 64724         False      False       False        True       False
# 64728         False      False       False       False       False
# 64730         False      False       False        True       False
# 64733         False      False       False        True       False
# 64734         False      False       False        True       False
# 64744         False      False       False       False       False
# 64750         False      False       False       False       False
# 64755         False      False       False       False       False
# 64792         False      False       False        True       False
# 64798         False      False       False        True       False
# 64802         False       True       False        True       False
# 64804         False      False       False       False       False
# 64807         False      False       False        True       False
# 64808         False      False       False        True       False
# 64809         False      False       False        True       False
# 64814         False      False       False        True       False
# 64815         False      False       False        True       False
# 64816         False      False       False        True        True
# 64822         False      False       False       False       False
# 64824         False      False       False       False       False
# 64825         False      False       False        True       False
# 64830         False      False       False        True       False
# 64833         False      False       False        True        True
# 64840         False      False       False       False       False
# 64843         False      False       False        True       False
# 64846         False      False       False       False       False
# 64849         False      False       False        True       False
# 64851         False      False       False        True       False
# 64886         False      False       False        True       False
#
#        is_alternate  is_init
# 3             False     True
# 8             False     True
# 9             False     True
# 17            False     True
# 41            False     True
# 57            False     True
# 60            False     True
# 61            False     True
# 64            False     True
# 68            False     True
# 71            False     True
# 82            False     True
# 83            False     True
# 90            False     True
# 114           False     True
# 124           False     True
# 136           False     True
# 149           False     True
# 151           False     True
# 154           False     True
# 159           False     True
# 160           False     True
# 162           False     True
# 165           False     True
# 167           False     True
# 168           False     True
# 221           False     True
# 224           False     True
# 230           False     True
# 237           False     True
# ...             ...      ...
# 64718         False     True
# 64724         False     True
# 64728         False     True
# 64730         False     True
# 64733         False     True
# 64734         False     True
# 64744         False     True
# 64750         False     True
# 64755         False     True
# 64792         False     True
# 64798         False     True
# 64802         False     True
# 64804         False     True
# 64807         False     True
# 64808         False     True
# 64809         False     True
# 64814         False     True
# 64815         False     True
# 64816         False     True
# 64822         False     True
# 64824         False     True
# 64825         False     True
# 64830         False     True
# 64833         False     True
# 64840         False     True
# 64843         False     True
# 64846         False     True
# 64849         False     True
# 64851         False     True
# 64886         False     True
#
# [5114 rows x 10 columns]

# %%
df['is_delete'] = df['exp'].apply(lambda x:len(re.findall('(delete|remove|removal|without|exclud|\[\w+\]|minus)',x,re.IGNORECASE))>0)

# %%
df[df['is_delete']]
# Out:
#                                                     clue  \
# 0      Local gild moribunD UNTil [taking some members...
# 1                    HOPEful [times]revealed in song (3)
# 5         Member of the Lords backtracking on record (4)
# 6                                Cheese cut & grated (8)
# 9                                      Lower numbers (6)
# 10        Finally, “Hi ho Silver” before the charge! (4)
# 11     Did men live sinfully, being intent on wrongdo...
# 12     Without question, a route should be organised ...
# 13     Press on, having left the last trio of straggl...
# 14     Bottoms up, endlessly – that’s the watchword! (5)
# 18     For this reason lack of amplification is condu...
# 19     Doctor, can I get the first pair to inject ess...
# 20     Dropped dead while antidote was working? Bothe...
# 23     Nick loses head in the sack – that’s messed up...
# 24     Edward the VIII? A British tyrant half the tim...
# 25     Country stronghold you raid in anger at the fr...
# 26         Parents to tour Rome at first, then here? (5)
# 28     Posh firm near Kent after good tip from Lord S...
# 29     Drinking like a setter? Don’t start panicking!...
# 33     love almost everything about that one’s sauce (5)
# 34      Eats and drinks after ditching wife for date (5)
# 36     Half-cut Barnes punches left-wingers? Ruddy qu...
# 39     One steering ship should avoid leading Republi...
# 42     Unit of beer model-type upset over head of stu...
# 43     Bit of computer kit in the Paris-Dakar rally? ...
# 47     Shaven-headed folk who might who guard The Doo...
# 48     Suits initially criticised medal won by those ...
# 50      One’s certain to do away with royal children (5)
# 83         China, clear about power, ignoring France (9)
# 90      Unpleasant smell, not first to indicate fish (5)
# ...                                                  ...
# 64715              Old cuts of such boiled ganders (5,4)
# 64716        Haulier reversed as he removed contents (6)
# 64719        Haulier restricted by shambolic hold-up (7)
# 64728  16AChief accountant upset customer lacking sin...
# 64731  23AOpinion’s taking in waiter but not starting...
# 64732         24APriest abandons sermonizing in pain (6)
# 64734  31APlain face is very good on shortened 2-iron...
# 64735  35ASoften first of ridges with iron for exampl...
# 64743    7Dleave them animal pickled in formaldehyde (8)
# 64769  One sort of wine’s off, waiter ultimately dese...
# 64778     Not mad about chance one gets to be gloomy (9)
# 64784  Discussed in mischievous way the sea creatures...
# 64786           So vampire might appear as ladybird? (5)
# 64787  Capital or very good deal ruined by incomplete...
# 64789  See 5 See 5 Down [INTERNATIONAL][FUND] 2 Repub...
# 64790                   Delay for debt-ridden sailor (6)
# 64791  Gives support where unemployment benefit is de...
# 64796       Notice nothing in French quarter but me? (8)
# 64797  State worker passed through endless mountain r...
# 64798             Investor first annoyed with Merkel (6)
# 64799       That which brings stillness on the Dart? (6)
# 64802  In most need of support – the rest of Spain do...
# 64804  Run with last bit of email, cc from Vince Cabl...
# 64812                celebrity losing heart for fish (4)
# 64824  Taking lead from Sita, Stoic converted – embra...
# 64836  Lacking time, take land out of production crea...
# 64837  Search for fun the don is misrepresenting? Not...
# 64839               Herb vicar’s uncovered in church (8)
# 64857  One-on-one combat taken outside that is, chara...
# 64862  Archer prize idiot, discard one and many books...
#
#                                                      exp  is_anagram  \
# 0       E 14 NELIS Fruit that’s PENSILE* [rotted] [wi...       False
# 1       W 21 OHM’S LAW [Criminal] {WHO WAS L (left)}*...       False
# 5       RE (on) EP (reord) all reversed (backtracking...       False
# 6       (AMPERSAN[d] )* AInd: grated.  Last one in. S...        True
# 9       N and ETHER are each a number: N just from N[...       False
# 10      AG (silver) before [h]I [h]O I had to look th...       False
# 11      (DID MEN LIVE)* AInd: sinfully 27/28 PUT ONE ...        True
# 12                (A ROUTE Q[uestion])* AInd: organised         True
# 13                     RE (on) PORT (left) [straggl]ERS        False
# 14                                      [b]OTTOM[s] < 6/       False
# 18      ERGO (For this reason) NO MIC (lack of amplif...       False
# 19      (CAN I )* AInd: Doctor, IN[ject]. As seen on ...        True
# 20                   (ANITDOTE – D[ead])* AInd: working         True
# 23                                      [n]OTCH in BED.        False
# 24      A + B + DIC[t]ATOR. I rather liked “half the ...       False
# 25      Acrostic of S[tronghold] Y[ou] R[aid] I[n] A[...       False
# 26                            (PA + MA) touring R[ome].        False
# 28                            G + L[ord] + U + CO + SE.        False
# 29                                          [f]LAPPING.        False
# 33                              ((I + 0) in AL[l]) + 1.        False
# 34                      [w]INES after ditching W for D.        False
# 36                                    [bar]NES in REDS.        False
# 39      [r]UDDER. 3 COCK-A-HOOP  Bird and a bear goin...       False
# 42                  S[tudio] in (ALE + Model T Ford).<.        False
# 43      The rally being an example of a DRIVE that is...       False
# 47                                          [s]ENTRIES.        False
# 48      (C[riticised] + OM) in BEES. Reference to par...       False
# 50                                         IS + SU[r]E.        False
# 83      An envelope (‘about’) of [f]ORCE (‘power’ – f...       False
# 90      A subtraction: [s]TENCH (‘unpleasant smell’) ...       False
# ...                                                  ...         ...
# 64715   1st and 3rd letters (cuts) of SUCH + an anagr...        True
# 64716   Hidden word in (contents) REVERSED AS HE REMO...       False
# 64719   R (restricted – in the context of a film cert...        True
# 64728   / AC (CA, chief accountant, upset) + C(L)ENT ...       False
# 64731   / BET (opinion, as in ‘I bet…’) around (P)ANN...       False
# 64732   / pr(E)ACHING (sermonising) without PR (priest)        False
# 64734   / SO (very good) + CLE(E) – shortened CLEEK, ...        True
# 64735   / R (first of ridges) + ELEm(E)NT – element, ...       False
# 64743   / anag (i.e. pickled) of THE(M) + ANiMAL (wit...        True
# 64769   NOSHERY NO SHER(r)Y, without the last letter ...       False
# 64778   SANE (sound in mind, rational; not mad) conta...       False
# 64784   NAUTILI (sounds like [discussed] NAUGHTILY [i...       False
# 64786   AS + HEN (a female [lady] bird) ASHEN (vampir...       False
# 64787   A (very good) + anagram of (ruined) DEAL + ID...        True
# 64789   (R [Republican] + GENT [man of good birth or ...       False
# 64790   TAR (sailor) contained in (ridden [oppressed ...        True
# 64791   SUBSCRIBES (signs ones names to; gives suppor...       False
# 64796   AD (advertisement; notice) + RIEN (the French...       False
# 64797   ANT (worker) contained in (passed through) AT...       False
# 64798   ANGEL (investor, particularly in the world of...       False
# 64799   CURARE (a paralysing poison [brings stillness...       False
# 64802   SAGGIEST : {SIEST(“siesta”,the midday rest th...       False
# 64804   INVULNERABLE : Anagram of(redraft) [RUN + L(l...        True
# 64812   OPAH : “Oprah” Winfrey,US TV talk show host,c...       False
# 64824   TAOISTIC : Anagram of(converted) ITA{“Sita” m...        True
# 64836   SEASIDE : “set aside”(take land out of produc...       False
# 64837   HEDONISM : Hidden in(not entirely) tHE DON IS...       False
# 64839   BASILICA : BASIL(herb) ICA{“vicar” minus “v” ...       False
# 64857   DIESEL FUEL An envelope (‘taken outside’) of ...       False
# 64862   CUPID A charade of CUP (‘prize’) + ‘id[iot]’,...       False
#
#        is_homophone  is_double  is_cryptic  is_contain  is_reverse  \
# 0             False      False       False       False        True
# 1             False      False       False        True       False
# 5             False       True       False        True        True
# 6             False      False       False        True       False
# 9             False      False        True       False       False
# 10            False      False       False       False       False
# 11            False      False       False        True       False
# 12            False      False       False       False       False
# 13            False      False       False       False       False
# 14            False      False       False       False        True
# 18            False      False       False       False       False
# 19            False      False       False       False       False
# 20            False      False       False       False       False
# 23            False      False       False        True       False
# 24            False      False       False       False       False
# 25            False      False       False       False       False
# 26            False      False       False       False       False
# 28            False      False       False       False       False
# 29            False      False       False       False       False
# 33            False      False       False        True       False
# 34            False      False       False       False       False
# 36            False      False       False        True       False
# 39            False      False       False        True        True
# 42            False      False       False        True        True
# 43            False      False       False       False        True
# 47            False      False       False       False       False
# 48            False      False       False        True       False
# 50            False      False       False       False       False
# 83            False      False       False        True       False
# 90            False      False       False       False       False
# ...             ...        ...         ...         ...         ...
# 64715         False      False       False        True       False
# 64716         False      False       False        True        True
# 64719         False      False       False        True       False
# 64728         False      False       False       False       False
# 64731         False      False       False        True       False
# 64732         False      False       False       False       False
# 64734         False      False       False        True       False
# 64735         False      False       False       False       False
# 64743         False      False       False       False       False
# 64769         False      False       False       False       False
# 64778          True      False       False        True       False
# 64784          True      False       False       False       False
# 64786         False      False       False       False       False
# 64787         False      False       False       False       False
# 64789         False      False       False        True       False
# 64790         False      False       False        True       False
# 64791         False      False       False       False       False
# 64796         False      False       False        True       False
# 64797         False      False       False        True       False
# 64798         False      False       False        True       False
# 64799         False      False       False       False       False
# 64802         False       True       False        True       False
# 64804         False      False       False       False       False
# 64812         False      False       False       False       False
# 64824         False      False       False       False       False
# 64836         False      False       False        True       False
# 64837         False      False       False       False       False
# 64839         False      False       False       False       False
# 64857         False      False       False        True        True
# 64862         False      False       False       False       False
#
#        is_alternate  is_init  is_delete
# 0             False    False       True
# 1             False    False       True
# 5             False    False       True
# 6             False    False       True
# 9             False     True       True
# 10            False    False       True
# 11            False    False       True
# 12            False    False       True
# 13            False    False       True
# 14            False    False       True
# 18            False    False       True
# 19            False    False       True
# 20            False    False       True
# 23            False    False       True
# 24            False    False       True
# 25            False    False       True
# 26            False    False       True
# 28            False    False       True
# 29            False    False       True
# 33            False    False       True
# 34            False    False       True
# 36            False    False       True
# 39            False    False       True
# 42            False    False       True
# 43            False    False       True
# 47            False    False       True
# 48            False    False       True
# 50            False    False       True
# 83            False     True       True
# 90            False     True       True
# ...             ...      ...        ...
# 64715         False    False       True
# 64716         False    False       True
# 64719         False    False       True
# 64728         False     True       True
# 64731         False    False       True
# 64732         False    False       True
# 64734         False     True       True
# 64735         False    False       True
# 64743         False    False       True
# 64769         False    False       True
# 64778         False    False       True
# 64784         False    False       True
# 64786         False    False       True
# 64787         False    False       True
# 64789         False    False       True
# 64790         False    False       True
# 64791         False    False       True
# 64796         False    False       True
# 64797         False    False       True
# 64798         False     True       True
# 64799         False    False       True
# 64802         False     True       True
# 64804         False     True       True
# 64812         False    False       True
# 64824         False     True       True
# 64836         False    False       True
# 64837         False    False       True
# 64839         False    False       True
# 64857         False    False       True
# 64862         False    False       True
#
# [14403 rows x 11 columns]

# %%
df['is_charade'] = df['exp'].apply(lambda x:len(re.findall('(charade|\+|\splus)',x,re.IGNORECASE))>0)

# %%
df[df['is_charade']]
# Out:
#                                                     clue  \
# 15         London landlord that’s facing sentence? (7,6)
# 22        Parisian caught breaking wind in congress? (7)
# 24     Edward the VIII? A British tyrant half the tim...
# 26         Parents to tour Rome at first, then here? (5)
# 28     Posh firm near Kent after good tip from Lord S...
# 30     In Spain, the PM turned on old American model (7)
# 32            Rubbish old git cites is all about me? (9)
# 33     love almost everything about that one’s sauce (5)
# 39     One steering ship should avoid leading Republi...
# 40     Tenor getting into row about a right crappy pl...
# 42     Unit of beer model-type upset over head of stu...
# 43     Bit of computer kit in the Paris-Dakar rally? ...
# 44     Plain rude to mess around with a northern don (9)
# 45     Police head new plan to ask for change in Amer...
# 48     Suits initially criticised medal won by those ...
# 49     Ecstasy Hoskins had with Her Maj and a flapper...
# 50      One’s certain to do away with royal children (5)
# 51                Drug-led artist in crossover style (7)
# 81     Join together in company with drinks before ch...
# 82     Device for calculating area covered initially ...
# 85                       Nobleman unknown in advance (5)
# 86           Reduced number in coastal region by day (9)
# 87     Ridicule inspector and anger people in quarrel...
# 88            Arrogance in memo I’d amended with pen (9)
# 92                           Bold call led by lawyer (6)
# 93          Stealing hearts during match, especially (8)
# 94                    Element about work upset agent (6)
# 96                                    Tea? New range (5)
# 97              Freeze sauce to retain top condition (8)
# 98     Separate northern takeover, in principle, not ...
# ...                                                  ...
# 64835        Motivate at home with religious feature (7)
# 64855                  Hard, Proust, funny old comic (7)
# 64857  One-on-one combat taken outside that is, chara...
# 64858    Making sweet love in windy act, ruing gas (5-7)
# 64859          Hitler had a little one — thanks mum! (4)
# 64860             Formerpresident, wee thing shaken (10)
# 64861  Flying reptile, frightening thing with lots of...
# 64862  Archer prize idiot, discard one and many books...
# 64864  Christian hoarding treasure primarily after go...
# 64866  Fish and snake on the road, one sliding down t...
# 64867          Southern African’s sexy figure, baby! (9)
# 64870  Iodine thus something to discuss regarding sim...
# 64872  Weak character from outer space, a Klingon, as...
# 64873  Something cheeky about capital of Rhodesia, a ...
# 64874  Lying down in middle of boulevard after drink (6)
# 64875  In which one may see Odette boast about the Fr...
# 64877                      Clear away thatch aloft (3,2)
# 64879   Hornblower’s short speech after end of clash (7)
# 64880  Suspicious transaction with him, a republican?...
# 64881         Drank one given by doctor, one by bunk (7)
# 64882  Court finally presented with motive for act of...
# 64884  Complete change of opinion concerning fellow e...
# 64885  Provide forceful evidence against the Italian,...
# 64887                Willy Loman? Name lass involved (8)
# 64888                   Roman god in place, cast out (5)
# 64889                 Quack remedy in no way unusual (7)
# 64891              Chief magistrate upset about demo (7)
# 64893                            Use Forster device? (6)
# 64897      Choose artist showing a complex character (7)
# 64898           Turn down quantity of Chinese food (3,3)
#
#                                                      exp  is_anagram  \
# 15      Charade: CAPITAL (London) LETTER (landlord) 7...        True
# 22                                    (UN + C) in COIL.        False
# 24      A + B + DIC[t]ATOR. I rather liked “half the ...       False
# 26                            (PA + MA) touring R[ome].        False
# 28                            G + L[ord] + U + CO + SE.        False
# 30                           (EL + PM)< after (EX + A).        False
# 32                          Anagram of (O + GIT CITES).         True
# 33                              ((I + 0) in AL[l]) + 1.        False
# 39      [r]UDDER. 3 COCK-A-HOOP  Bird and a bear goin...       False
# 40                              T. in ((A + R) in LINE.        False
# 42                  S[tudio] in (ALE + Model T Ford).<.        False
# 43      The rally being an example of a DRIVE that is...       False
# 44                     Anagram of (RUDE + A + N + DON).         True
# 45                        Anagram of (HEAD + N + PLAN).         True
# 48      (C[riticised] + OM) in BEES. Reference to par...       False
# 49                                        E + I‘D + ER.        False
# 50                                         IS + SU[r]E.        False
# 51                           A charade of BHANG and RA.        False
# 81      A charade of CO (‘company’) plus ALES (‘drink...       False
# 82      An envelope (‘in’) of AC (‘AreaCovered initia...       False
# 85      A charade of EARL (‘nobleman’) plus Y (mathem...       False
# 86      An envelope (‘in’) of TEN (‘number’) in SHORE...       False
# 87      A charade of DI (Detective ‘Inspector’) plus ...       False
# 88      A charade of IMMODE, an anagram (‘amended’) o...        True
# 92      A charade of DA (District Attorney, American ...       False
# 93      An envelope (‘during’) of H (‘hearts’ in card...       False
# 94      A charade of C (circa, ‘about’) plus OP (opus...       False
# 96      A charade of CHAI (‘tea’) plus N (‘new’). A v...       False
# 97      An envelope (‘to retain’) of LID (‘top’) plus...       False
# 98      An envelope (‘in’) of N (‘northern’) plus COU...       False
# ...                                                  ...         ...
# 64835   INSPIRE : IN(at home and not out) plus(with) ...       False
# 64855   HOTSPUR A charade of H (‘hard’) + OTSPUR, an ...        True
# 64857   DIESEL FUEL An envelope (‘taken outside’) of ...       False
# 64858   SUGAR-COATING An anagram (‘windy’) of O (‘lov...        True
# 64859   TASH A charade of TA (‘thanks’) + SH (‘mum’)....       False
# 64860   TAMBOURINE A charade of TAMBO (Oliver Reginal...       False
# 64861   PTEROSAUR 13 is PRONOUNCED, and this is the f...       False
# 64862   CUPID A charade of CUP (‘prize’) + ‘id[iot]’,...       False
# 64864   AUDITOR A charade (‘after’) of AU (‘gold’) + ...       False
# 64866   SKATEBOARD A charade of SKATE (‘fish’) + BOA ...       False
# 64867   HOTTENTOT A charade of HOT (‘sexy’) + TEN (‘f...       False
# 64870   ISOTOPIC A charade of I (‘iodine’, chemical s...       False
# 64872   LIMPET A charade of LIMP (‘weak’) + ET (‘char...       False
# 64873   BURMA A charade of an envelope (‘about’) of R...       False
# 64874               SUPINE (IN+(boul)E(vard)) after SUP        False
# 64875                         SWAN LAKE (LA in SWANK)+E        False
# 64877                       MOP UP MOP(hair, thatch)+UP        False
# 64879         HORATIO (clas)H+ORATIO Horatio Hornblower        False
# 64880   ANTIMONARCHIST (TRANSACTION+HIM*) 17. Said of...        True
# 64881                                IMBIBED I+MB+I+BED        False
# 64882                            TREASON (cour)T+REASON        False
# 64884                            ABOUT-FACE ABOUT+F+ACE        False
# 64885                          MILITATE (IL+IT) in MATE        False
# 64887                             SALESMAN (NAME+LASS*)         True
# 64888                                   PLUTO PL+(OUT*)         True
# 64889                                 NOSTRUM NO+ST+RUM        False
# 64891                               NOMARCH (ON<)+MARCH        False
# 64893   EMPLOY EM(forster)+PLOY clever misleading clu...       False
# 64897                                  ELECTRA ELECT+RA        False
# 64898                                   DIM SUM DIM+SUM        False
#
#        is_homophone  is_double  is_cryptic  is_contain  is_reverse  \
# 15            False      False       False        True       False
# 22            False      False       False        True       False
# 24            False      False       False       False       False
# 26            False      False       False       False       False
# 28            False      False       False       False       False
# 30            False      False       False       False        True
# 32            False      False       False       False       False
# 33            False      False       False        True       False
# 39            False      False       False        True        True
# 40            False      False       False        True       False
# 42            False      False       False        True        True
# 43            False      False       False       False        True
# 44            False      False       False       False       False
# 45            False      False       False       False       False
# 48            False      False       False        True       False
# 49            False      False       False       False       False
# 50            False      False       False       False       False
# 51            False      False       False       False       False
# 81            False      False       False       False       False
# 82            False      False       False        True       False
# 85            False      False       False       False       False
# 86            False      False       False        True       False
# 87            False      False       False        True       False
# 88            False      False       False       False       False
# 92            False      False       False       False       False
# 93            False      False       False        True       False
# 94            False      False       False        True        True
# 96            False      False       False       False       False
# 97            False      False       False        True       False
# 98            False      False       False        True       False
# ...             ...        ...         ...         ...         ...
# 64835         False      False       False       False       False
# 64855         False      False       False        True       False
# 64857         False      False       False        True        True
# 64858         False      False       False       False       False
# 64859         False      False       False       False       False
# 64860         False      False       False       False       False
# 64861          True      False       False       False       False
# 64862         False      False       False       False       False
# 64864          True      False       False        True       False
# 64866          True      False       False       False       False
# 64867          True      False       False       False       False
# 64870         False      False       False       False       False
# 64872          True      False       False       False       False
# 64873         False      False       False        True       False
# 64874         False      False       False       False       False
# 64875         False      False       False        True       False
# 64877         False      False       False       False       False
# 64879         False      False       False       False       False
# 64880         False      False        True       False       False
# 64881         False      False       False       False       False
# 64882         False      False       False       False       False
# 64884         False      False       False       False       False
# 64885         False      False       False        True       False
# 64887         False      False       False       False       False
# 64888         False      False       False       False       False
# 64889         False      False       False       False       False
# 64891         False      False       False       False        True
# 64893         False      False       False        True       False
# 64897         False      False       False       False       False
# 64898         False      False       False       False       False
#
#        is_alternate  is_init  is_delete  is_charade
# 15            False    False      False        True
# 22            False    False      False        True
# 24            False    False       True        True
# 26            False    False       True        True
# 28            False    False       True        True
# 30            False    False      False        True
# 32            False    False      False        True
# 33            False    False       True        True
# 39            False    False       True        True
# 40            False    False      False        True
# 42            False    False       True        True
# 43            False    False       True        True
# 44            False    False      False        True
# 45            False    False      False        True
# 48            False    False       True        True
# 49            False    False      False        True
# 50            False    False       True        True
# 51            False    False      False        True
# 81            False    False      False        True
# 82            False     True      False        True
# 85            False    False      False        True
# 86            False    False      False        True
# 87            False    False      False        True
# 88            False    False      False        True
# 92            False    False      False        True
# 93            False    False      False        True
# 94            False    False      False        True
# 96            False    False      False        True
# 97            False    False      False        True
# 98            False    False       True        True
# ...             ...      ...        ...         ...
# 64835         False    False      False        True
# 64855         False    False      False        True
# 64857         False    False       True        True
# 64858         False    False      False        True
# 64859         False    False      False        True
# 64860         False    False      False        True
# 64861         False    False      False        True
# 64862         False    False       True        True
# 64864         False    False      False        True
# 64866         False    False      False        True
# 64867         False    False      False        True
# 64870         False    False      False        True
# 64872         False    False      False        True
# 64873         False    False      False        True
# 64874         False    False      False        True
# 64875         False    False      False        True
# 64877         False    False      False        True
# 64879         False    False      False        True
# 64880         False    False      False        True
# 64881         False    False      False        True
# 64882         False    False      False        True
# 64884         False    False      False        True
# 64885         False    False      False        True
# 64887         False    False      False        True
# 64888         False    False      False        True
# 64889         False    False      False        True
# 64891         False    False      False        True
# 64893         False    False      False        True
# 64897         False    False      False        True
# 64898         False    False      False        True
#
# [19262 rows x 12 columns]

# %%
df['is_&lit'] = df['exp'].apply(lambda x:len(re.findall('(&lit|\slit\s)',x,re.IGNORECASE))>0)

# %%
df[df['is_&lit']]
# Out:
#                                                     clue  \
# 139    9Dwarning that has Tory rebels going their sep...
# 156                 Chap engaged in ogling? Not half (6)
# 164    Effigy stuffed with vile contents lit up with ...
# 210    What could be suitable behind plug with leads ...
# 265    This is certain to be encompassed by interpret...
# 490                   What may cause traumas at sea? (7)
# 556                  Milled grain for a bloomer, say (9)
# 727        Popeye’s tip: his can supply contains it? (7)
# 838                          figure turns — on this? (4)
# 852     Chaser possibly? I’m not sure one’s a hunter (8)
# 884        One settling beside Zulu, east of Namibia (5)
# 903                France’s term for bumbling Boris? (6)
# 976    A short La Scala production made her name, app...
# 1005   Prehistoric structures, rough old pieces with ...
# 1007   Excellent person to have because he made a blo...
# 1218                 What might confuse AA seller? (4,4)
# 1516          Who could give us mirth, nothing more? (8)
# 1662   Sparkler perhaps lit near warm campfire, final...
# 1680    Sight somewhat grotesque, yes, or execrable? (7)
# 1770   10AQuietly encourage the removal of undesirabl...
# 1795       One not very good picking up runs? Hardly (7)
# 1833            Hybrid bulbel the Spanish introduced (8)
# 2035           Partiality gets me in post improperly (8)
# 2378                      Adult with two 14s around? (3)
# 2387                Somewhat posh? A topper, perhaps (3)
# 2393                           Nearly time to crash? (9)
# 2507   Our close relations suffering or ill, as to fi...
# 2667                          Can over go west here? (4)
# 2688                  Guardian nursing river country (5)
# 2745                   Serious language may limit it (5)
# ...                                                  ...
# 63083      He’s at home among celery and fennel tops (4)
# 63191      Rampant hallucinations about squiffy bird (5)
# 63201                      Turn to block some water? (6)
# 63259  Tempestuous at heart, I’m about to preside ove...
# 63273  Inflammation primarily found in maternal breas...
# 63630  10Aplace to throw ends of Lambert and Butler a...
# 63637            21AIt’s edible part of cabbage leaf (5)
# 63638  24AConservative bringing in a Liberal – it lea...
# 63643  3DWas ruminant holding up rest essentially lef...
# 63647  14DIt might protect bay where the going’s soft...
# 63649  18DUniversities are rivals on paper before Ham...
# 63776  Origin of creation heralds appearance of stars...
# 63886    Leaders in crime and probably other spheres (5)
# 64207  Menus on the table virtually absurd, into hyst...
# 64209  Point taken by smallest in litter? Nothing to ...
# 64234  Policymaker ultimately following tough course (9)
# 64235                   One sporting frightful horn? (5)
# 64286  27A 13DOrganisms flourishing on best air, pump...
# 64297      What can help to make children nuisances? (5)
# 64401                What could make one lie square? (9)
# 64502         Rules on air that smoker will resent (3,3)
# 64520                                       Play up? (8)
# 64579   What’ll stop you receiving advert for organ? (7)
# 64762            Where 5 10 is unable to be made out (6)
# 64794        Very complacent or misguidedidealists (4-9)
# 64802  In most need of support – the rest of Spain do...
# 64818   Cryptic giant having joined Times – has he? (10)
# 64842  There’s assistance here to welcome rerouted fl...
# 64844                 Tiger starts with it of course (3)
# 64896  Jazz fan about to reveal what goes on in night...
#
#                                                      exp  is_anagram  \
# 139     &lit-ish/CD/charade?! / When the DIVISION BEL...        True
# 156     LECHER Half of CH(ap) inside LEER &lit I gues...       False
# 164     GUILTILY Contents of (v)IL(e) & LIT reversed ...       False
# 210     APT (suitable) following AD (plug), then the ...       False
# 265                              sure in (idle)*, &lit.         True
# 490    TRAUMAS* &lit – sumatra is a “short violent sq...       False
# 556    CORN (milled grain) + homophone of “flower”, &...       False
# 727    P[opeye] in (HIS CAN)* &lit, where “supply” = ...        True
# 838                    A SIX (rev). Another & lit clue.        False
# 852     *CHASER, ER (I’m not sure). A third & lit clue.        False
# 884     / &lit-ish? SWA (South West Africa, aka Namib...       False
# 903     / &lit-ish again? ROSBI (anag, i.e. bumbling,...        True
# 976     HEAD GIRL Cryptic definition (“upper classes”...        True
# 1005     &lit. Old* + men (chess pieces) + s[tonehenge]        False
# 1007     Beaut around for(=because). The Beaufort sca...        True
# 1218    anagram (what might confuse) of AA SELLER – d...        True
# 1516                               (us mirth 0)*, &lit.         True
# 1662    Anagram (flickering) of LIT NEAR WARM [campfi...        True
# 1680                                  Hidden word &lit.        False
# 1770    the removal of undesirables / P (piano, quiet...        True
# 1795    BRADMAN BAD MAN = “One not very good” around ...       False
# 1833    BLUEBELL – an anagram (hybrid) of BULBEL arou...        True
# 2035          NEPOTISM *(ME IN POST) *(improperly) &lit         True
# 2378   A between two D[aughters], &lit, with a questi...       False
# 2387                      Hidden in posH A Topper, &lit        False
# 2393   NIGH + T + FALL, &lit – “crash” as in “crash o...       False
# 2507    Hidden word but I do not understand what purp...        True
# 2667    OVAL (LAV (can, toilet) + O (over))< (go west...       False
# 2688   R in US (Guardian) + U[nited] S[tates]. Either...        True
# 2745               &lit; hidden in “seriouS LANGuage..”        False
# ...                                                  ...         ...
# 63083   CHEF An envelope (‘among’) of ‘he’ in C + F (...       False
# 63191   (DTS [delirium tremens; hallucinations] conta...        True
# 63201   SPIGOT : GO(turn, as in what players in a gam...       False
# 63259   MISRULE (Tempe)S(tuous) IM, reversed, +RULE 1...       False
# 63273   MASTITIS MA’S TITIS 😆 + &lit Apologies, I ori...       False
# 63630   &lit / A SHY (a place to throw), containing T...       False
# 63637   &lit/it’s edible / hidden word in cabBAGE Lea...       False
# 63638   &lit (and some!) / CON (Conservative) around ...       False
# 63643   Left alone / ES (rESt, essentially) + CHEWED ...        True
# 63647   &lit-ish/double defn-ish/ A DAMP (race)COURSE...       False
# 63649   &lit/Universities / OX (noughts and crosses, ...       False
# 63776   CHAOS Initial letters (‘origin’?; the plural ...       False
# 63886   First letters of (leaders in) CRIME AND PROBA...       False
# 64207   HESTON BLUMENTHAL An envelope (‘into’) of EST...        True
# 64209             THEREUNTO E in THE RUNT + O, AND &lit        False
# 64234   HARD (tough) + LINE (course) + last letter (u...       False
# 64235   I (one) contained in (sporting) an anagram of...        True
# 64286   &lit-ish, organisms (dependent on oxygen to l...        True
# 64297   ENNUI Cryptic definition, or &lit, depending ...       False
# 64401                      EQUALISER (LIE SQUARE*) &lit         True
# 64502   Homophone “Syntax” (rules on air) and &Lit. I...       False
# 64520   Headroom being free area above your head so s...       False
# 64579   EARPLUG : PLUG(advertisement) placed after(fo...       False
# 64762                           NEBULA *UNABLE, + &lit?        False
# 64794   Anagram of (misguided) EFSF IDEALISTS (EFSF i...        True
# 64802   SAGGIEST : {SIEST(“siesta”,the midday rest th...       False
# 64818   ENIGMATIST : Anagram of(cryptic) [GIANT plus(...        True
# 64842   AIRFIELD : AID(assistance) containing(to welc...        True
# 64844   TEE : Double defn: 1st: The letter “t” with w...       False
# 64896             CABARET CAT around BARE &lit, perhaps        False
#
#        is_homophone  is_double  is_cryptic  is_contain  is_reverse  \
# 139           False      False       False       False       False
# 156           False      False       False        True       False
# 164           False      False       False        True        True
# 210           False      False       False       False       False
# 265           False      False       False        True       False
# 490           False      False       False       False       False
# 556            True      False       False       False       False
# 727           False      False       False        True       False
# 838           False      False       False       False       False
# 852           False      False       False       False       False
# 884           False      False       False       False       False
# 903           False      False       False       False       False
# 976           False      False        True       False       False
# 1005          False      False       False       False       False
# 1007          False      False       False        True       False
# 1218          False      False       False       False       False
# 1516          False      False       False       False       False
# 1662          False      False        True       False       False
# 1680          False      False       False       False       False
# 1770          False      False       False       False       False
# 1795          False      False       False        True       False
# 1833          False      False       False        True       False
# 2035          False      False       False        True       False
# 2378          False      False       False        True       False
# 2387          False      False       False        True       False
# 2393          False      False       False        True       False
# 2507          False      False       False        True       False
# 2667          False      False       False       False        True
# 2688          False      False       False        True       False
# 2745          False      False       False        True       False
# ...             ...        ...         ...         ...         ...
# 63083         False      False       False        True       False
# 63191         False      False       False        True        True
# 63201         False      False       False        True       False
# 63259         False      False       False       False        True
# 63273         False      False       False        True       False
# 63630         False      False       False        True       False
# 63637         False      False       False        True       False
# 63638         False      False       False        True       False
# 63643         False       True       False       False       False
# 63647         False       True       False       False       False
# 63649         False      False       False       False       False
# 63776         False      False       False       False       False
# 63886         False      False       False       False       False
# 64207         False      False       False        True       False
# 64209         False      False       False        True       False
# 64234         False      False       False       False       False
# 64235         False      False       False        True       False
# 64286         False      False       False        True       False
# 64297         False      False        True        True       False
# 64401         False      False       False       False       False
# 64502          True      False       False       False       False
# 64520         False      False        True        True       False
# 64579         False      False       False       False       False
# 64762         False      False       False       False       False
# 64794         False      False       False       False       False
# 64802         False       True       False        True       False
# 64818         False      False        True       False       False
# 64842         False      False       False        True       False
# 64844         False       True       False       False       False
# 64896         False      False       False        True       False
#
#        is_alternate  is_init  is_delete  is_charade  is_&lit
# 139           False    False      False        True     True
# 156           False    False      False       False     True
# 164           False    False      False       False     True
# 210           False    False       True       False     True
# 265           False    False      False       False     True
# 490           False    False      False       False     True
# 556           False    False      False        True     True
# 727           False    False       True       False     True
# 838           False    False      False       False     True
# 852           False    False      False       False     True
# 884           False    False      False        True     True
# 903           False    False      False        True     True
# 976           False    False       True       False     True
# 1005          False    False       True        True     True
# 1007          False    False      False        True     True
# 1218          False    False      False       False     True
# 1516          False    False      False       False     True
# 1662          False    False       True       False     True
# 1680          False    False      False       False     True
# 1770          False    False       True        True     True
# 1795          False    False      False       False     True
# 1833          False    False      False       False     True
# 2035          False    False      False       False     True
# 2378          False    False       True       False     True
# 2387          False    False      False       False     True
# 2393          False    False      False        True     True
# 2507          False    False      False       False     True
# 2667          False    False      False        True     True
# 2688          False    False       True        True     True
# 2745          False    False      False       False     True
# ...             ...      ...        ...         ...      ...
# 63083         False    False      False        True     True
# 63191         False    False      False       False     True
# 63201         False    False      False       False     True
# 63259         False    False      False        True     True
# 63273         False    False      False        True     True
# 63630         False    False      False        True     True
# 63637         False    False      False        True     True
# 63638         False     True      False        True     True
# 63643         False     True       True        True     True
# 63647         False    False      False       False     True
# 63649         False    False      False        True     True
# 63776         False     True      False       False     True
# 63886         False     True      False       False     True
# 64207         False    False       True       False     True
# 64209         False    False      False        True     True
# 64234         False    False      False        True     True
# 64235         False    False      False       False     True
# 64286         False    False      False       False     True
# 64297         False    False      False       False     True
# 64401         False    False      False       False     True
# 64502         False    False      False       False     True
# 64520         False    False      False       False     True
# 64579         False    False      False       False     True
# 64762         False    False      False        True     True
# 64794         False    False      False       False     True
# 64802         False     True       True        True     True
# 64818         False    False      False        True     True
# 64842         False    False      False       False     True
# 64844         False    False      False       False     True
# 64896         False    False      False       False     True
#
# [623 rows x 13 columns]

# %%
df['is_hidden'] = df['exp'].apply(lambda x:len(re.findall('(hidden)',x,re.IGNORECASE))>0)

# %%
df[df['is_hidden']]
# Out:
#                                                     clue  \
# 7           One’s offered hospitality in rogue state (5)
# 59      Large part of tomahawk may be unearthed here (5)
# 62     junction of routes with lane is spanned by it (5)
# 78         This will be imbibed in some do copiously (5)
# 89          Modules among best in use, on reflection (5)
# 103         Self altogether absorbing, on reflection (3)
# 193                   Knowing some nuclear chemistry (4)
# 202                  Exchange airless Wapping houses (4)
# 213                 Fake element among tigers at zoo (6)
# 262    Some European he maligns misguidedly? Little n...
# 327                    Conclusion of some gastronome (5)
# 346    Bit of catarrh on child producing wheezing sou...
# 383            Irate Dane resigned, partly over song (8)
# 422              Regularly attends influential talks (3)
# 435                      Fish filling our Amish nets (7)
# 438    Running up shirt seams to dress top musicians (7)
# 447    Type of dance music found back in drab Baghdad...
# 465    Not all of part is terrible for Folies perform...
# 481    One who’s agreed to meet in Coventry’s terminu...
# 489    Outstanding capital features in Bernini aquati...
# 498    Professional theologian providing some useful ...
# 520     Ugly photograph displays architectural featur...
# 561           Surge observed in chapati — delicious! (4)
# 573                    Trim a slice of bread or naan (5)
# 666     Leaves a bit depressed alas; Des so tired in ...
# 684      Israeli lithograph featuring Talmudic demon (6)
# 700                          Comets, as Haley’s band (4)
# 723    Instrument from a record hidden at either end?...
# 735                   Ring of Fire’s on a television (8)
# 770               Metal block obscuring other houses (5)
# ...                                                  ...
# 64241  Some spectacular urban description? On the con...
# 64256                In Africa, barter over counters (5)
# 64261  Penetrators of the mysteries of origami coming...
# 64297      What can help to make children nuisances? (5)
# 64345  In which to measure land bordered by Acacia Cr...
# 64358  The essence of theism in stern place of worshi...
# 64379                         Supplies some skittles (3)
# 64399  Veteran worried about extremely lazy Goldeneye...
# 64411               Bird exhibited in Science Museum (3)
# 64420       Split occurring in rock group in private (4)
# 64427  Home to let’s part in basis for rapid devlopme...
# 64430          Grant accepted by well-placed entrant (4)
# 64435                Silken textiles must include it (5)
# 64458             Gather group among team assistants (5)
# 64486   It’s found in couples each at endless enmity (4)
# 64509    Love apple core to be spewed out by robots? (6)
# 64510                     Esther Rantzen’s straying! (6)
# 64601              Reason particular guest’s content (5)
# 64641             Quake in the centre – more or less (6)
# 64678      Metal crest’s from unearthed genouilliere (4)
# 64712            Popular Christmas tree stocked here (5)
# 64716        Haulier reversed as he removed contents (6)
# 64733  26ASaucy calendar displays series of romances (5)
# 64780  LIke mechanical man traced back from Martucci ...
# 64801      Even Ali tying involves an act of bribery (8)
# 64816  Turning up piece from Madonna, Mel B only gets...
# 64826  Agree lecturer’s content to choose incumbent? (7)
# 64837  Search for fun the don is misrepresenting? Not...
# 64841                            City in Laos, look! (4)
# 64856                     Further Essex traffic jams (5)
#
#                                                      exp  is_anagram  \
# 7                                   Hidden: roGUE STate        False
# 59      Hidden in “tomahawk”. I’m not sure that this ...       False
# 62      Hidden in routes lane. Tesla is a derived SI ...       False
# 78      Hidden in “some do copiously”. Our second typ...       False
# 89      A hidden (‘in’) reversed (‘on reflection’) an...       False
# 103                     Hidden in reverse of altOGEther        False
# 193                    ARCH Hidden in nucleAR CHemistry        False
# 202             Hidden answer [houses]: airless Wapping        False
# 213     Hidden answer [element among]: tigers at zoo ...       False
# 262     n in (he maligns)* — nice to see ‘some’ witho...        True
# 327                     OMEGA Hidden in sOME GAstronome        False
# 346                  RHONCHI Hidden in catarRH ON CHIld        False
# 383     Hidden reversed/”partly over” in [Irat]E DANE...       False
# 422     {a}t{t}e{n}d{s} — ref. TED talks 31 TICKLING ...       False
# 435     Hidden in fillinG OUR AMIsh, ‘nets’ the inclu...       False
# 438     Hidden rev. in shIRT SEAMs — ‘to dress’ the i...       False
# 447     GABBA : Hidden in reversal of(found back in) ...       False
# 465     ARTISTE : Hidden in(Not all of) “part is terr...       False
# 481                       Hidden in CovenTRY’S TERminus        False
# 489    Hidden in bernINI Aquatints – plural of “inion...       False
# 498                             Hidden in usefUL EMAils        False
# 520       GLYPH (hidden word in [displays] UGLY PHOTO...       False
# 561                        Hidden in chapaTI DE licious        False
# 573    Hidden in breAD OR Naan – the second hidden an...       False
# 666     TOSSED SALAD Hidden (‘a bit’) and reversed (‘...       False
# 684     LILITH Hidden or ‘featured’ in ‘IsraeLI LITHo...       False
# 700                    hidden in “..cometS AS Haleys..”        False
# 723                A LP + H OR N (either end of HiddeN)        False
# 735                    Hidden in fiRE’S ON A TElevision        False
# 770                                         Hidden word        False
# ...                                                  ...         ...
# 64241   Hidden word in (some) SPECTACULAR URBAN rever...       False
# 64256   ABACI Hidden and reversed in “Africa barter”....       False
# 64261                      MAGI Another hidden reverse.        False
# 64297   ENNUI Cryptic definition, or &lit, depending ...       False
# 64345   ACRES A hidden answer (‘bordered by’) in ‘Aca...       False
# 64358   MINSTER A hidden answer (‘the essence of’) in...       False
# 64379                    KIT : Hidden in(some) sKITtles        False
# 64399   TREVELYAN (VETERAN*) around L(az)Y 12. Moiste...        True
# 64411                        EMU hidden: sciencE MUseum        False
# 64420   Hidden word in (in) PRIVATE RIVA (a cleft in ...       False
# 64427   Hidden word in (part in) HOME TO LET’S METOL ...        True
# 64430   Hidden word in (accepted by) WELL_PLACED ENTR...       False
# 64435   Hidden word (include) in SILKEN TEXTILES  KEN...        True
# 64458   Hidden word in (group among) TEAM ASSISTANTS ...       False
# 64486   Hidden word in (it’s found in) EACH AT ENDLES...       False
# 64509   Indirect hidden in auTOMATOns. The central pa...       False
# 64510                          Hidden in EsthER RANTzen        False
# 64601   ARGUE : Hidden in(…’s content) particulAR GUEst        False
# 64641   Hidden word in (in) THE CENTRE MORE OR LESS T...       False
# 64678   metal M Hidden word in (from) UNEARTHED GENOU...       False
# 64712   Hidden word in (stocked here) POPULAR CHRISTM...       False
# 64716   Hidden word in (contents) REVERSED AS HE REMO...       False
# 64733   / hidden word in sauCY C(A)LEndar 27A T GRAEC...        True
# 64780   Hidden word in (traced … from) MARTUCCI TO BO...       False
# 64801     VENALITY : Hidden in(involves) eVEN ALI TYing        False
# 64816   NOBLEMAN : Reversal of(turning up) and hidden...       False
# 64826   REELECT : Hidden in(…’s content) agREE LECTurer        False
# 64837   HEDONISM : Hidden in(not entirely) tHE DON IS...       False
# 64841                    OSLO : Hidden in(in) laOS LOok        False
# 64856   EXTRA A hidden answer (‘jams’) in ‘EssEX TRAf...       False
#
#        is_homophone  is_double  is_cryptic  is_contain  is_reverse  \
# 7             False      False       False       False       False
# 59            False      False       False        True       False
# 62            False      False       False        True       False
# 78            False      False       False        True       False
# 89            False      False       False        True        True
# 103           False      False       False        True        True
# 193           False      False       False        True       False
# 202           False      False       False       False       False
# 213           False      False       False       False       False
# 262           False      False       False        True       False
# 327           False      False       False        True       False
# 346           False      False       False        True       False
# 383           False      False       False        True        True
# 422           False      False       False        True       False
# 435           False      False       False        True       False
# 438           False      False       False        True       False
# 447           False      False       False        True        True
# 465           False      False       False        True       False
# 481           False      False       False        True       False
# 489           False      False       False        True       False
# 498           False      False       False        True       False
# 520           False      False       False        True       False
# 561           False      False       False        True       False
# 573           False      False       False        True       False
# 666           False      False       False        True        True
# 684           False      False       False        True       False
# 700           False      False       False        True       False
# 723           False      False       False       False       False
# 735           False      False       False        True       False
# 770           False      False       False       False       False
# ...             ...        ...         ...         ...         ...
# 64241         False      False       False        True        True
# 64256         False      False       False        True        True
# 64261         False      False       False       False        True
# 64297         False      False        True        True       False
# 64345         False      False       False        True       False
# 64358         False      False       False        True       False
# 64379         False      False       False       False       False
# 64399         False      False       False        True       False
# 64411         False      False       False       False       False
# 64420         False      False       False        True       False
# 64427         False      False       False        True       False
# 64430         False      False       False        True       False
# 64435         False      False       False        True       False
# 64458         False      False       False        True       False
# 64486         False      False       False        True       False
# 64509         False      False       False        True       False
# 64510         False      False       False        True       False
# 64601         False      False       False       False       False
# 64641         False      False       False        True       False
# 64678         False      False       False        True       False
# 64712         False      False       False        True       False
# 64716         False      False       False        True        True
# 64733         False      False       False        True       False
# 64780         False      False       False        True        True
# 64801         False      False       False       False       False
# 64816         False      False       False        True        True
# 64826         False      False       False       False       False
# 64837         False      False       False       False       False
# 64841         False      False       False       False       False
# 64856         False      False       False        True       False
#
#        is_alternate  is_init  is_delete  is_charade  is_&lit  is_hidden
# 7             False    False      False       False    False       True
# 59            False    False      False       False    False       True
# 62            False    False      False       False    False       True
# 78            False    False      False       False    False       True
# 89            False    False      False       False    False       True
# 103           False    False      False       False    False       True
# 193           False    False      False       False    False       True
# 202           False    False       True       False    False       True
# 213           False    False      False       False    False       True
# 262           False    False       True       False    False       True
# 327           False    False      False       False    False       True
# 346           False    False      False       False    False       True
# 383           False    False       True       False    False       True
# 422           False    False      False       False    False       True
# 435           False    False      False       False    False       True
# 438           False    False      False       False    False       True
# 447           False    False      False       False    False       True
# 465           False    False      False       False    False       True
# 481           False    False       True       False    False       True
# 489           False    False      False       False    False       True
# 498           False    False      False       False    False       True
# 520           False    False       True       False    False       True
# 561           False    False      False       False    False       True
# 573           False    False      False       False    False       True
# 666           False    False      False       False    False       True
# 684           False    False      False       False    False       True
# 700           False    False      False       False    False       True
# 723           False    False      False        True    False       True
# 735           False    False      False       False    False       True
# 770           False    False      False       False    False       True
# ...             ...      ...        ...         ...      ...        ...
# 64241         False    False      False       False    False       True
# 64256         False    False      False       False    False       True
# 64261         False    False      False       False    False       True
# 64297         False    False      False       False     True       True
# 64345         False    False      False       False    False       True
# 64358         False    False      False       False    False       True
# 64379         False    False      False       False    False       True
# 64399         False     True      False       False    False       True
# 64411         False    False      False       False    False       True
# 64420         False    False      False       False    False       True
# 64427         False    False      False       False    False       True
# 64430         False    False      False       False    False       True
# 64435         False    False       True       False    False       True
# 64458         False    False      False       False    False       True
# 64486         False    False      False       False    False       True
# 64509         False    False      False       False    False       True
# 64510         False    False      False       False    False       True
# 64601         False    False      False       False    False       True
# 64641         False    False      False       False    False       True
# 64678         False    False      False       False    False       True
# 64712         False    False      False       False    False       True
# 64716         False    False       True       False    False       True
# 64733         False     True      False        True    False       True
# 64780         False    False      False       False    False       True
# 64801         False    False      False       False    False       True
# 64816         False     True      False       False    False       True
# 64826         False    False      False       False    False       True
# 64837         False    False       True       False    False       True
# 64841         False    False      False       False    False       True
# 64856         False    False      False       False    False       True
#
# [1970 rows x 14 columns]

# %%
df['is_spoonerism']  = df['exp'].apply(lambda x:len(re.findall('(spooner)',x,re.IGNORECASE))>0)

# %%
df[df['is_spoonerism']]
# Out:
#                                                     clue  \
# 282    Spooner’s authentic furniture material that ma...
# 371     See 6  Spooner’s conundrum; Greek’s 6th, or 7...
# 568    Spooner’s rascal ran off, getting damper in Au...
# 2084     Act honourably and skin fruit for Spooner (4,4)
# 2398   Wee condoms, perhaps, if emerging from Spooner...
# 3299   Spooner will pester associates who are tycoons...
# 4221    Spooner’s view of fool’s power – that might b...
# 5856    Schoolgirl shows contempt for Spooner and run...
# 6003         Cover over Miss Woodhouse’s predicament (7)
# 6608    Find tiny holes in prison of mine for Spooner...
# 6908   Tinned sort of offal Spooner delivers in barro...
# 7612   Drops to the floor, as does Spooner’s limbo da...
# 9792     Novelist Roald’s 23as narrated by Spooner (7,7)
# 9901           Spooner up for distortion by design (2,7)
# 10249                    Big cat trainer for Spooner (7)
# 10807     Spooner urinated toys in legal documents (4,5)
# 11662  According to Spooner, only that man Francis li...
# 11894  / LOCU-STEIN-CH Spooner’s kept Twin Peaks dire...
# 12001  Spooner’s to come across kind-hearted energy s...
# 13235       Novel storage unit in Spooner’s kitchen? (8)
# 13492  Spooner’s busy wide bay is part of Spanish cul...
# 13600      Gather Julius confesses to being an idiot (5)
# 14651  Parasite was a parliamentary leader, said Spoo...
# 15059  What security-concious Spooner has fitted to f...
# 15148          Beelzebub, one probably now healed? (3,7)
# 15835  Spooner’s minor road excavation on major route...
# 15980                 Spooner’s chief murder weapons (9)
# 16112   Particular person, one that lifts depression,...
# 16861  Adverse reaction caused by Spooner’s need to s...
# 17539          One doubts God is involved in robbery (7)
# ...                                                  ...
# 45193  Spooner’s little song gives room for movement (6)
# 47602                   Self-proclaimed birdwatcher? (7)
# 48133  Spooner’s boxing and running in singularly inc...
# 49121   Uncertain if fluids be suitable for pouring (10)
# 49595            Fighting Spooner’s exploding feline (6)
# 49721  And the consequences when that’s ballsed up? (...
# 49854  Itinerant people, lacking distance learning, t...
# 50179  Spooner’s starting to say joints are a problem...
# 50185           Viz features Spooner’s problem joint (6)
# 50216  Seceding Spooner’s arousing a comment from an ...
# 52099  Rehearsal for card game finished by Spoonerist...
# 52830           Elite Spooner’s drunk after fiasco (3,6)
# 52917  Spooner’s call to girl found among the eucalyp...
# 54220                Restrain Spooner’s drunken rage (8)
# 54454                              Waited to predict (4)
# 54625           Snack, Spooner’s filth of the filth? (7)
# 54829  Arab leader offended by Spooner’s crude arrang...
# 55444                   Promises no unfair wordplay (10)
# 55929   Protective cover for Spooner’s style of hairl...
# 57435         Spooner’s empty room a problem for cat (8)
# 57639   According to Spooner, journalist with sinceri...
# 58281          Warning call from Christian, perhaps? (8)
# 59390  Middle East city where Spooner may help a vehi...
# 61397        Spooner’s pawned pet to get head wear (6,3)
# 61486  Spooner’s fair question leads to polite decept...
# 62337        Source of protein Spooner’s son spotted (7)
# 62804  Spooner’s departed newspaper – Standard for Th...
# 63053  Flier going through to Russian capital after A...
# 63770         Preserve holy one appointed by Spooner (9)
# 64580                    Spooner’s tutor spotted cat (7)
#
#                                                      exp  is_anagram  \
# 282     spoonerism of SOUND (authentic) PINE (furnitu...       False
# 371      To make my day, a Spoonerism of ‘teaser’ (a ...       False
# 568    Spoonerism of “brat fled”. Damper is a kind of...       False
# 2084    PLAY FAIR Spoonerism of flay pear – skin frui...       False
# 2398   Spoonerism of “widdle” (to urinate, wee) “Mate...       False
# 3299    MAGNATES NAG (pester) + MATES (associates) – ...       False
# 4221      MOONLIGHT (a Spoonerism of LOON [fool] + MI...       False
# 5856    DISMISSES A Spoonerism of MISS (schoolgirl) D...       False
# 6003    DILEMMA DIL (lid<) + EMMA (Miss Woodhouse, fr...       False
# 6608    NITPICK A Spoonerism of PIT (mine) NICK (pris...       False
# 6908    Spoonerism of CANNED (tinned) HEART (sort of ...       False
# 7612    a Spoonerism of “gets low” (what a limbo danc...       False
# 9792    a Spoonerism of Dahl’s Chickens (Roald’s 23 a...       False
# 9901                                     *(SPOONER UP).         True
# 10249   Teacher (trainer) turned into Tea cher then s...       False
# 10807   DEED POLLS A Spoonerism of: PEED (urinated) +...       False
# 11662  Spoonerism of “solely he”, and a reference to ...       False
# 11894   / LOCUST FINCH = Spoonerism of FOCUSSED (kept...       False
# 12001   WIND FARM is a written Spoonerism of “find wa...       False
# 13235   BOOKCASE – the Spoonerism being ‘cook base’ (...       False
# 13492   A Spoonerism of FULL (‘busy’) BIGHT (‘wide ba...       False
# 13600   AM ASS (the writer confesses to being an idio...       False
# 14651   Spoonerism of “”lead house” (was a parliament...       False
# 15059    ‘Better locks,’ according to the Rev. Spooner.        False
# 15148   OLD SCRATCH Cryptic definition 25 Spooner’s s...       False
# 15835   Spoonerism of “lane mine” (minor road, excava...       False
# 15980            Spoonerism of BOSS CROWS (murder of..)        False
# 16112   NITPICKER A Spoonerism of PIT (depression) NI...       False
# 16861           spoonerism of LACK (need) BASH (strike)        False
# 17539   If you’re AT a HEIST, you may be “involved in...       False
# ...                                                  ...         ...
# 45193   LEEWAY – a Spoonerism of ‘wee lay’ (little so...       False
# 47602   SPOONER This one made me laugh: a Spoonerism ...       False
# 48133   RIGHT FACE : Spoonerism of “fight”{ the singu...       False
# 49121    (IF FLUIDS BE)*  17 LIE IN WAIT Be ready to ...        True
# 49595    COMBAT (Spoonerism of BOM [sounds like {a Sp...       False
# 49721   (WHEN THAT)* AInd: ballsed up. Last answer. A...        True
# 49854   BED IN : “Bedouin”(nomads;intinerant people i...       False
# 50179   SNEEZE A charade of S (‘Spooner’s starting’) ...       False
# 50185   NAMELY This time the joint is the same, but S...       False
# 50216   BREAKING AWAY : Spoonerism of “raking” “wakin...       False
# 52099   DUMMY RUN : Spoonerism of “rummy”(the card ga...       False
# 52830   Spoonerism of “flop tight”, drunk after fiaso...       False
# 52917   KOALA – Spoonerism of ‘lo Carla’ (call to gir...       False
# 54220          HANDCUFF Spooner might say ‘canned huff’        False
# 54454   BODE : Double defn: 1st: Past tense of “bide”...       False
# 54625   POPCORN Spoonerism of COP PORN, filth being d...       False
# 54829         Makeshift. Spoonerism of “Sheikh miffed”.        False
# 55444   SPOONERISM An anagram (‘unfair’) of ‘promises...        True
# 55929   SUNBONNET A ‘lift and separate’ clue as well ...       False
# 57435   Spooner’s BARE HALL (empty room) for aconcret...       False
# 57639     HACK (journalist) + CANDIDNESS (sincerity) ...       False
# 58281   FORENAME FORE (warning) and CALL (name) 6 Mos...       False
# 59390   KANDAHAR : Spoonerism of “hand”(help, as in “...        True
# 61397        A Spoonerism of HOCKED CAT (‘pawned pet’).        False
# 61486         WHITE LIE A Spoonerism of “light – why?”.        False
# 62337   SOYBEAN A Spoonerism of BOY SEEN (‘son spotte...       False
# 62804   FLED (departed) + RAG (newspaper) Dr William ...       False
# 63053   A (first letter of [capital of] ARMENIA) + VI...       False
# 63770   MARMALADE A Spoonerism of LAMA MADE (‘holy on...       False
# 64580           CHEETAH : Spoonerism of “teacher”,tutor        False
#
#        is_homophone  is_double  is_cryptic  is_contain  is_reverse  \
# 282            True      False       False       False       False
# 371           False      False       False        True       False
# 568           False      False       False        True       False
# 2084          False      False       False       False       False
# 2398          False      False       False       False       False
# 3299          False      False       False       False       False
# 4221          False      False       False       False       False
# 5856          False      False       False       False       False
# 6003          False      False       False       False        True
# 6608          False      False       False       False       False
# 6908          False      False       False        True       False
# 7612          False       True       False       False       False
# 9792          False      False       False       False       False
# 9901          False      False       False       False       False
# 10249         False      False       False       False       False
# 10807         False      False       False       False       False
# 11662         False      False       False       False       False
# 11894         False      False       False       False       False
# 12001         False      False       False       False       False
# 13235         False      False       False       False       False
# 13492         False      False       False       False       False
# 13600         False      False       False       False       False
# 14651         False      False       False       False       False
# 15059         False      False       False       False       False
# 15148         False      False        True       False       False
# 15835         False      False       False       False       False
# 15980         False      False       False       False       False
# 16112         False      False       False       False       False
# 16861         False      False       False       False       False
# 17539         False      False       False        True       False
# ...             ...        ...         ...         ...         ...
# 45193         False      False       False       False       False
# 47602         False      False       False       False       False
# 48133         False      False       False        True       False
# 49121         False      False       False        True       False
# 49595          True      False       False       False       False
# 49721         False      False       False        True       False
# 49854         False      False       False        True       False
# 50179         False      False       False       False       False
# 50185         False      False       False       False       False
# 50216          True      False       False        True       False
# 52099         False      False       False       False       False
# 52830         False      False       False       False       False
# 52917         False      False       False       False       False
# 54220         False      False       False       False       False
# 54454         False       True        True        True        True
# 54625         False      False       False       False       False
# 54829         False      False       False       False       False
# 55444         False      False       False       False       False
# 55929         False      False       False       False       False
# 57435         False      False       False        True       False
# 57639          True      False       False       False       False
# 58281         False      False       False        True       False
# 59390         False      False       False        True       False
# 61397         False      False       False       False       False
# 61486         False      False       False       False       False
# 62337         False      False       False       False       False
# 62804         False      False       False        True       False
# 63053         False      False       False       False       False
# 63770         False      False       False       False       False
# 64580         False      False       False       False       False
#
#        is_alternate  is_init  is_delete  is_charade  is_&lit  is_hidden  \
# 282           False    False      False       False    False      False
# 371           False    False      False        True    False      False
# 568           False    False      False       False    False      False
# 2084          False    False      False       False    False      False
# 2398          False    False      False       False    False      False
# 3299          False    False      False        True    False      False
# 4221          False    False       True        True    False      False
# 5856          False    False      False       False    False      False
# 6003          False    False      False        True    False      False
# 6608          False    False      False       False    False      False
# 6908          False    False      False       False    False      False
# 7612          False    False      False       False    False      False
# 9792          False    False      False       False    False      False
# 9901          False    False      False       False    False      False
# 10249         False    False      False       False    False      False
# 10807         False    False      False        True    False      False
# 11662         False    False      False       False    False      False
# 11894         False    False       True        True    False      False
# 12001         False    False      False       False    False      False
# 13235         False    False      False       False    False      False
# 13492         False    False      False       False    False      False
# 13600         False    False      False       False    False      False
# 14651         False    False      False       False    False      False
# 15059         False    False      False       False    False      False
# 15148         False    False      False       False    False      False
# 15835         False    False      False       False    False      False
# 15980         False    False      False       False    False      False
# 16112         False    False      False       False    False      False
# 16861         False    False      False       False    False      False
# 17539         False     True      False       False    False      False
# ...             ...      ...        ...         ...      ...        ...
# 45193         False    False      False       False    False      False
# 47602         False    False      False       False    False      False
# 48133         False    False      False        True    False      False
# 49121         False    False      False       False    False      False
# 49595         False    False      False        True    False      False
# 49721         False    False      False       False    False       True
# 49854         False    False       True       False    False      False
# 50179         False    False      False        True    False      False
# 50185         False    False      False       False    False      False
# 50216         False    False      False       False    False      False
# 52099         False    False      False        True    False      False
# 52830         False    False      False       False    False      False
# 52917         False    False      False       False    False      False
# 54220         False    False      False       False    False      False
# 54454         False    False      False       False    False      False
# 54625         False    False      False       False    False      False
# 54829         False    False      False       False    False      False
# 55444         False    False      False       False    False      False
# 55929         False    False      False        True    False      False
# 57435         False    False      False       False    False      False
# 57639         False    False      False        True    False      False
# 58281         False    False      False       False    False      False
# 59390         False    False      False        True    False      False
# 61397         False    False      False       False    False      False
# 61486         False    False      False       False    False      False
# 62337         False    False      False       False    False      False
# 62804         False    False       True        True    False      False
# 63053         False     True       True        True    False      False
# 63770         False    False      False       False    False      False
# 64580         False    False      False       False    False      False
#
#        is_spoonerism
# 282             True
# 371             True
# 568             True
# 2084            True
# 2398            True
# 3299            True
# 4221            True
# 5856            True
# 6003            True
# 6608            True
# 6908            True
# 7612            True
# 9792            True
# 9901            True
# 10249           True
# 10807           True
# 11662           True
# 11894           True
# 12001           True
# 13235           True
# 13492           True
# 13600           True
# 14651           True
# 15059           True
# 15148           True
# 15835           True
# 15980           True
# 16112           True
# 16861           True
# 17539           True
# ...              ...
# 45193           True
# 47602           True
# 48133           True
# 49121           True
# 49595           True
# 49721           True
# 49854           True
# 50179           True
# 50185           True
# 50216           True
# 52099           True
# 52830           True
# 52917           True
# 54220           True
# 54454           True
# 54625           True
# 54829           True
# 55444           True
# 55929           True
# 57435           True
# 57639           True
# 58281           True
# 59390           True
# 61397           True
# 61486           True
# 62337           True
# 62804           True
# 63053           True
# 63770           True
# 64580           True
#
# [108 rows x 15 columns]

# %%
df['is_palindrome']  = df['exp'].apply(lambda x:len(re.findall('(palindrome)',x,re.IGNORECASE))>0)

# %%
df[df['is_palindrome']]
# Out:
#                                                     clue  \
# 187                                   Look both ways (4)
# 718                          Pass on way up and down (5)
# 2173                     Daryl or Gordon? Either way (6)
# 2761     When madam does this it makes no difference (7)
# 4822                   Look up, one way or the other (5)
# 10994        Level with another in top spot perhaps (11)
# 12009  An exclamation of mild disapprobation whicheve...
# 12417  One may be in the bar, and also on the counter...
# 12432               Built – that could be erected? (3,2)
# 12837  Stories from the north — the same from the sou...
# 15119           Decorate again, one way or the other (7)
# 15581                Crack running this way and that (3)
# 18831                     Uniform that’s reversible? (5)
# 21366        Royal address that could go either way? (4)
# 22370   Such a cheque is no good, even when returned (3)
# 27813                               Each-way stake (3,2)
# 28238              Muscle that may twist either way? (7)
# 30222                               Reversible canoe (5)
# 37330                          Partner, East or West (4)
# 39114                      Auntie viewed up and down (4)
# 40017  Radar perhaps picked up circuit in start of de...
# 40667                  firm belief from east or west (5)
# 41457                      Twelve there, twelve back (4)
# 41473                Principle that can do a U-turn? (5)
# 42865                                  Go either way (3)
# 44165   This tennis player’s form can be up and down (5)
# 45100  Broadcaster has to be looking in two direction...
# 47451                  Have a quick look up and down (4)
# 47598               One may be speeding either way (4,3)
# 48195      Abundance of crystals treating ailments (4,4)
# 48206  A fish going backwards around little island in...
# 48211                           One is drawn onward (10)
# 48986         Turner back in its original condition? (7)
# 49296           Doctrine written up remains the same (5)
# 50086                       Being raised, either way (7)
# 51978              Sprayed with water front and back (5)
# 54719           It detects things from any direction (5)
# 59585               Conviction that can be reversed? (5)
# 61371        Liveliness whichever way you look at it (3)
# 63695     Decorate from top to bottom, or vice versa (7)
#
#                                                      exp  is_anagram  \
# 187                                   PEEP A palindrome        False
# 718                            cryptic clue, palindrome        False
# 2173    Daryl Hannah (US actress) or Hannah Gordon (U...       False
# 2761    cryptic def; referring to the fact that the w...       False
# 4822             A palindrome (‘one way or the other’).        False
# 10994    PALINDROMES (both LEVEL and TOP SPOT are exa...       False
# 12009   tut-tut is a palindrome (whichever way you lo...       False
# 12417   MINIM A palindrome (and also on the counter) ...       False
# 12432   PUT UP A palindrome (reads the same upwards, ...       False
# 12837   SAGAS “from the north — the same from the sou...       False
# 15119                          cryptic clue; palindrome        False
# 15581                                        Palindrome        False
# 18831                  LEVEL, a palindrome (reversible)        False
# 21366                                        Palindrome        False
# 22370          DUD is a palindrome [even when returned]        False
# 27813   =”stake”=to support, tether. PUT UP is a pali...       False
# 28238                                  Palindrome &Lit.        False
# 30222             cryptic clue; reversible = palindrome        False
# 37330                             E or W = a palindrome        False
# 39114   Cryptic reference to the BBC, up and down for...       False
# 40017   PALINDROME (lap)rev. in d{escent} Rome — a pa...       False
# 40667               Palindrome (‘from east or west’)           False
# 41457   Cryptic definition. The first of three palind...       False
# 41473                               Another palindrome.        False
# 42865     PEP is a palindrome hence it means the same...       False
# 44165   Monica SELES, a palindrome (can be up and down)        False
# 45100   Slang for BBC, looking in two directions is a...       False
# 47451   PEEP – this verb meaning to have a quick look...       False
# 47598                            RACE CAR A palindrome.        False
# 48195   SALT MINE – anagram (treating) of AILMENTS 9,...        True
# 48206   DOMINICA – A COD (a fish) reversed (going bac...       False
# 48211       PALINDROME – ‘drawn onward’ is a palindrome        False
# 48986    Palindrome: This “turner” will be in its ori...       False
# 49296   TENET : Cryptic defn: A palindrome, which wri...       False
# 50086     The solution is a palindrome (‘either way’)...       False
# 51978   DEWED ‘front and back’ refers to the fact tha...       False
# 54719   RADAR (Not sure if this counts: Ada is a prog...       False
# 59585     The solution is a palindrome (‘that can be ...       False
# 61371   PEP : A palindrome(whichever way you look at ...       False
# 63695   REPAPER (the word is a palindrome so can be r...       False
#
#        is_homophone  is_double  is_cryptic  is_contain  is_reverse  \
# 187           False      False       False       False       False
# 718           False      False        True       False       False
# 2173          False      False       False       False       False
# 2761          False      False        True       False       False
# 4822          False      False       False       False       False
# 10994         False      False        True        True       False
# 12009         False      False       False       False       False
# 12417         False      False       False        True       False
# 12432         False      False       False       False       False
# 12837         False      False       False       False       False
# 15119         False      False        True       False       False
# 15581         False      False       False       False       False
# 18831         False      False       False       False       False
# 21366         False      False       False       False       False
# 22370         False      False       False       False       False
# 27813         False      False       False       False       False
# 28238         False      False       False       False       False
# 30222         False      False        True       False       False
# 37330         False      False       False       False       False
# 39114         False      False        True       False       False
# 40017         False      False       False        True       False
# 40667         False      False       False       False       False
# 41457         False      False        True        True       False
# 41473         False      False       False       False       False
# 42865         False      False       False       False       False
# 44165         False      False       False       False       False
# 45100         False      False       False        True       False
# 47451         False      False       False        True       False
# 47598         False      False       False       False       False
# 48195         False      False       False       False       False
# 48206         False      False       False        True        True
# 48211         False      False       False       False       False
# 48986         False      False       False        True        True
# 49296         False      False        True        True       False
# 50086         False      False       False       False       False
# 51978         False      False       False       False       False
# 54719         False      False       False       False       False
# 59585         False      False       False       False        True
# 61371         False      False       False       False       False
# 63695         False      False       False       False       False
#
#        is_alternate  is_init  is_delete  is_charade  is_&lit  is_hidden  \
# 187           False    False      False       False    False      False
# 718           False    False      False       False    False      False
# 2173          False    False      False       False    False      False
# 2761          False    False      False       False    False      False
# 4822          False    False      False       False    False      False
# 10994         False    False      False       False    False      False
# 12009         False    False      False       False    False      False
# 12417         False    False      False       False    False      False
# 12432         False    False      False       False    False      False
# 12837         False    False      False       False    False      False
# 15119         False    False      False       False    False      False
# 15581         False    False      False       False    False      False
# 18831         False    False      False       False    False      False
# 21366         False    False      False       False    False      False
# 22370         False    False      False       False    False      False
# 27813         False    False      False       False    False      False
# 28238         False    False      False       False     True      False
# 30222         False    False      False       False    False      False
# 37330         False    False      False       False    False      False
# 39114         False    False      False       False    False      False
# 40017         False    False      False       False    False      False
# 40667         False    False      False       False    False      False
# 41457         False    False      False       False    False      False
# 41473         False    False      False       False    False      False
# 42865         False    False      False       False    False      False
# 44165         False    False      False       False    False      False
# 45100         False    False      False       False    False      False
# 47451         False    False      False       False    False      False
# 47598         False    False      False       False    False      False
# 48195         False    False      False       False    False      False
# 48206         False    False      False       False    False      False
# 48211         False    False      False       False    False      False
# 48986         False    False      False       False    False      False
# 49296         False    False      False       False    False      False
# 50086         False    False      False       False    False      False
# 51978         False    False      False       False    False      False
# 54719         False    False      False       False    False      False
# 59585         False    False      False       False    False      False
# 61371         False    False      False       False    False      False
# 63695         False    False      False       False    False      False
#
#        is_spoonerism  is_palindrome
# 187            False           True
# 718            False           True
# 2173           False           True
# 2761           False           True
# 4822           False           True
# 10994          False           True
# 12009          False           True
# 12417          False           True
# 12432          False           True
# 12837          False           True
# 15119          False           True
# 15581          False           True
# 18831          False           True
# 21366          False           True
# 22370          False           True
# 27813          False           True
# 28238          False           True
# 30222          False           True
# 37330          False           True
# 39114          False           True
# 40017          False           True
# 40667          False           True
# 41457          False           True
# 41473          False           True
# 42865          False           True
# 44165          False           True
# 45100          False           True
# 47451          False           True
# 47598          False           True
# 48195          False           True
# 48206          False           True
# 48211          False           True
# 48986          False           True
# 49296          False           True
# 50086          False           True
# 51978          False           True
# 54719          False           True
# 59585          False           True
# 61371          False           True
# 63695          False           True

# %%
df['clue'] = df['clue'].apply(lambda x:re.sub("\(\d[,-]*\d*\)","",x))

# %%
df['not_clue'] = df['clue'].apply(lambda x:len(re.findall("[A-Z]{3,}",x))>0)

# %%
df=df[~df['not_clue']]

# %%
df = df.reset_index(drop=True)

# %%
df = df.drop("not_clue",axis=1)

# %%
df
# Out:
#                                                     clue  \
# 0           Nothing divides the lines – that’s the idea
# 1                                          Blows kisses
# 2        Run at it wildly, picking up speed and winning
# 3            Member of the Lords backtracking on record
# 4                                   Cheese cut & grated
# 5              One’s offered hospitality in rogue state
# 6      Those living abroad get help returning, with f...
# 7                                         Lower numbers
# 8            Finally, “Hi ho Silver” before the charge!
# 9      Did men live sinfully, being intent on wrongdo...
# 10     Without question, a route should be organised ...
# 11     Press on, having left the last trio of straggl...
# 12        Bottoms up, endlessly – that’s the watchword!
# 13              London landlord that’s facing sentence?
# 14     Party embracing a limit on spending from the b...
# 15               No being cryptic and causing problems!
# 16     For this reason lack of amplification is condu...
# 17     Doctor, can I get the first pair to inject ess...
# 18     Dropped dead while antidote was working? Bother!
# 19                          The main problem with canoe
# 20           Parisian caught breaking wind in congress?
# 21       Nick loses head in the sack – that’s messed up
# 22     Country stronghold you raid in anger at the fr...
# 23            Parents to tour Rome at first, then here?
# 24           Nice dame I put out is a really cool woman
# 25     Posh firm near Kent after good tip from Lord S...
# 26       Drinking like a setter? Don’t start panicking!
# 27        In Spain, the PM turned on old American model
# 28        Crazy couple of people getting jiggy with it?
# 29               Rubbish old git cites is all about me?
# ...                                                  ...
# 64419       Promote correct manner of ambulation, as 13
# 64420  Iodine thus something to discuss regarding sim...
# 64421          Potential layer in this painting finish?
# 64422  Weak character from outer space, a Klingon, as...
# 64423  Something cheeky about capital of Rhodesia, a ...
# 64424     Lying down in middle of boulevard after drink
# 64425  In which one may see Odette boast about the Fr...
# 64426                      Girl cuddling boy in a state
# 64427                           Clear away thatch aloft
# 64428               Cat, say, brought back after search
# 64429      Hornblower’s short speech after end of clash
# 64430    Suspicious transaction with him, a republican?
# 64431            Drank one given by doctor, one by bunk
# 64432  Court finally presented with motive for act of...
# 64433              Fuss about a single step in a series
# 64434  Complete change of opinion concerning fellow e...
# 64435  Provide forceful evidence against the Italian,...
# 64436            Is worried about small son getting pet
# 64437                   Willy Loman? Name lass involved
# 64438                      Roman god in place, cast out
# 64439                    Quack remedy in no way unusual
# 64440  Around northern tip of region, one state with ...
# 64441                 Chief magistrate upset about demo
# 64442   Inordinate praise about favourite hors d’oeuvre
# 64443                               Use Forster device?
# 64444          Computer image of distressed lamb in hut
# 64445          Trendy types, carollers surrounding wife
# 64446  Jazz fan about to reveal what goes on in night...
# 64447         Choose artist showing a complex character
# 64448                Turn down quantity of Chinese food
#
#                                                      exp  is_anagram  \
# 0       O (Nothing) between (divides) THE and RY (lin...       False
# 1       Double Definition. First one in to give a use...       False
# 2        MPH (speed) inside (RUN AT IT)* AInd: wildly...        True
# 3       RE (on) EP (reord) all reversed (backtracking...       False
# 4       (AMPERSAN[d] )* AInd: grated.  Last one in. S...        True
# 5                                   Hidden: roGUE STate        False
# 6       AID< (help, returning) first letters S P O R ...       False
# 7       N and ETHER are each a number: N just from N[...       False
# 8       AG (silver) before [h]I [h]O I had to look th...       False
# 9       (DID MEN LIVE)* AInd: sinfully 27/28 PUT ONE ...        True
# 10                (A ROUTE Q[uestion])* AInd: organised         True
# 11                     RE (on) PORT (left) [straggl]ERS        False
# 12                                      [b]OTTOM[s] < 6/       False
# 13      Charade: CAPITAL (London) LETTER (landlord) 7...        True
# 14      A CAP (a limit) inside DO (party). Musical term        False
# 15      Answer as wordplay NO is ON (playing) reverse...       False
# 16      ERGO (For this reason) NO MIC (lack of amplif...       False
# 17      (CAN I )* AInd: Doctor, IN[ject]. As seen on ...        True
# 18                   (ANITDOTE – D[ead])* AInd: working         True
# 19                          (CANOE)* AInd: problem with         True
# 20                                    (UN + C) in COIL.        False
# 21                                      [n]OTCH in BED.        False
# 22      Acrostic of S[tronghold] Y[ou] R[aid] I[n] A[...       False
# 23                            (PA + MA) touring R[ome].        False
# 24                            Anagram of (NICE DAME I).         True
# 25                            G + L[ord] + U + CO + SE.        False
# 26                                          [f]LAPPING.        False
# 27                           (EL + PM)< after (EX + A).        False
# 28                                     Two definitions.        False
# 29                          Anagram of (O + GIT CITES).         True
# ...                                                  ...         ...
# 64419   PROPAGATE A homophone of proper gait (‘correc...       False
# 64420   ISOTOPIC A charade of I (‘iodine’, chemical s...       False
# 64421       EGGSHELL Definition and cryptic definition.        False
# 64422   LIMPET A charade of LIMP (‘weak’) + ET (‘char...       False
# 64423   BURMA A charade of an envelope (‘about’) of R...       False
# 64424               SUPINE (IN+(boul)E(vard)) after SUP        False
# 64425                         SWAN LAKE (LA in SWANK)+E        False
# 64426                       LOUISIANA LOUISA around IAN        False
# 64427                       MOP UP MOP(hair, thatch)+UP        False
# 64428                         SCOURGE (EG<) after SCOUR        False
# 64429         HORATIO (clas)H+ORATIO Horatio Hornblower        False
# 64430   ANTIMONARCHIST (TRANSACTION+HIM*) 17. Said of...        True
# 64431                                IMBIBED I+MB+I+BED        False
# 64432                            TREASON (cour)T+REASON        False
# 64433                               STAIR STIR around A        False
# 64434                            ABOUT-FACE ABOUT+F+ACE        False
# 64435                          MILITATE (IL+IT) in MATE        False
# 64436                  CARESS CARES around S(on) … Down        False
# 64437                             SALESMAN (NAME+LASS*)         True
# 64438                                   PLUTO PL+(OUT*)         True
# 64439                                 NOSTRUM NO+ST+RUM        False
# 64440   WEATHER STATION R in (ONE STATE WITH A*) a bi...        True
# 64441                               NOMARCH (ON<)+MARCH        False
# 64442                    APPETISER (PRAISE*) around PET         True
# 64443   EMPLOY EM(forster)+PLOY clever misleading clu...       False
# 64444                          THUMBNAIL (LAMB IN HUT*)         True
# 64445                         SWINGERS SINGERS around W        False
# 64446             CABARET CAT around BARE &lit, perhaps        False
# 64447                                  ELECTRA ELECT+RA        False
# 64448                                   DIM SUM DIM+SUM        False
#
#        is_homophone  is_double  is_cryptic  is_contain  is_reverse  \
# 0             False      False       False        True       False
# 1             False       True       False        True       False
# 2             False      False       False        True       False
# 3             False       True       False        True        True
# 4             False      False       False        True       False
# 5             False      False       False       False       False
# 6             False      False       False       False        True
# 7             False      False        True       False       False
# 8             False      False       False       False       False
# 9             False      False       False        True       False
# 10            False      False       False       False       False
# 11            False      False       False       False       False
# 12            False      False       False       False        True
# 13            False      False       False        True       False
# 14            False      False       False        True       False
# 15            False      False       False        True        True
# 16            False      False       False       False       False
# 17            False      False       False       False       False
# 18            False      False       False       False       False
# 19            False      False       False       False       False
# 20            False      False       False        True       False
# 21            False      False       False        True       False
# 22            False      False       False       False       False
# 23            False      False       False       False       False
# 24            False      False       False       False       False
# 25            False      False       False       False       False
# 26            False      False       False       False       False
# 27            False      False       False       False        True
# 28            False       True       False       False       False
# 29            False      False       False       False       False
# ...             ...        ...         ...         ...         ...
# 64419          True      False       False       False       False
# 64420         False      False       False       False       False
# 64421         False      False        True       False       False
# 64422          True      False       False       False       False
# 64423         False      False       False        True       False
# 64424         False      False       False       False       False
# 64425         False      False       False        True       False
# 64426         False      False       False        True       False
# 64427         False      False       False       False       False
# 64428         False      False       False       False        True
# 64429         False      False       False       False       False
# 64430         False      False        True       False       False
# 64431         False      False       False       False       False
# 64432         False      False       False       False       False
# 64433         False      False       False        True       False
# 64434         False      False       False       False       False
# 64435         False      False       False        True       False
# 64436         False      False       False        True       False
# 64437         False      False       False       False       False
# 64438         False      False       False       False       False
# 64439         False      False       False       False       False
# 64440         False      False       False        True       False
# 64441         False      False       False       False        True
# 64442         False      False       False        True       False
# 64443         False      False       False        True       False
# 64444         False      False       False        True       False
# 64445         False      False       False        True       False
# 64446         False      False       False        True       False
# 64447         False      False       False       False       False
# 64448         False      False       False       False       False
#
#        is_alternate  is_init  is_delete  is_charade  is_&lit  is_hidden  \
# 0             False    False      False       False    False      False
# 1             False     True      False       False    False      False
# 2             False    False      False       False    False      False
# 3             False    False       True       False    False      False
# 4             False    False       True       False    False      False
# 5             False    False      False       False    False       True
# 6             False     True      False       False    False      False
# 7             False     True       True       False    False      False
# 8             False    False       True       False    False      False
# 9             False    False       True       False    False      False
# 10            False    False       True       False    False      False
# 11            False    False       True       False    False      False
# 12            False    False       True       False    False      False
# 13            False    False      False        True    False      False
# 14            False    False      False       False    False      False
# 15            False     True      False       False    False      False
# 16            False    False       True       False    False      False
# 17            False    False       True       False    False      False
# 18            False    False       True       False    False      False
# 19            False    False      False       False    False      False
# 20            False    False      False        True    False      False
# 21            False    False       True       False    False      False
# 22            False    False       True       False    False      False
# 23            False    False       True        True    False      False
# 24            False    False      False       False    False      False
# 25            False    False       True        True    False      False
# 26            False    False       True       False    False      False
# 27            False    False      False        True    False      False
# 28            False    False      False       False    False      False
# 29            False    False      False        True    False      False
# ...             ...      ...        ...         ...      ...        ...
# 64419         False    False      False       False    False      False
# 64420         False    False      False        True    False      False
# 64421         False    False      False       False    False      False
# 64422         False    False      False        True    False      False
# 64423         False    False      False        True    False      False
# 64424         False    False      False        True    False      False
# 64425         False    False      False        True    False      False
# 64426         False    False      False       False    False      False
# 64427         False    False      False        True    False      False
# 64428         False    False      False       False    False      False
# 64429         False    False      False        True    False      False
# 64430         False    False      False        True    False      False
# 64431         False    False      False        True    False      False
# 64432         False    False      False        True    False      False
# 64433         False    False      False       False    False      False
# 64434         False    False      False        True    False      False
# 64435         False    False      False        True    False      False
# 64436         False     True      False       False    False      False
# 64437         False    False      False        True    False      False
# 64438         False    False      False        True    False      False
# 64439         False    False      False        True    False      False
# 64440         False    False      False       False    False      False
# 64441         False    False      False        True    False      False
# 64442         False    False      False       False    False      False
# 64443         False    False      False        True    False      False
# 64444         False    False      False       False    False      False
# 64445         False    False      False       False    False      False
# 64446         False    False      False       False     True      False
# 64447         False    False      False        True    False      False
# 64448         False    False      False        True    False      False
#
#        is_spoonerism  is_palindrome
# 0              False          False
# 1              False          False
# 2              False          False
# 3              False          False
# 4              False          False
# 5              False          False
# 6              False          False
# 7              False          False
# 8              False          False
# 9              False          False
# 10             False          False
# 11             False          False
# 12             False          False
# 13             False          False
# 14             False          False
# 15             False          False
# 16             False          False
# 17             False          False
# 18             False          False
# 19             False          False
# 20             False          False
# 21             False          False
# 22             False          False
# 23             False          False
# 24             False          False
# 25             False          False
# 26             False          False
# 27             False          False
# 28             False          False
# 29             False          False
# ...              ...            ...
# 64419          False          False
# 64420          False          False
# 64421          False          False
# 64422          False          False
# 64423          False          False
# 64424          False          False
# 64425          False          False
# 64426          False          False
# 64427          False          False
# 64428          False          False
# 64429          False          False
# 64430          False          False
# 64431          False          False
# 64432          False          False
# 64433          False          False
# 64434          False          False
# 64435          False          False
# 64436          False          False
# 64437          False          False
# 64438          False          False
# 64439          False          False
# 64440          False          False
# 64441          False          False
# 64442          False          False
# 64443          False          False
# 64444          False          False
# 64445          False          False
# 64446          False          False
# 64447          False          False
# 64448          False          False
#
# [64449 rows x 16 columns]

# %%
df[
    ~df['is_anagram']&
    ~df['is_homophone']&
    ~df['is_double']&
    ~df['is_cryptic']&
    ~df['is_contain']&
    ~df['is_reverse']&
    ~df['is_alternate']&
    ~df['is_init']&
    ~df['is_charade']&
    ~df['is_&lit']&
    ~df['is_hidden']&
    ~df['is_spoonerism']&
    ~df['is_delete']&
    ~df['is_palindrome']
]
# Out:
#                                                     clue  \
# 49            Telegraphy switching parts of battle plan
# 63             Cop’s jumping obstacles for US teenagers
# 64                     Cheer following tart round dance
# 67     Wine: a dash of red with chicken is set before...
# 70               Protean US creature mounting a rostrum
# 76     Small group as is proper with end of concert g...
# 142    Large inflatable nipple burst by the German co...
# 144    Extremely racy novel arrangement might make Au...
# 159                      Lunatic shows off behind lorry
# 197               Pretext to cut recreation by per cent
# 199          Term at school about it produces merriment
# 223               Kick off again with skill after break
# 248    Chronic disorder remains to beset tense old wo...
# 252               Over-optimistic, wordy, lacking power
# 255               Good article about Old English writer
# 256    Southern resort, beside Lake, has something to...
# 259                        Channel avoided on the radio
# 260                      Regret a lot of vexed argument
# 262    Broadcaster with lots of cash keeping source o...
# 264        Relish receiving current bringer of delivery
# 265                   Badger runs repeatedly into grass
# 272         Comedian, one writing dully about sergeant?
# 273              Author‘s daughter becomes ill, not son
# 276     Old books on desert traveller in ideal location
# 279            Mother I see with leg misplaced in dance
# 281     See 11 Volunteers, smart, start to supervise ...
# 284          Scotsman in the East End, member of a sect
# 287      Bulb operating, something electrically charged
# 288                    Pole meeting journalist sat down
# 292                              Fan to drink Guinness?
# ...                                                  ...
# 63816                                 Play nurse first?
# 63829            3AIn parts, Brando, who may have a 28?
# 63837          28ADetached “sexists” who may have a 3A?
# 63844        Almost heaven, after tea, this French wine
# 63847  A Hollywood hangout for the stars, and racing ...
# 63848                           Remark on bridge puzzle
# 63868         Bill wants lay to turn over and misbehave
# 63873                     Sort of stroke beneath member
# 63877  Blair’s left-wing members hit back – a real gem!
# 63884                     Do row, as cowed MPs stand by
# 63920                        Illuminated note in volume
# 63924                        A network under discussion
# 63946                       Mother’s request for fabric
# 63956   Religious glibness in meeting Judge disregarded
# 63965        Two moccasins, say, either side of gumshoe
# 63971                                 A coarse American
# 64009                       Producer of fine cocktails?
# 64027                  Something hunted in blasted site
# 64075  Where Giants made a Causeway with one-for-one ...
# 64137                     Come on portrait of listener?
# 64187                            Ground needed for play
# 64188             Switch on ignition in service vehicle
# 64193                     Slips in evidence of humanity
# 64199  Contending successfully with a course of masonry
# 64308               Playwright‘s an obstacle right away
# 64322                Record-holder’s secret kept up it?
# 64353  Where bloomers are made like the fourth and si...
# 64373  Something that prevents quarrel where items ar...
# 64379  Finally changing sides,president establishing ...
# 64402                     Most important tree on street
#
#                                                      exp  is_anagram  \
# 49      TACTIC with its parts exchanged. TIC-TAC (whi...       False
# 63      BOBBY’S over OXERS. This word now has a rathe...       False
# 64                                    RAH following HO.        False
# 67                                          R HEN IS H.        False
# 70      A BEMA (rev). I was only vaguely familiar wit...       False
# 76      DUE (concer)T T. The second T is the encore. ...       False
# 142     ZEPPELIN ZE – comically how Germans pronounce...       False
# 144     RAUNCHIEST [AUSTEN RICH]*in a novel arrangement        False
# 159          MOONSTRUCK MOONS – shows offbehind & TRUCK        False
# 197                    PLEASURE (recreation)cut by half        False
# 199     HILARY (term at school) arounf IT As far as I...       False
# 223     RESTART : ART(a skill at doing a particular t...       False
# 248                                           as(T)h ma        False
# 252                                             {p}rosy        False
# 255                                          g (OE) the        False
# 256     S Hove L — OK Hove is a Southern resort, but ...       False
# 259                                            “ducked”        False
# 260                                          sor{e} row        False
# 262                                 Sky wa(r{evenue})ds        False
# 264                                           sav(I)our        False
# 265                                            ha(r r)y        False
# 272                                           ha(NCO)ck        False
# 273                                         d {s}ickens        False
# 276       OT (old books) after CAMEL (desert traveller)        False
# 279                                   MOTHER I SEE LEG*        False
# 281     TA (volunteers) STING (smart) S (start to Sup...       False
# 284                          hAMISH (scotsman, cockney)        False
# 287     ON (operating) ION (something electrically ch...       False
# 288                        PERCH (pole) ED (journalist)        False
# 292                       SUP (drink) PORTER (guinness)        False
# ...                                                  ...         ...
# 63816                             PRETEND PRE-TEND Down        False
# 63829   may have a 28 – sis(ter) / Brando = letters B...       False
# 63837   may have a 3A – bro(ther) / ‘sexists’ detache...       False
# 63844   CHABLIS BLIS(s) (“almost heaven”) after CHA (...       False
# 63847           SUNSET STRIP *TIPSTERS after (“on”) SUN        False
# 63848   CROSSWORD WORD (= “remark”) after (“on”) CROS...       False
# 63868   AC (Bill) TUP (lay) Not sure why the lay has ...       False
# 63873                      UNDER (beneath) ARM (member)        False
# 63877   ZAP is hot hit back, Def. is a gem, but do no...       False
# 63884                            PARTY (Do) LINE (Line)        False
# 63920   LITRE : LIT(illuminated) RE(the syllable used...       False
# 63924   AT ISSUE : A TISSUE(a network, eg. a tissue o...       False
# 63946   DAMASK : DAM(mother) ASK(request) Defn: A rev...       False
# 63956                                UNCTION (j)UNCTION        False
# 63965   SNAKE EYES SNAKES[moccasin is a type of snake...       False
# 63971   [definition only]  APPLE-KNOCKER (a coarse or...       False
# 64009   STUDFARM (one of the less well-knowndefinitio...       False
# 64027   QUARRY (a site for blasting; blasted site) QU...       False
# 64075   ANTRIM with I for A Well worth a visit, espec...       False
# 64137   DRAW NEAR : DRAWN EAR(a portrait of a ear,lis...       False
# 64187   PLOT ([a small piece of] ground) PLOT (the st...       False
# 64188   FIRE ENGINE (switch on ignition) FIRE ENGINE ...       False
# 64193   ERRORS (slips) ERRORS (reference the quote ‘t...       False
# 64199   COPING (the covering course of masonry of a w...       False
# 64308         BARRIE BARRIE(r), the author of Peter Pan        False
# 64322   SLEEVE I’m afraid I can’t see the wordplay he...       False
# 64353   BAKERY : Whimsical adjective describing(like)...       False
# 64373   BARROW : BAR(something that prevents/stops) R...       False
# 64379   CARTEL : Carter(Jimmy, the peanut farmer form...       False
# 64402   FIRST : FIR(kind of tree) ST(abbrev. for stre...       False
#
#        is_homophone  is_double  is_cryptic  is_contain  is_reverse  \
# 49            False      False       False       False       False
# 63            False      False       False       False       False
# 64            False      False       False       False       False
# 67            False      False       False       False       False
# 70            False      False       False       False       False
# 76            False      False       False       False       False
# 142           False      False       False       False       False
# 144           False      False       False       False       False
# 159           False      False       False       False       False
# 197           False      False       False       False       False
# 199           False      False       False       False       False
# 223           False      False       False       False       False
# 248           False      False       False       False       False
# 252           False      False       False       False       False
# 255           False      False       False       False       False
# 256           False      False       False       False       False
# 259           False      False       False       False       False
# 260           False      False       False       False       False
# 262           False      False       False       False       False
# 264           False      False       False       False       False
# 265           False      False       False       False       False
# 272           False      False       False       False       False
# 273           False      False       False       False       False
# 276           False      False       False       False       False
# 279           False      False       False       False       False
# 281           False      False       False       False       False
# 284           False      False       False       False       False
# 287           False      False       False       False       False
# 288           False      False       False       False       False
# 292           False      False       False       False       False
# ...             ...        ...         ...         ...         ...
# 63816         False      False       False       False       False
# 63829         False      False       False       False       False
# 63837         False      False       False       False       False
# 63844         False      False       False       False       False
# 63847         False      False       False       False       False
# 63848         False      False       False       False       False
# 63868         False      False       False       False       False
# 63873         False      False       False       False       False
# 63877         False      False       False       False       False
# 63884         False      False       False       False       False
# 63920         False      False       False       False       False
# 63924         False      False       False       False       False
# 63946         False      False       False       False       False
# 63956         False      False       False       False       False
# 63965         False      False       False       False       False
# 63971         False      False       False       False       False
# 64009         False      False       False       False       False
# 64027         False      False       False       False       False
# 64075         False      False       False       False       False
# 64137         False      False       False       False       False
# 64187         False      False       False       False       False
# 64188         False      False       False       False       False
# 64193         False      False       False       False       False
# 64199         False      False       False       False       False
# 64308         False      False       False       False       False
# 64322         False      False       False       False       False
# 64353         False      False       False       False       False
# 64373         False      False       False       False       False
# 64379         False      False       False       False       False
# 64402         False      False       False       False       False
#
#        is_alternate  is_init  is_delete  is_charade  is_&lit  is_hidden  \
# 49            False    False      False       False    False      False
# 63            False    False      False       False    False      False
# 64            False    False      False       False    False      False
# 67            False    False      False       False    False      False
# 70            False    False      False       False    False      False
# 76            False    False      False       False    False      False
# 142           False    False      False       False    False      False
# 144           False    False      False       False    False      False
# 159           False    False      False       False    False      False
# 197           False    False      False       False    False      False
# 199           False    False      False       False    False      False
# 223           False    False      False       False    False      False
# 248           False    False      False       False    False      False
# 252           False    False      False       False    False      False
# 255           False    False      False       False    False      False
# 256           False    False      False       False    False      False
# 259           False    False      False       False    False      False
# 260           False    False      False       False    False      False
# 262           False    False      False       False    False      False
# 264           False    False      False       False    False      False
# 265           False    False      False       False    False      False
# 272           False    False      False       False    False      False
# 273           False    False      False       False    False      False
# 276           False    False      False       False    False      False
# 279           False    False      False       False    False      False
# 281           False    False      False       False    False      False
# 284           False    False      False       False    False      False
# 287           False    False      False       False    False      False
# 288           False    False      False       False    False      False
# 292           False    False      False       False    False      False
# ...             ...      ...        ...         ...      ...        ...
# 63816         False    False      False       False    False      False
# 63829         False    False      False       False    False      False
# 63837         False    False      False       False    False      False
# 63844         False    False      False       False    False      False
# 63847         False    False      False       False    False      False
# 63848         False    False      False       False    False      False
# 63868         False    False      False       False    False      False
# 63873         False    False      False       False    False      False
# 63877         False    False      False       False    False      False
# 63884         False    False      False       False    False      False
# 63920         False    False      False       False    False      False
# 63924         False    False      False       False    False      False
# 63946         False    False      False       False    False      False
# 63956         False    False      False       False    False      False
# 63965         False    False      False       False    False      False
# 63971         False    False      False       False    False      False
# 64009         False    False      False       False    False      False
# 64027         False    False      False       False    False      False
# 64075         False    False      False       False    False      False
# 64137         False    False      False       False    False      False
# 64187         False    False      False       False    False      False
# 64188         False    False      False       False    False      False
# 64193         False    False      False       False    False      False
# 64199         False    False      False       False    False      False
# 64308         False    False      False       False    False      False
# 64322         False    False      False       False    False      False
# 64353         False    False      False       False    False      False
# 64373         False    False      False       False    False      False
# 64379         False    False      False       False    False      False
# 64402         False    False      False       False    False      False
#
#        is_spoonerism  is_palindrome
# 49             False          False
# 63             False          False
# 64             False          False
# 67             False          False
# 70             False          False
# 76             False          False
# 142            False          False
# 144            False          False
# 159            False          False
# 197            False          False
# 199            False          False
# 223            False          False
# 248            False          False
# 252            False          False
# 255            False          False
# 256            False          False
# 259            False          False
# 260            False          False
# 262            False          False
# 264            False          False
# 265            False          False
# 272            False          False
# 273            False          False
# 276            False          False
# 279            False          False
# 281            False          False
# 284            False          False
# 287            False          False
# 288            False          False
# 292            False          False
# ...              ...            ...
# 63816          False          False
# 63829          False          False
# 63837          False          False
# 63844          False          False
# 63847          False          False
# 63848          False          False
# 63868          False          False
# 63873          False          False
# 63877          False          False
# 63884          False          False
# 63920          False          False
# 63924          False          False
# 63946          False          False
# 63956          False          False
# 63965          False          False
# 63971          False          False
# 64009          False          False
# 64027          False          False
# 64075          False          False
# 64137          False          False
# 64187          False          False
# 64188          False          False
# 64193          False          False
# 64199          False          False
# 64308          False          False
# 64322          False          False
# 64353          False          False
# 64373          False          False
# 64379          False          False
# 64402          False          False
#
# [9061 rows x 16 columns]

# %%
df.to_csv("../fifteen_dataset/combined_2011-2018.csv",index=False)
