# %%
from bs4 import BeautifulSoup
from bs4 import NavigableString
import re
from itertools import groupby

# %%
import requests

# %%
def get_HTML(url):
    headers =  {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/57.0.2987.133 Safari/537.36' }    
    resp_data = requests.get(url, headers=headers).text
    return resp_data

# %%
def scrape_soup_cryptic_crossword_data(current_node):
    opened = []
    reached_across = False
    data = [] 
    while(current_node):
        if hasattr(current_node,'contents') and current_node.contents:
            opened += reversed(current_node.contents)
        else:
            if type(current_node) is NavigableString :
                p = current_node.parent
                style = p.get('style')
                name = p.name
                if(name=="u"or name=='strong'or(style and len(re.findall('(underline?|\<u\>)',style)))):
                    if(current_node != "\n"):
                        data.append('|{}|'.format(current_node))
                else:
                    data.append(current_node)


#                     has_underline = len(re.search('underline?',str(p)).groups())>0
                    
        if len(opened) > 0:
            current_node = opened.pop()
        else:
#             print(opened)
            break
    
    return [x[0] for x in groupby(data)]

# %%
def scrape_html_for_cryptic_crossword_data(html):
    try:
        soup = BeautifulSoup(html, "lxml")
        body = soup.find('body')
        return scrape_soup_cryptic_crossword_data(body.parent)
    except Exception as e:
        print(e)
        return []

# %%
#!/usr/bin/python

import os

dataset = []
i = 0
# traverse root directory, and list directories as dirs and files as files
for root, dirs, files in os.walk("/Users/life/Documents/www.fifteensquared.net"):
    path = root.split(os.sep)
    for file in files:
        if len(re.findall('.html$',file))>0:
            file_path = '/'.join(path)+'/'+file
            i%1000 == 0 and print(i)
            i+=1
            try:
                with open(file_path,encoding="utf8") as html:
                    dataset += scrape_html_for_cryptic_crossword_data(html)
            except Exception as e:
                print(e)
                continue
# Out:
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000

# %%
# dataset

# %%
corpus = re.sub('[\n\t]',' ',"".join(dataset))

# %%
corpus = re.sub('\xa0','',corpus)

# %%
corpus[:100]
# Out:
# '1 |Stubbornness| ruined body defending posh group of drivers (8) |OBDURACY| : Anagram of(ruined) BOD'

# %%
clues = re.findall('\d{1,2}[\.\s]*[A-Z]+[&…“”\s\w\-–—,’‘?;:!\/\\\|]+[\s]+\(\d{1,2}[,\-]*\d*\)',corpus)

# %%
len(clues)
# Out:
# 74128

# %%
clues[1000:1500]
# Out:
# ['17. Run into it in need of refreshing food (9)',
#  '18. Philip, say, gets excellent backing for business groups (9)',
#  '19. Dame Elisabeth started with indistinct sound (5)',
#  '20. Irish socialist usurps my credit? It couldn’t be simpler (11)',
#  '24. Challenge inconclusive victory somewhere in Australia (6)',
#  '25. Jaws writer clutches armpit (8)',
#  '26. On holiday, say, and just up out of bed (6)',
#  '27. Least reliable butcher likes wrapping article in paper (8)',
#  '2. Taking a snooze after a ransom? (10)',
#  '3. Where deer stores energy? (5)',
#  '4. One’s bent perhaps, not broken, kept in safe (6,6)',
#  '6. Drastic changes suppress mother’s tantrums (9)',
#  '7. Part of church a priest should enter first (4)',
#  '8. Wise to avoid independent Irish banker (4)',
#  '13. State of beauty with power to captivate the Italian? (10)',
#  '14. English males get sandwiches after a fight (10)',
#  '16. Treatment of celeb left clearing the air? (9)',
#  '21. Neck problem – Kent’s regulars don’t finish game (5)',
#  '22. Dame’s premature end (4)',
#  '23. Slow down bypassing Kelvin Hill in Glasgow (4)',
#  '1 DEFIANCE Upset ace fined for |open disobedience| (8)',
#  '5 AVENUE A meeting-place in |the suburban street| (6)',
#  '9 BLESSING |Grace|, opening batsman, gets unusual singles (8)',
#  '10 SNOOPS |Sneaks| around courts (6)',
#  '12 SALON Girl working in |a hairdressers| (5)',
#  '13 OPERATION |Medical treatment| in |battle| (9)',
#  '14 SNIPER Are all his shots singles through cover? (6)',
#  '16 GRINDER Mouth organist? (7)',
#  '19 SWEAR IN |Induct into office| when I answer correctly (5,2)',
#  '21 CREEPS |Toadies| engendering |feeling of revulsion| (6)',
#  '23 OTHERWISE  He swore it might be |different| (9)',
#  '25 DOWEL |Peg| possibly owed a pound (5)',
#  '26 INLAYS |Inserts| in songs (6)',
#  '27 ARTISTRY Create a stir, try |some skill| (8)',
#  '28 HANDLE Held with an awkward |grip| (6)',
#  '29 OPEN SHOP Frank to inform against |business accepting non-union staff| (4,4)',
#  '1 DEBASE |Lower| by degrees into river (6)',
#  '2 FREELANCE |He works alone| to import fish into European country (9)',
#  '3 ARSON The offence of one coming to light (5)',
#  '4 CONTOUR |Outline| of study-trip (7)',
#  '6 VANDALISE |Destroy| and put into a bag (9)',
#  '7 NAOMI No, I am wrong, |she was Ruth’s mother-in-law| (5)',
#  '8 ELSINORE |Location for Hamlet| relies on redevelopment (8)',
#  '11 BERG Plead a case for right |Austrian composer| (4)',
#  '15 PORTRAYAL |Depicting| characters performing in play or art (9)',
#  '17 DIPSWITCH Wash hairpiece – |it reduces the highlights| (9)',
#  '18 ASTONISH |Cause amazement| to a holy man on his involvement (8)',
#  '20 NAIL A love outwardly |secure| (4)',
#  '21 CHEER UP |Take encouragement| from acclamation at university (5,2)',
#  '22 PLAY UP |Misbehave| and |make too much of a story| (4,2)',
#  '24 HELEN She loved Paris – not only in the spring (5)',
#  '25 DEIGN Hamlet, say, gives |consent| (5)',
#  '1. Bill had a meal eating dog? True! (8)',
#  '5. Head covering in African country edged with gold (6)',
#  '9. Set off as Winnie’s companion crossing river (7)',
#  '10. Shouts when fattening food is served aboard ship (7)',
#  '11. Orpheus playing — without hesitation, a really great guy (9)',
#  '12. Resin? Last bit in tube’s lousy (5)',
#  '13. A smuttier rag may upset JPs (12)',
#  '20. Confession of professional killer somewhere off Scottish mainland (5)',
#  '21. Ability to understand, perhaps too late, things hid obscurely (9)',
#  '23. Bid in game, not game that politician will follow (2-5)',
#  '24. Poor person given shelter and love by leader of temple (4-3)',
#  '25. Old stone fouled up by the oil (6)',
#  '26. Close in on a fish keeping very quiet (8)',
#  '1. Skilled person in part is terrific (6)',
#  '2. Resentful employee of building firm? (6)',
#  '3. Bishop with inner conceit upset man, I understand (5)',
#  '6. Negotiate for a shire here? (5,4)',
#  '7. Put up with topless fashion making conversation (8)',
#  '10. Posh PM strains awkwardly to convey fairness and good humour (13)',
#  '14. Worker getting hold of a young drunk may be just the person to solve problem (5,4)',
#  '15. A doctor that is pleasant — one out to create an aura (8)',
#  '16. Stella running, full of energy in motion, is very thin (8)',
#  '18. Country overcome by thug and associate (6)',
#  '19. Bird enters school — something seen in the needlework class (6)',
#  '12 Somehow a loser with nothing |can, probably| (7)',
#  '14 In |battle| Lancaster’s first to leave squadron (5)',
#  '19 A good man rests in bed? |Most harmful|! (9)',
#  '2 Reform goes wrong for these |intimate friends| (5,4)',
#  '4 Englishwoman may hold |badge of rank| (9)',
#  '5 Negative expression |heard on the farm| (5)',
#  '7 Girl by |strength| (5)',
#  '15 Top royal in total disorder gets |reprimand| (7-2)',
#  '24 Good water |essential as a basis for whisky| (5)',
#  '01 Turning Twisting Messi Tricks” (10)',
#  '10  Clue I botched with no hint of science that is about |amino acid| (10)',
#  '14  Gulf shimmering with gold magnificence (6)',
#  '18  Study savoury, recipe included |showing wide tonal differences| (9)',
#  '20  Ridges in runny cheeses he cut, |cut in slices| (9)',
#  '27  School’s No 2 teaching English, in charge |of certain languages| (6)',
#  '2 Host clothed in a coloured |he’s obsessed with keeping clean| (10)',
#  '3  Surprising success, filled with stylish vigour? |To Jock it may be foolish| (7)',
#  '9  What poet may do about closing heart |valve| (7)',
#  '19  Ape grabbing it’s punished, |hit wrongly| (7)',
#  '23  You may find it rash going wild with |one in Cornish teas|! (5)',
#  '26  Giving strong drink up, |something important to Sikhs| (4)',
#  '1 Some Plymouth gin knocked over |nobleman| (6)',
#  '4 Small item of furniture is |fixed| (6)',
#  '11 Love’s in other words being ready to make |change| (10)',
#  '12 Heated, |dry out|? (9)',
#  '18 Rascal enthusiastic about |European city| (9)',
#  '24 Group of former workers fish – |this may be hoped for on retirement|! (6,9)',
#  '26 Journalist in news broadcast in |European country| (6)',
#  '1 Josh has new revolutionary |19| (7)',
#  '3 The French name picked by proprietor is |one from 18, say| (9)',
#  '7 Heads of executive note-taking company mislay |pen| (7)',
#  '13 Short moral discourse about detectives, one is |out for blood| (9)',
#  '14 That man in East London certainly had on women’s |make-up| (3,6)',
#  '20 Reportedly crazed, chic |model| (7)',
#  '22 Extremely silly fellow upset |group of clergymen| (5)',
#  '23 Ace detective died arresting hard |little sucker| (5)',
#  '1. Way to pay for course (8)',
#  '5. Sickness in China? Use antibiotics (6)',
#  '10. Leading elected group of people with a common goal (2,5)',
#  '11. Check on a dazzling display in carriage (7)',
#  '12. Own about fifty in Split? (5)',
#  '13. Who lacquers long hair, brushed back? Bank employee, heading off (9)',
#  '14. In a procession classes notice? (8,6)',
#  '18. Girl with apple shortly to make dessert (9,5)',
#  '20. Powerful older woman seen in troika, briefly, during parade (9)',
#  '22. Funny turn after onset of dizziness (5)',
#  '24. A crime such as this may give one little time to think rationally (7)',
#  '25. Vase containing ornate icon showing fabulous creature (7)',
#  '26. An ordinary seaman, sailor capsized in front of gondola (6)',
#  '27. Person supporting that woman through a depression (8)',
#  '1. King entering fray causes a shock (6)',
#  '2. Waste year away from Irish county (5)',
#  '3. Show clan misinterpreted a form of Langue d’oc (9)',
#  '6. Mindful of a conflict over Ecstasy (5)',
#  '7. Tranquil silence, in spite of that on Scottish loch (9)',
#  '8. Star in East, twinkling, seen by chance (8)',
#  '9. Sea dog’s steamer (5-9)',
#  '15. Set of rooms beside Thames originally housing soldiers (9)',
#  '16. Circular and folder in wastepaper basket (5,4)',
#  '17. Sign of wound across one hand cut by this? (8)',
#  '19. Earth flat? Most original of theories (6)',
#  '21. Children’s author almost upset dramatist (5)',
#  '23. Invigorating air in heart of blowy region (5)',
#  '1. Make out fabulous stores close to retail |chain| (8)',
#  '10. Notice skirts twirling in opener from Lady |Gaga| (6)',
#  '12. Winning back Liberals, virtuous type calls to |exert influence| (4,7)',
#  '20. Crazy family’s |slippers seen on these?| (6,5)',
#  '1. Trouble in new language? |You should have it at your fingertips| (4,6)',
#  '3. Throwing up portion of crisps ill-advisedly |makes sinner less fat|? (5)',
#  '6. Fleet Street heart-throb gets |closer| (5,4)',
#  '11. Reformed human sin with Pope |Victor’s tactics| (3-9)',
#  '13. Father becoming “pater” in |old German territory|? (10)',
#  '16. Nothing’s stopping complete poet getting |beyond the limits of his craft|? (9)',
#  '22. Turned up source of light |whimper| (4)',
#  '20 See 9 See 9 23 |FAGIN| OT character’s hard work at home (5)',
#  '1 He’s been removed from dictionary, |the beast| (6)',
#  '10 Injure retreating salesman: |run for it| (7)',
#  '12 About to request |a container| (4)',
#  '13 King George is back in Aberdeen perhaps, finding |somewhere to drink| (4,6)',
#  '25 Yes, Percy’s first; first on |duty| (4)',
#  '31 Take it when you’re committed (6)',
#  '3 How Mr Lyttleton contained his |doubt| (4)',
#  '16 Olympics run by Coe – not well – initially (3-7)',
#  '9 Birds leaving Canada behind; it’s |a sign| (5)',
#  '14 Dog-tired, Anna, having lost Pole, suffered |humiliation| (11)',
#  '19 This |hero| takes the road followed by six Kings (2,6)',
#  '22 Premier English flower |festival| (6)',
#  '26 Introducing mobster’s overtly lovely lady! (4)',
#  '10. One of the relative gains acquired through union negotiations (2-3)',
#  '11. Son was visibly moved, did some housework (5)',
#  '19. What are the odds of Ulster creating |employment|? (3)',
#  '26. Pressure moderate in |old person’s pulse| (5)',
#  '28. Measure covering energy |capture| (5)',
#  '3. Extremely short child in part of course, |like some classes in biology| (10)',
#  '6. Members of colony, we hear, |wind up in the Alps| (4)',
#  '8. Old hand mostly |has an outstanding score| (4)',
#  '19. One’s holding us up — that’s |inappropriate| (8)',
#  '23. Birthday’s ending soon, |as it happens| (6)',
#  '24. Royal I spotted around is |showing good judgment| (4)',
#  '5. Golfer’s shot home |help| (5,2)',
#  '10. Deal with secret dicky |bird| (9)',
#  '25. Lady holding line for |legion| (9)',
#  '27. Chuck and Kitty providing |frequent supper| (7)',
#  '28. Jolly fish entered |rough water| (4,3)',
#  '1. Ealing production that’s |good-humoured| (6)',
#  '2. A community centre did command |performance of early music| (6)',
#  '3. Old queen united with dogs coming round for |talks| (10)',
#  '5. Dolly’s for females inside |temple| (9)',
#  '6. Starters for ten — university challenges kitchen to provide |food| (4)',
#  '8. Yuan finally extracted from curious Cantonese |wallet| (8)',
#  '15. Rude sign stops rude |bankrupt| (9)',
#  '16. Thrown cigarette end missing |forest resident| (5,3)',
#  '20. Heavy sleepers oversleep after vacation? |Herbal medicine| is the answer (6)',
#  '24. Second-best |place for boarding| (4)',
#  '15.Peeled potato cakes, |part of salade verte|? (8)',
#  '27.Graf duel disfigured – |did it distinguish him at the front?| (8)',
#  '3.Misread quiz – every other to be written out in |form of Arabic| (5)',
#  '4.Former errand boy half caught up in |casualty| (6)',
#  '5.Off-key cornist |controls only one function| (7)',
#  '8.Impact poorly where love’s involved – |there’s no sex in its production| (7)',
#  '9.Fiasco damaged oar in |current down under| (7)',
#  '14.Spurn a line at sea, |dealing with old land campaign| (10)',
#  '24.Crack marksman historically not left in charge |regarding aim|? (5)',
#  '25.Tense travelling? |Lost footing| (5)',
#  '8. A table |in a train, say| (6)',
#  '13. Point of land facing tornado? |It’s hard to say| (6,7)',
#  '15. Desert deal possibly in the |frame| (10)',
#  '18. Stephano crashed |carriage| (8)',
#  '20. Artist losing knight in |game| (6)',
#  '1. Mother runs with ghastly hat on in |race| (8)',
#  '14. Which dear French |PM|? (8)',
#  '16. Gloomy pub in |Scottish town| (6)',
#  '1 Give a hand to collect |rubbish| (8)',
#  '19 Avengers manufactured |chemical weapon| (5,3)',
#  '21 A violin and guitar are unfinished, not hollow or |piercing| (10)',
#  '22 Epic poet detailed |birthplace| (4)',
#  '26 Question we try to compose on |keyboard| (6)',
#  '28 Tories, taking north not south, are obliterated by old |labour| (8)',
#  '8 Carelessly, I bang rock into |snake| (4,5)',
#  '13 About time to take new students for |a drink| (11)',
#  '15 Money to come out with for |Jack’s impulse buy| (9)',
#  '17 Foreign letter that French sailor took back inside gave |permission to enter port| (8)',
#  '23 Dictator invaded by Tanzania for |bread, as required by religion| (5)',
#  '5 See 15 See 15 6 |MADEIRA| Wine and cheese: uplifting with a little Gershwin (7)',
#  '10 Police coming around to arrest model after some bust up with |a servant| (8)',
#  '13 Battle back to capture an award for |coach| (6)',
#  '15 Help to eat cold |tart| (4)',
#  '16 Discourage an inclination to swallow up English |firm| (10)',
#  '27 Suitable to include exercises on it to finally stimulate |enthusiasm| (8)',
#  '28 I’m taken aback by doctors having |a drink| (6)',
#  '29 Roamed freely near the edges but kept |within bounds| (8)',
#  '1 Cover up girl’s |predicament| (7)',
#  '2 In imitation of a story containing the source of friction in |paradise| (9)',
#  '3 Experiment cut short over a number of |petty considerations| (6)',
#  '6 About to occur in |defeat| (8)',
#  '8 Credit the French duke when |amused| (7)',
#  '19 Assert as a right following Bill’s |enthusiastic praise| (7)',
#  '21 Essentially deny entering class with |an explosive device| (7)',
#  '22 Finnish spoken with |elegance| (6)',
#  '24 Democrat, upset about work, |felt dejected| (5)',
#  '1  Lecturer working with academic |author| (6)',
#  '4  He had a hammer and chisel initially to chip |inside the ribs| (8)',
#  '11  Advanced city with marine |distress| (5)',
#  '12  Dress to suppress loud |music| (4)',
#  '13  Mother uses broken toy shark to make |dolls| (10)',
#  '16  Ambassador key to Hungary’s |well being| (6)',
#  '28  Doctor nearly materialised, leaving the Master in |multiple universes| (9)',
#  '30  Whistler hesitates and |passes on| (6)',
#  '3  Rescue ship travelling north encounters |circular pods| (4)',
#  '5  Pictures of pigs by hot |painter| (7)',
#  '6  Child can follow scripture lessons with a |description of rationality| (10)',
#  '9  Expert with current maps upside-down takes right direction to start with (6)',
#  '20  Commander finally in charge after group’s |release| (3,4)',
#  '21  I leave idiot for a |Greek islander| (6)',
#  '22  Sending up a cry of disgust could be |sufficient| (6)',
#  '26  Force setter has shortly to |concede| (4)',
#  '11 PRINCETON Charles not up to university? (9)',
#  '1 Drivers tucked into fresh motel |porridge| (7)',
#  '5 Drink alcohol for |comfort| (7)',
#  '12 In a manner of speaking, without a |clue| (10)',
#  '16 One has to retain extraordinary |stillness| (7)',
#  '18 Glances saucily away from game when |drunk| (6)',
#  '24 Deterioration of worn central |engine part| (5)',
#  '1 With nothing to mark |award|? (5)',
#  '2 Return to market place escaping, opening |crush| (7)',
#  '6 Stay to have a look at reported |information| (10)',
#  '8 Old |news| (7)',
#  '16 Refusal to conclude |this is hellish| (7)',
#  '19 Allow to look through |brochure| (7)',
#  '23 Big names turn up with |shady character| (4)',
#  '4. Shop around for announced light source (8)',
#  '10. Tool ejected to bend metal back (7)',
#  '11. Brutes slam in a backhand (7)',
#  '12. One-time order for type of bomb (4)',
#  '13. Aligned anew, put off about … about … about … about … about … about the onset of influenza (10)',
#  '15. Surrounded by idiots, guru at last becomes opaque (6)',
#  '16. After a short time, even arsenic starts to seem horribly addictive (7)',
#  '20. Confidential data showing ship passing island back to front (7)',
#  '21. Stun no-good, holding opponents at bay to start with (6)',
#  '24. Public display of old site (10)',
#  '26. The elite return without a business-class car (4)',
#  '28. Over-embarrassed about irrational running back and forth being comparatively silly (7)',
#  '29. Harder to replace one with a permanent employee (7)',
#  '30. Infuriating US gun enthusiasts with drink, say, all around (8)',
#  '31. Cornered film director doesn’t finish day (6)',
#  '1. Foul vapours over Chad hiding a massively uneven contest (8)',
#  '3. Point to rising total of birds (4)',
#  '5. Clearance boss pulling up dock (8)',
#  '6. Iron held by parliamentary district at no time bringing complaint (5,5)',
#  '7. Player for Scottish team gets a red card (5)',
#  '8. Live to be partial again? (6)',
#  '9. Georgia put up billionaire (5)',
#  '14. Speaking to a theologian, scripture seems in the end to be musical (10)',
#  '17. Maybe cat’s milk could make us careful (9)',
#  '18. Government-administered students get up to eat spud (5-3)',
#  '19. Hid that old surgeon smoked perhaps (8)',
#  '22. Interfere in brawl about monkeys, the last being lost (6)',
#  '23. Very American composer (5)',
#  '25. Musician has piano in support (5)',
#  '27. Daughter with beard in the early morning (4)',
#  '1  There’s 100, fool, in brief U-turn (9)',
#  '6  European city recipes (4)',
#  '8  Our TV is set to get Love Master sketch (8)',
#  '9  Pyre made of prestige vehicle in wharf (6)',
#  '11  CD repaired with deeper piece of cotton wool? (8)',
#  '12  Scottish wooded valley country habits getting pretty low marks (6)',
#  '15  Resolve to tarry anew, keeping love in a whirl (8)',
#  '19  U trap, I’d say containing a mass of hair (6)',
#  '21  Muriel who wrote on the French King (8)',
#  '22  Blazing round London’s East End (6)',
#  '24  Isolate number from time the Guardian has divided by 50 (6)',
#  '25  Cotton fibre separator spirit and gracious hopping game (3,5)',
#  '26  Sunday best for recycling good belt attachment? (4)',
#  '27 Rams, angry looking with level temperature (3,6)',
#  '1  Nameless object with hot fast flow (5)',
#  '2  Imbibing nitrogen, be the greatest fibber? (7)',
#  '3  Small drink? It doesn’t matter much (5)',
#  '4  C-cricket? Where? (7)',
#  '5  Prophet restricts search (9)',
#  '6  Lug to be put in retreat, send the first one you come to (7)',
#  '7  Diamond saloon, possible favourite bar which secures a flight covering (6,3)',
#  '13  Tungsten pill popping debtor (9)',
#  '17  Went before noble and wrinkly dog overlapped (7)',
#  '18  Aim to restrict tabloid energy (7)',
#  '20  Source of ham writer, one entering piece (7)',
#  '22 Mutilate not one gable ornament (5)',
#  '23  Lifting watch, say (5)',
#  '1 Renegade, with silver hidden in dam, forms an |elaborate plan| (9)',
#  '8 I censor a badly |written summary of play’s plot| (8)',
#  '9 No sin found in |one yet to take vows| (6)',
#  '10 Invest a tenner to secure |property| (6)',
#  '11 I cry loudly for |dessert| (3,5)',
#  '16 Bone discovered in barrow is |about to perish| (8)',
#  '19 Tea ordered in attempt to reach |agreement between states| (6)',
#  '22 State adopting dancing bear is |not far away| (6)',
#  '24 Surrealist painter claiming right to meet central character in Carroll’s |Looking Glass| (6)',
#  '27 Priest leading men to evangelist’s final |manuscript| (9)',
#  '2 Managed to get rid of |plunder| (7)',
#  '3 During winter, sex is |brief|! (5)',
#  '4 Sticky stuff decays in |treats| (7)',
#  '5 Worried aunt got me a |vegetable| (9)',
#  '7 Evangelical Union against the Messiah embracing a |sacrament| (9)',
#  '13 Girl out, so arranged for a |physician| (9)',
#  '14 Must opera turn into |long-running play|? (9)',
#  '18 Dickens’ first twenty quires given to Queen by |idealist| (7)',
#  '20 Former Liberal issues a |warning| (7)',
#  '7A SIM Information carrier is going the wrong way on motorway (3)',
#  '9A PANEGYRIC Laudatory address for which grey snakes in the grass? (9)',
#  '10A ATLAS Titan with a fearsome burden finally got rid of cross (5)',
#  '11A HOSANNA Rating received by animator, praise be (7)',
#  '12A PEERAGE Lords go and speak with passion (7)',
#  '13A PHOTOJOURNALISM Motors around with John Paul I, snapping at the heels of the rich and famous? (15)',
#  '15A FORKED LIGHTNING Celestial phenomenon dedicated to monarch enthrals Felicity, with head turned north (6,9)',
#  '17A SOBER UP Get real ale tab written out – well done for drinking that! (5,2)',
#  '18A TEST ACT Historical pro-monarchy legislation put back with diplomacy (4,3)',
#  '20A PYLON Bearer of cable from Home Counties leaving 007 isolated? (5)',
#  '21A IMBURSING Having run into broken-down minibus, German settling (9)',
#  '22A TIS I confirm the identity of Pacific trees (3)',
#  '23A EASTER BUNNY A tenner buys novelty egg-carrier (6,5)',
#  '1D COP SHOP Crack opera enthralled Nick (3,4)',
#  '2D ANNUS HORRIBILIS One going in dodgy harbour inns with Iris? It’s really not a good time (5,10)',
#  '3D SIGYN Ram perhaps nurturing yen for wife of mischievous husband (5)',
#  '4D DERMATOGLYPHICS Box-occupier who talked up training got physical work on hands and feet (15)',
#  '5D UNCOPYRIGHTABLE The horrendous early botching up of work that can’t be made secure (15)',
#  '6D SPARE PART Has PA repartitioned walls a bit? (5,4)',
#  '7D SYLLABIFICATION A breakdown of communication, basically? Not if I can fix it! (15)',
#  '8D MISTERM Man acquires married name in an inappropriate way (7)',
#  '14D OPEN RANGE Area that’s limitless fruit – put a pound in! (4,5)',
#  '15D FUSSPOT Perfectionist three-quarters safeguard position (7)',
#  '19D SHRUB Irritate mum, promoted to supervise plant (5)',
#  '24 Choose to employ one hand, but raise the other here (5)',
#  '4  Tennis player‘s hard slog knocking out finalist (4)',
#  '9  To crack regiment, |they’re doggedly tough fighters| (5)',
#  '10  Details ultimately unknown about sort of therapy one’s given for |viral illness| (9)',
#  '11  As you say, they make better |herding dogs| (7)',
#  '12  English detachment returning initially on |train| (7)',
#  '16  Feasts taken regularly could make you |so| (3)',
#  '17  Without piano introduction perform |song| (3)',
#  '24  In time, towns developed in |southern Florida|? (9)',
#  '1  Mother keeps longing for |actor|, so called… (7)',
#  '4  After fog’s lifted, soldiers |attack| (2,3)',
#  '5  A college servant at Oxford dismissed university| course| (5)',
#  '14  Suggested adult should be hauled out and |charged| (8)',
#  '19  Hit by car’s |exhaust| ? (3,4)',
#  '2  On board, irate knight has no input (4)',
#  '5  Copper falls out with copper (8)',
#  '11  One more broadcast on the air (7)',
#  '13  Intone inclination (4)',
#  '15  That’s a surprise! I manage to lose in broken resistance (6)',
#  '16  Buddhist states toss Ravi out (7)',
#  '17  Intend to repress independent spirit (6)',
#  '19  Plate found by cops on outskirts of Caithness (4)',
#  '21  Tie-back in ill-gotten gains (7)',
#  '24  One stalled by endless new problems (6)',
#  '26  Developer of circuit returned after start of project in New York (4)',
#  '29  One fearsome rogue on the rampage (4)',
#  '31  Upset islanders regularly harboured old Eastender (6)',
#  '33  Separate fluid steadily (7)',
#  '34  Something to heat part of boat from the stern (4)',
#  '36  Smoother, but not hard, metal here (6)',
#  '38  Alternative to cold rice pudding, nothing less! (7)',
#  '40  Recline, perhaps, after a gin cocktail (6)',
#  '42  Grand tirade about grass (4)',
#  '43  Salicine hastily treated neck muscles (7)',
#  '44  Al is found in this ruined cloister yard (8)',
#  '45  Breaking up, it’s sacrificed in busiest exploits (4)',
#  '2  Works broadcast’s essential (5)',
#  '3  Futile to set up ten on TV? (6)',
#  '4  Goad reluctant horseman to take part (4)',
#  '6  Equips a fleet with a female title (4)',
#  '7  Dearth of bread following sex change (4)',
#  '8  Queen abandons one of her pets, being insignificant (3)',
#  '9  Song about team first to tactically loosen play (6)',
#  '10  Nancy’s sister gone away at last (5)',
#  '12  Choose one function (6)',
#  '18  Retrospectively act over tax declaration (6)',
#  '20  Arch over lake in heart of Eden (6)',
#  '23  Measures effect on sales of changing sides (4)',
#  '25  Shy about lapsed catholic’s crystal gaze (4)',
#  '28  Lasso slipping over Ted in money-making opportunity (6)',
#  '30  Unknown Truro leader of insurgency starts ordering mayhem (6)',
#  '32  O’Connor covers call transfers (6)',
#  '33  Sad about article in old East Germany (5)',
#  '35  Fires up Nissen-like houses (5)',
#  '37  Nettle bishop with a third note (4)',
#  '38  Local once occupied Baron’s stronghold (4)',
#  '39  Second Australian in Europe soon covered in hair (4)',
#  '41  Failing international lines (3)',
#  '20 Solver’s eaten half a fruit, |more green| (7)',
#  '21 Form an audible |spokesman| (7)',
#  '26 Masonic |drink| (5)',
#  '28 Won’t play |Rugby, possibly| (4)',
#  '31 Stop moving around, Gaff’s back on the |town| (8)',
#  '4 Note showing we object to |trick| (4)',
#  '5 Paul, confused about identity, |retired| (4,2)',
#  '7 Task I prepared for |Hindu goddess| (5)',
#  '13 Itinerant people, lacking distance learning, |take root| (3,2)',
#  '18 Energy shown by ever-rising |officer| (5)',
#  '24 Doctor Fog heard |commotion| (3-2)',
#  '25 After misdeed, best |place to receive instructions about behaviour| (5)',
#  '27 Don’t even test air-|head| (4)',
#  '20 See 12 See 12 21 |DRAGON| Persist as fiery character (6)',
#  '9 At extremities girl experiences irritation |produced by bugs| (8)',
#  '10 Sophy sick? |Out-of-date medicine| has contributed to that (6)',
#  '15 Tea is served, securing link with |voluntary organisations| (9)',
#  '19 Bank keeping quiet when| response| is demanded (5)',
#  '23 Dope with endeavour to join the |aristocracy| (6)',
#  '24 Peculiar larvae in |plant| (8)',
#  '25 Shoddy stuff at back of the |gallery|? (4)',
#  '3 I hit on ancestry unexpectedly — |something obtained from old documents|? (7,7)',
#  '6 Fantastic caress when beset by desire mounting? |It’s essential| (9)',
#  '8 Sorcerer and hag hop around — |we map out the steps| (14)',
#  '13 Support not weighing much |that may be used by photographer| (9)',
#  '18 A bit of cake maybe cut for a |ruler| (6)',
#  '20 Rep unexpectedly tight-lipped about one |bonus payment| (7)',
#  '22 Elder denied one |European title| (5)',
#  '1 The broken-down train isn’t |moving| (2,7)',
#  '6 Reason heard for |bird cries| (4)',
#  '9 Society girl rejected title? |Rubbish|! (6)',
#  '10 When companies provide |capital| (6)',
#  '15 Tory boss may make |an attempt to elicit sympathy| (3,5)',
#  '22 Graduate right to give approval to |composer| (6)',
#  '3 A fateful day for |military assistants| (5)',
#  '6 Tom takes in strip |show| (7)',
#  '20 A local |employee|? (7)',
#  '23 Rosie’s |willowy form| (5)',
#  '1  Think about mother’s |source of perfume| (8)',
#  '5  Magazine eradicated |pest| (6)',
#  '10  Apathetic summer working on |science| (4,11)',
#  '13  Country folk imprisoning soldiers left |a mess| (8)',
#  '18  Mostly evaluate |the dim bulbs|? (5)',
#  '20  US state in success? That is |a convivial feeling| (8)',
#  '23  African country developed the school, not church (7)',
#  '25  Relative taken outside following America’s |rejection| (7)',
#  '27  Fish in river? On the contrary |ditch| (6)',
#  '3  Mostly senseless time preceding debut of Labour |figure| (7)',
#  '14  Wire binding rings with daughter included in |collection| (8)',
#  '17  Autumn apartment to |offer no excitement| (4,4)',
#  '22  Make off with champion |cut of bacon| (6)',
#  '25  Regretted a form of |salsa| (5)',
#  '17 ARGOT Slow time for language (5)',
#  '26 ALMEH Dancing-girl’s uneasiness when unionist leaves and then he returns (5)',
#  '2 IVAN Terrible one beheaded female singer (4)',
#  '3 UNLIT Dark weapon rested (6)',
#  '4 ASSART Donkey to grub (6)',
#  '19 SAGA French author’s long story (4)',
#  '24 RUNG Spoke, having regrets (4)',
#  '27 ALALIA Inability to speak about city twice (6)',
#  '29 STINTS Southern birds are small waders (6)',
#  '9 See 16 10 |PEARL DIVER| Criminal prevailed before ending in slammer, one going down for a long time (5,5)',
#  '26 See 23 27 |STAYED| Remained proper, by the sound of it (6)',
#  '1. Fail to avoid young lady (4)',
#  '9. Name one volatile gas (4)',
#  '10. TV lawyer, character defending army suspect (5,5)',
#  '14. Drink from trophy after Cambridge college lost at last (6,3)',
#  '16. Fortunate? Very possibly (4)',
#  '17. Opposed to some in Constantinople (4)',
#  '18. Volunteers to feed US artist’s fish (5,4)',
#  '20. One eager to leave bang on time caught guard breaking into cupboard (5-7)',
#  '24. Drudge recalled being beaten about at home (10)',
#  '25. First to recognise a French character (4)',
#  '26. Weak type, complete killjoy (3,7)',
#  '27. Extremely clever? Yes, to some extent (4)',
#  '1. Leader of military junta shot head of charging animal (7)']

# %%
inputs = [(clues[i],clues[i+1],i) for i in range(len(clues)-1)]

# %%
inputs[0]
# Out:
# ('9 A vehicle kept by retired German in |US port| (8)',
#  '10 Sporting contest a timeless group backed in |dome| (6)',
#  0)

# %%
def get_explanation(curr_clue,next_clue,i):
    regex = re.escape(curr_clue) + '(.+?)' + re.escape(next_clue)
    try:
        return re.search(regex,corpus).group(1)
    except Exception:
        return "ERROR"

# %%
from itertools import starmap
from multiprocessing import Pool

# %%
with Pool(4) as pool:
    starmap_explanations = pool.starmap(get_explanation,inputs)
# starmap_explanations = []
# counter = 0
# for i in inputs:
#     if(counter % 100 == 0): print(counter)
#     counter += 1
#     starmap_explanations.append(get_explanation(i[0],i[1],i[2]))

# %%
starmap_explanations[12]
# Out:
# ' |ZOOM| : Z(the last;latest character in the English alphabet) + reversal of(bringing up, in a down clue) MOO(to low;to make the deep low sound uttered by cattle]. Answer: The cinematic technique of bringing a subject into close-up (zoom in) or causing it to recede (zoom out) while maintaining focus, using a zoom lens. '

# %%
clues[:10]
# Out:
# ['9 A vehicle kept by retired German in |US port| (8)',
#  '10 Sporting contest a timeless group backed in |dome| (6)',
#  '13 A priest, old chap moved when digesting extremes of religiosity in |unorthodox books| (9)',
#  '16 Second rousing cheer enveloping sports body and |athlete| (2,5)',
#  '19 Dubious name associated with individual |plant| (7)',
#  '21 Report of official banning |device to detect change|? (6)',
#  '27 Succeed at university in |medical examination|? (6-2)',
#  '29 Stay hiker disrupted with no end of drink in |a frenzied state| (8)',
#  '1 Contemplate banning outsiders |being legitimate| (6)',
#  '2 Bird beginning to swoop in part for |fish| (5,4)']

# %%
import pandas

# %%
clues_cpy = clues[:-1]

# %%
len(clues_cpy)
# Out:
# 74127

# %%
len(starmap_explanations)
# Out:
# 74127

# %%
df = pandas.DataFrame({'clue':clues_cpy,'exp':starmap_explanations})

# %%
df['len'] = df['exp'].apply(lambda x:len(x))

# %%
from matplotlib import pyplot

# %%
print(df['len'].mean())
pyplot.plot(df['len'])
# Out:
# 2030.305327343613

# %%
df = df[df['len']<400]

# %%
df = df.reset_index(drop=True)

# %%
df[df.clue.apply(lambda x:len(re.findall('\|.+\|?',x))>0)]
# Out:
#                                                     clue  \
# 0      9 A vehicle kept by retired German in |US port...
# 1      10 Sporting contest a timeless group backed in...
# 2      16 Second rousing cheer enveloping sports body...
# 3      19 Dubious name associated with individual |pl...
# 4      29 Stay hiker disrupted with no end of drink i...
# 5      1 Contemplate banning outsiders |being legitim...
# 6      2 Bird beginning to swoop in part for |fish| (...
# 7      8 Senior diplomat with a country house almost ...
# 8      11 Latest character bringing up low |cinematic...
# 9      15 Blame about to be forgotten in |testing per...
# 10     17 Awkward to-do amid bow, say, in |part of ch...
# 11     18 Preserve trailed by celebrated baseball pla...
# 62     8 Wise man hiding jug in |waste disposal syste...
# 63     11 Republican in state where progress is impos...
# 64     12 With this |type of remedy| get better takin...
# 65             22 Way for holy person to be |humble| (6)
# 66     23 Creature offering advice to punters, |dumpi...
# 67     24 Originally, colonialists swindled |African ...
# 68     25 Insect jumping from police officer’s |cloth...
# 69     3 Vehicle used by boy overturned by |one damag...
# 70     5 Male with Dutch tool for gathering up |plant...
# 71                   7 Choose the French |condiment| (6)
# 72     13 British weather event leads to |sudden insp...
# 73     18 Actors with neat arrangement for |half an i...
# 74              21 Fluffed lines — time to |sign up| (6)
# 102                               9 Punch a |priest| (4)
# 103                   15 Told to milk |farm animals| (4)
# 104    17 In scrabble, valuable characters embody a |...
# 105                    19 Broke and not very |fresh| (8)
# 106    26 You reactivate sample of |organic compound|...
# ...                                                  ...
# 67036  7 WORKHORSE |Trojan| king captured by Greek ch...
# 67037  8 NAZIISM Nationalist movement primarily welco...
# 67038  9 DOUBLE JOINTED Luddite, one with job in peri...
# 67039  15 POLYESTER |Material| girls in conversation?...
# 67040  18 RALEIGH |Elizabeth I’s favourite| beer in c...
# 67041          20 COMPERE For every income, a |host| (7)
# 67042  21 GROWN-UP |Over-eighteen| set to drink wine ...
# 67043  1 SPOT CHECKS Blemishes on the outside of holy...
# 67044        9 SORB Brothers returning for |service| (4)
# 67045  10 MELTING POT Gent involved with plot, I’m in...
# 67046           11 BOSTON |US city| street in favour (6)
# 67047  12 EVENTING Regular obsession, not hard when i...
# 67048  13 SONORANT |Type of sound| made by boy shouti...
# 67049  15 OWEN |Poet| seen as old and modern, looking...
# 67050   17 BRED |Raised |money, disposing of article (4)
# 67051  22 ALSATIAN |Dog| squatted, one occupying a gr...
# 67052  25 APPLE SAUCE |Squishy food| device hairy man...
# 67053  26 VASE |Container| with lubricant, not commer...
# 67054  27 EERY Very hard stuff putting maiden off – t...
# 67055  28 RESILIENCE Soldiers quiet, crossing island ...
# 67056  2 PRO BONO Supporting singer-songwriter |for t...
# 67057  3 TOBIT |Book| that’s beginning with account o...
# 67058  4 HYMENEAN |Old fashioned wedding|’s exciting ...
# 67059  5 COLLECTIVE NOUNS Number participating in nas...
# 67060  6 SOIREE |Party| thus faces anger, end of tole...
# 67061     7 TIGHTROPE |Line up for daring challenge| (9)
# 67062  14 OLD BAILEY I’d obey all that’s ordered in |...
# 67063  16 GOOD DEAL |Bargain| that you would expect f...
# 67064  18 RELAPSE Fruit tree growing up on trellis, o...
# 67065  20 CLASSIC |Standard work| in the third tier o...
#
#                                                      exp  len
# 0       |SAVANNAH| : [ A + VAN(a vehicle) ] contained...  112
# 1       |CUPOLA| : CUP(a sporting contest, eg. the FA...  228
# 2       |MO FARAH| : [ MO(short for a moment;a second...  336
# 3       |ANEMONE| : Anagram of(Dubious) NAME placed a...  133
# 4       |HYSTERIA| : Anagram of(disrupted) “stay hike...  104
# 5       |ONSIDE| : “consider”(to contemplate;think ab...  195
# 6       |DOVER SOLE| : DOVE(a bird belonging to the s...  294
# 7       |HEADACHE| : HE(abbrev. for “His/Her Excellen...  254
# 8       |ZOOM| : Z(the last;latest character in the E...  321
# 9       |PROBATION| : “reprobation”(disapproval;conde...  243
# 10      |ROOD-TOWER| : Anagram of(Awkward) TO-DO cont...  240
# 11      |CANBERRA| : CAN(to preserve in a can) placed...  371
# 62      SEWERAGE – a wise man around (hiding) a large...  349
# 63      DREADLOCKS – R(epublican) inside the state wh...   96
# 64      HERBAL – a verb meaning to get better around ...  213
# 65      MODEST – A way or style followed by the usual...   78
# 66      FLY-TIPPING – a small insect followed by a ve...   96
# 67      CHAD – the initial letter (originally) of Col...   92
# 68      SERGE – drop the three-letter insect from the...   71
# 69      VANDAL – a commercial vehicle followed by the...  247
# 70      MANDRAKE – a male person followed by D(utch) ...  227
# 71      PICKLE – a verb meaning to choose followed by...   75
# 72      BRAINSTORM – B(ritish) followed by a weather ...  180
# 73      CASTANET – a generic word for the actors in a...  354
# 74      ENLIST – an anagram (fluffed) of LINES follow...   59
# 102     |LAMA| : LAM(to punch;to beat) + A. Answer: A...   63
# 103     |EWES| : Homophone of(Told) “use”(to exploit;...   56
# 104     |JAZZ| : J,Z,Z(the valuable character tiles i...  161
# 105     |INSOLENT| : “insolvent”(broke;unable to pay ...  124
# 106        |UREA| : Hidden in(sample) “you reactivate”.    46
# ...                                                  ...  ...
# 67036   A double envelope (‘captured by’ and ‘clothin...  115
# 67037   An envelope (‘welcoming’) of AZ (‘extreme chr...  156
# 67038   An anagram (‘in peril’) of ‘luddite one’ plus...   54
# 67039   Sounds like (‘in conversation’) POLLY ESTHER ...   57
# 67040   An envelope (‘in’) of ALE (‘beer’) in RIGH[t]...   98
# 67041   An envelope (‘in-‘) of PER (‘for every’) in ‘...   53
# 67042   An envelope (‘to drink’) of WN (‘|W|i|N|e reg...   77
# 67043   SPECKS (blemishes) on the outside of [ OT (ho...  167
# 67044                        reverse of BROS (brothers)    28
# 67045                                     GENT PLOT IM*    15
# 67046                      ST (street) in BOON (favour)    30
# 67047   EVEN (regular) ThING (obsession, without ‘H’ ...   54
# 67048       [SON (boy) RANT (shouting)] around O (love)    45
# 67049   O (old) WEN (modern = NEW, reversed) – presum...   64
# 67050   BREaD (money, without ‘A’ – article) 19 VIOLE...  138
# 67051   [ SAT (squatted) I (one) ] in A LANd (ground,...  174
# 67052   APPLianCE (device, with ESAU – hairy man , re...  110
# 67053   VASEline (lubricant, without LINE for commerc...   59
# 67054   EmERY (very hard stuff, without ‘M’ – maiden,...   61
# 67055   [RE (soldiers) SILENCE (quiet)] around I (isl...   58
# 67056     PRO (supporting) BONO (singer-songwriter, U2)    47
# 67057   T (That’s, beginning) OBIT (account of someon...   56
# 67058                                       HE MEN NAY*    13
# 67059   NO (number) in CULTS VIOLENCE* (answer to 19ac)    49
# 67060      SO (thus) IRE (anger) E (end of toleranc|E|)    46
# 67061   cryptic clue 8 FLOUNCE |Decorative piece on g...   86
# 67062                                      ID OBEY ALL*    14
# 67063   cryptic clue; an alternative meaning for DEAL...   77
# 67064   reverse of ESPALiER (fruit tree on trellis, g...  103
# 67065           CLASS 1C (third tier of the first form)    41
#
# [52238 rows x 3 columns]

# %%
# df.to_csv("../fifteen_dataset/fifteen_all_tagged_2.csv",index=False)
